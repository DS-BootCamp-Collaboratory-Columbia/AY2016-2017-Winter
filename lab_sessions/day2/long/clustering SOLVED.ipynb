# %% [markdown]
# # Clustering
#
# In this module, we will learn about clustering in Python.

# %%
# %matplotlib inline
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets as skdat
import scipy

# %% [markdown]
# ## K-means clustering
#
# As discussed in the talk, K-means is an effective clustering algorithm that is widely used. In this lab, you will implement K-means and explore its strengths and limitations.
#
# Here is the pseudocode for K-means:<br/>
# <ol>
#     <li>randomly initialize $\mu_k, \mathrm{\;for\;} k=1,\dots,K$</li>
#     <li>while $\mu$ not converged:</li>
#     <ol>
#         <li>assign data point n to nearest cluster: $r_{n} \leftarrow \arg \min_k ||x_n - \mu_k ||^2, \mathrm{\;for\;} n=1,\dots,N$</li>
#         <li>count number of data points assigned to cluster $k$, $N_k \leftarrow \sum_{n=1}^N r_{nk}, \mathrm{\;for\;} k=1,\dots,K$</li>
#         <li>update cluster centers: $\mu_k \leftarrow \frac{1}{N_k} \sum_{n=1}^N x_n r_{nk}, \mathrm{\;for\;} k=1,\dots,K$</li>
#     </ol>
# </ol>
# Recall that $r_{nk}$ is a binary variable indicating whether data point $n$ is assigned to cluster $k$ and that $\mu_k$ is the center for cluster $k$. Note that $\mu_k$ could be a scalar or a vector; its dimensionality matches that of the data $x_{1:N}$.

# %% [markdown]
# ### Task 1
#
# Given the above pseudocode for K-means, complete the implementation below.
#
# Guidance: your answer will likely include a main *while* loop (one for each outer iteration of K-means) and two *for* loops (one stepping through the data and another stepping through the clusters).

# %%
def kmeans(X, K, eps=1e-5, max_iterations=200):
    """
        arguments:
            X: a (N,D) numpy array of observed data
            K: integer indicating number of clusters
            eps (optional): real threshold for change in mu for deciding when to stop
            max_iterations (optional): max num of iterations, regardless of eps threshold
        returns:
            mu: a (K,D) numpy array of cluster means after k-means converged
            R: a (N,K) numpy array of binary cluster assignments
    """
    
    #todo: put your code here
    (N,D) = X.shape
    np.random.seed(100)
    rand_n = np.random.choice(range(N),size=K)
    mu = X[rand_n,:]
    prev_mu = np.inf #always do the first iteration
    R = np.zeros((N,K)) #this will be written over before first read
    it = 0
    while np.abs(mu-prev_mu).sum() >= eps and it<max_iterations:
        #store previous value of mu
        prev_mu = mu.copy()
        #A. update cluster assignments according to nearest cluster
        for n in range(N):
            d = np.array([np.linalg.norm(X[n,:] - mu[k,:]) for k in range(K)])
            R[n,:] = 0.
            R[n,d.argmin()] = 1.
        #B. calculate cluster sizes
        Nk = R.sum(axis=0) + 1e-9 #add epsilon to avoid divide by zero errors
        #C. update cluster centers
        mu = np.dot(R.T, X) / Nk[:,np.newaxis] #results in a (K,D) matrix
        it += 1
        #print('cluster centers',mu)
        #print('cluster assignments',R)    
    
    return mu, R

#apply to some toy data generated by sklearn package:
N,D,K = 100, 2, 3
X, true_class = skdat.make_blobs(n_samples=N, n_features=D, centers=K, random_state=0)
mu, R = kmeans(X,K)
print('cluster centers',mu)
print('cluster assignments',R.argmax(axis=1))
print('true assignments',true_class)
# Out:
# cluster centers [[ 2.26282192  1.26005527]
#  [ 0.81438285  4.08457242]
#  [-1.82049132  2.84315898]]
# cluster assignments [0 1 0 1 1 1 2 2 0 1 1 1 0 1 2 0 2 1 2 2 2 2 2 1 0 0 0 0 2 2 1 0 0 1 2 1 1
#  0 0 2 2 0 0 1 1 1 0 0 2 2 1 0 1 0 2 2 0 0 1 0 0 2 2 2 2 0 1 2 0 1 2 0 2 0
#  1 1 1 1 2 0 1 1 0 1 1 1 1 1 0 1 1 0 1 2 2 1 1 1 2 2]
# true assignments [1 0 1 0 0 0 2 2 1 0 0 0 1 0 2 1 2 0 2 2 2 2 2 0 1 1 1 1 2 2 0 1 1 0 2 2 0
#  1 1 2 2 1 1 0 0 0 1 1 2 2 2 1 0 1 2 2 1 1 0 1 1 2 2 2 2 1 0 2 1 0 2 0 0 1
#  1 0 0 0 2 1 0 0 1 0 1 0 0 0 1 0 1 1 2 2 2 2 0 0 2 2]

# %%
plt.ioff()
def plot_clusters_2D(X,R,mu,separate=False,titles=None):
    colors = ['r', 'g', 'b']
    A = R.argmax(axis=1) #calculate most likely cluster assignment
    for k in range(K):
        nsk, = np.where(A==k) #select data points based on assignment
        c = colors[k % len(colors)] #choose colour from list
        plt.scatter(X[nsk,0], X[nsk,1], marker='x', color=c)
        plt.scatter(mu[k,0],mu[k,1],color=c)
        if titles is not None: plt.title(titles[k])
        if separate and k<K-1: plt.figure()
plot_clusters_2D(X,R,mu)

# %% [markdown]
# #### Question:
# How does your implementation scale in the number of data points $N$ and the number of clusters $K$?
#
# #### Answer:
# [write here]

# %% [markdown]
# #### Label switching
# Notice the discovered cluster assignments from K-means are different from the known assignments used in data generation, even though the means are quite close. This phenonmenon is known as "label switching" and results from the fact that the underlying model is symmetric with respect to cluster assignments (i.e., data points belong to the same cluster they are assigned to even if we switch the cluster id's of all the assignments).
#
# #### Bonus Task (optional)
# Write a method to calculate how well the cluster assignments discovered by K-means matches those of the generated data regardless of label switching. Use an error of 0 if they match and an error of 1 if they do not, then find the average over all data points.

# %% [markdown]
# ## Limitations of K-means

# %% [markdown]
# ### Task 2
#
# As discussed in the talk, there are several limitations of K-means. One of them is that it is sensitive to outliers.
#
# #### Question:
# Why is K-means sensitive to outliers (write below)?
# #### Answer:
# [here]
#
# The first step in this task is to add outliers to the above 2D toy data set. Set the variable outliers below to include outliers in the context of X and add it to the X dataset:

# %%
outliers = np.array([
                [30., 20.],
                [-30., -30.],
                [0., -25.]
                 ])
X_outlier = np.vstack((X, outliers))
mu1, R1 = kmeans(X_outlier,K)
plot_clusters_2D(X_outlier,R1,mu1)

# %% [markdown]
# Now apply your *kmeans* function to X_outliers and visualize the results. Specifically, color-code each data point $n$ by its assignment $r_{nk}$, giving each cluster a different color.

# %% [markdown]
# ## Clustering New York City collisions data
#
# To end this lab session, we will apply the clustering methods you just implemented to a subset of the New York City collisions data set. The data set is the location of traffic collisions in New York City between June 1st 2016 and June 8th 2016. The data was obtained from https://data.cityofnewyork.us/Public-Safety/NYPD-Motor-Vehicle-Collisions/h9gi-nx95/data
#
# We will use the `Pandas` library to simply load a CSV (comma-separated values) file of the data and display a summary (the first and last several rows) of the whole data file.

# %%
import pandas as pd
data_path = './data/nyc_collisions_01june_08june_2016.csv'
collisions_table = pd.read_csv(data_path)
collisions_table #browse data in a table format
# Out:
#             DATE   TIME        BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 
# 5335  06/08/2016  13:41      MANHATTAN   10019.0  40.770314 -73.991400
# 5336  06/08/2016  13:40            NaN       NaN        NaN        NaN
# 5337  06/08/2016  13:40         QUEENS   11414.0  40.670403 -73.856289
# 5338  06/08/2016  13:35      MANHATTAN   10002.0  40.719082 -73.985072
# 5339  06/08/2016  13:35       BROOKLYN   11235.0  40.583106 -73.954141
# 5340  06/08/2016  13:33          BRONX   10453.0  40.850181 -73.910582
# 5341  06/08/2016  13:31            NaN       NaN        NaN        NaN
# 5342  06/08/2016  13:30            NaN       NaN        NaN        NaN
# 5343  06/08/2016  13:30  STATEN ISLAND   10314.0  40.612808 -74.126292
# 5344  06/08/2016  13:30      MANHATTAN   10038.0  40.711972 -73.997771
# 5345  06/08/2016  13:30       BROOKLYN   11216.0  40.685966 -73.950678
# 5346  06/08/2016  14:15      MANHATTAN   10017.0  40.753318 -73.972587
# 5347  06/08/2016  14:15         QUEENS   11434.0  40.679030 -73.778420
# 5348  06/08/2016  14:15         QUEENS   11378.0  40.721031 -73.904096
#
#                        LOCATION        ON STREET NAME  CROSS STREET NAME  \
# 0                           NaN                   NaN                NaN
# 1                           NaN                   NaN                NaN
# 2                           NaN         RICHMOND ROAD      TARGEE STREET
# 3                           NaN         41-18 56TH ST          56 STREET
# 4                           NaN           MAIN STREET                NaN
# 5      (40.669946, -73.8426132)                   NaN                NaN
# 6     (40.8016264, -73.9096721)       EAST 136 STREET      WALNUT AVENUE
# 7                           NaN  NORTH CONDUIT AVENUE         140 STREET
# 8     (40.8891934, -73.8312982)           DYRE AVENUE    EAST 233 STREET
# 9                           NaN          AVERY AVENUE                NaN
# 10    (40.6745081, -73.9734955)                   NaN                NaN
# 11                          NaN             BELT PKWY                NaN
# 12    (40.7649726, -73.7777519)            209 STREET          38 AVENUE
# 13    (40.7714641, -73.9943462)        WEST 57 STREET          12 AVENUE
# 14    (40.7635447, -73.9851922)        WEST 52 STREET           8 AVENUE
# 15    (40.6528929, -73.8667311)         GATEWAY DRIVE     ERSKINE STREET
# 16    (40.6649915, -73.8813883)                   NaN                NaN
# 17                          NaN          WALDO AVENUE                NaN
# 18                          NaN            103 AVENUE                NaN
# 19                          NaN        S/B ASHLAND PL      LAFAYETTE AVE
# 20                          NaN    NORTHERN BOULEVARD                NaN
# 21                          NaN                   NaN                NaN
# 22    (40.6544387, -73.8608315)                   NaN                NaN
# 23                          NaN          NAGLE AVENUE                NaN
# 24                          NaN      AMSTERDAM AVENUE                NaN
# 25                          NaN                   NaN                NaN
# 26    (40.8043441, -73.9215703)    BRUCKNER BOULEVARD       BROOK AVENUE
# 27    (40.5550339, -74.1297557)       HYLAN BOULEVARD      SPRATT AVENUE
# 28    (40.7392896, -73.8528746)        WALDRON STREET         108 STREET
# 29                          NaN          LENOX AVENUE    WEST 124 STREET
# ...                         ...                   ...                ...
# 5319                        NaN        EAST 35 STREET        PARK AVENUE
# 5320  (40.7227174, -74.0044483)          GRAND STREET    THOMPSON STREET
# 5321  (40.7135991, -73.8019111)                   NaN                NaN
# 5322   (40.7065999, -73.855302)                   NaN                NaN
# 5323                        NaN                   NaN                NaN
# 5324  (40.8259386, -73.9492624)                   NaN                NaN
# 5325  (40.8112661, -73.9578098)      AMSTERDAM AVENUE    WEST 123 STREET
# 5326                        NaN         PRINCE STREET                NaN
# 5327                        NaN      BRONXWOOD AVENUE                NaN
# 5328                        NaN     BAY RIDGE PARKWAY                NaN
# 5329                        NaN      AMSTERDAM AVENUE                NaN
# 5330  (40.7585505, -73.8296366)             41 AVENUE  KISSENA BOULEVARD
# 5331  (40.8835177, -73.8452466)                   NaN                NaN
# 5332  (40.8082617, -73.9188059)          BROOK AVENUE    EAST 139 STREET
# 5333                        NaN                   NaN                NaN
# 5334  (40.7584318, -73.9730687)           PARK AVENUE     EAST 52 STREET
# 5335  (40.7703138, -73.9914004)             11 AVENUE     WEST 57 STREET
# 5336                        NaN             46 AVENUE                NaN
# 5337   (40.670403, -73.8562889)      LINDEN BOULEVARD          79 STREET
# 5338  (40.7190824, -73.9850722)      RIVINGTON STREET     CLINTON STREET
# 5339   (40.583106, -73.9541414)       SHORE BOULEVARD      EMMONS AVENUE
# 5340  (40.8501811, -73.9105821)         JEROME AVENUE    EAST 177 STREET
# 5341                        NaN   N/N FLATBUSH AVENUE   LAFAYETTE AVENUE
# 5342                        NaN            147 AVENUE         184 STREET
# 5343  (40.6128076, -74.1262915)                   NaN                NaN
# 5344  (40.7119717, -73.9977708)        MADISON STREET      OLIVER STREET
# 5345  (40.6859655, -73.9506777)                   NaN                NaN
# 5346  (40.7533182, -73.9725871)        EAST 46 STREET           3 AVENUE
# 5347  (40.6790298, -73.7784205)          SMITH STREET       BAISLEY BLVD
# 5348  (40.7210307, -73.9040958)       FLUSHING AVENUE          61 STREET
#
#                  OFF STREET NAME         ...          \
# 0                      73 AVENUE         ...
# 1                            NaN         ...
# 2                            NaN         ...
# 3                            NaN         ...
# 4                            NaN         ...
# 5           150-19 CROSSBAY BLVD         ...
# 6                            NaN         ...
# 7                            NaN         ...
# 8                            NaN         ...
# 9                            NaN         ...
# 10            223 BERKELEY PLACE         ...
# 11                           NaN         ...
# 12                           NaN         ...
# 13                           NaN         ...
# 14                           NaN         ...
# 15                           NaN         ...
# 16          805 CLEVELAND STREET         ...
# 17                           NaN         ...
# 18                           NaN         ...
# 19                           NaN         ...
# 20                           NaN         ...
# 21               WEST 141 STREET         ...
# 22                           NaN         ...
# 23                           NaN         ...
# 24                           NaN         ...
# 25    EAST 88 STREET YORK AVENUE         ...
# 26                           NaN         ...
# 27                           NaN         ...
# 28                           NaN         ...
# 29                           NaN         ...
# ...                          ...         ...
# 5319                         NaN         ...
# 5320                         NaN         ...
# 5321            84-17 164 STREET         ...
# 5322        89-89 UNION TURNPIKE         ...
# 5323                         NaN         ...
# 5324           565 WEST 145TH ST         ...
# 5325                         NaN         ...
# 5326                         NaN         ...
# 5327                         NaN         ...
# 5328                         NaN         ...
# 5329                         NaN         ...
# 5330                         NaN         ...
# 5331      1880 SCHIEFELIN AVENUE         ...
# 5332                         NaN         ...
# 5333                         NaN         ...
# 5334                         NaN         ...
# 5335                         NaN         ...
# 5336                         NaN         ...
# 5337                         NaN         ...
# 5338                         NaN         ...
# 5339                         NaN         ...
# 5340                         NaN         ...
# 5341                         NaN         ...
# 5342                         NaN         ...
# 5343      1872 VICTORY BOULEVARD         ...
# 5344                         NaN         ...
# 5345         355 NOSTRAND AVENUE         ...
# 5346                         NaN         ...
# 5347                         NaN         ...
# 5348                         NaN         ...
#
#       CONTRIBUTING FACTOR VEHICLE 2  CONTRIBUTING FACTOR VEHICLE 3  \
# 0                       Unspecified                    Unspecified
# 1                       Unspecified                            NaN
# 2                       Unspecified                            NaN
# 3                       Unspecified                            NaN
# 4                       Unspecified                            NaN
# 5                       Unspecified                            NaN
# 6                       Unspecified                            NaN
# 7                       Unspecified                            NaN
# 8                       Unspecified                            NaN
# 9                       Unspecified                            NaN
# 10                      Unspecified                            NaN
# 11                      Unspecified                    Unspecified
# 12                      Unspecified                            NaN
# 13                      Unspecified                            NaN
# 14                      Unspecified                            NaN
# 15                      Unspecified                            NaN
# 16                      Unspecified                            NaN
# 17                      Unspecified                            NaN
# 18                      Unspecified                            NaN
# 19                      Unspecified                            NaN
# 20                      Unspecified                            NaN
# 21                      Unspecified                            NaN
# 22                      Unspecified                            NaN
# 23                      Unspecified                            NaN
# 24                      Unspecified                            NaN
# 25                      Unspecified                            NaN
# 26                      Unspecified                            NaN
# 27                              NaN                            NaN
# 28                      Unspecified                            NaN
# 29                      Unspecified                            NaN
# ...                             ...                            ...
# 5319                            NaN                            NaN
# 5320                    Unspecified                            NaN
# 5321                    Unspecified                            NaN
# 5322                    Unspecified                    Unspecified
# 5323                    Unspecified                            NaN
# 5324                    Unspecified                            NaN
# 5325                            NaN                            NaN
# 5326                    Unspecified                            NaN
# 5327                    Unspecified                            NaN
# 5328                    Unspecified                            NaN
# 5329                    Unspecified                            NaN
# 5330                    Unspecified                            NaN
# 5331                    Unspecified                            NaN
# 5332                    Unspecified                            NaN
# 5333                    Unspecified                            NaN
# 5334                    Unspecified                            NaN
# 5335                    Unspecified                            NaN
# 5336                    Unspecified                            NaN
# 5337                    Unspecified                            NaN
# 5338                    Unspecified                            NaN
# 5339                    Unspecified                            NaN
# 5340                    Unspecified                    Unspecified
# 5341                    Unspecified                            NaN
# 5342                    Unspecified                            NaN
# 5343                    Unspecified                            NaN
# 5344                    Unspecified                            NaN
# 5345                    Unspecified                            NaN
# 5346                            NaN                            NaN
# 5347                            NaN                            NaN
# 5348                    Unspecified                            NaN
#
#       CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  \
# 0                               NaN                            NaN
# 1                               NaN                            NaN
# 2                               NaN                            NaN
# 3                               NaN                            NaN
# 4                               NaN                            NaN
# 5                               NaN                            NaN
# 6                               NaN                            NaN
# 7                               NaN                            NaN
# 8                               NaN                            NaN
# 9                               NaN                            NaN
# 10                              NaN                            NaN
# 11                      Unspecified                            NaN
# 12                              NaN                            NaN
# 13                              NaN                            NaN
# 14                              NaN                            NaN
# 15                              NaN                            NaN
# 16                              NaN                            NaN
# 17                              NaN                            NaN
# 18                              NaN                            NaN
# 19                              NaN                            NaN
# 20                              NaN                            NaN
# 21                              NaN                            NaN
# 22                              NaN                            NaN
# 23                              NaN                            NaN
# 24                              NaN                            NaN
# 25                              NaN                            NaN
# 26                              NaN                            NaN
# 27                              NaN                            NaN
# 28                              NaN                            NaN
# 29                              NaN                            NaN
# ...                             ...                            ...
# 5319                            NaN                            NaN
# 5320                            NaN                            NaN
# 5321                            NaN                            NaN
# 5322                            NaN                            NaN
# 5323                            NaN                            NaN
# 5324                            NaN                            NaN
# 5325                            NaN                            NaN
# 5326                            NaN                            NaN
# 5327                            NaN                            NaN
# 5328                            NaN                            NaN
# 5329                            NaN                            NaN
# 5330                            NaN                            NaN
# 5331                            NaN                            NaN
# 5332                            NaN                            NaN
# 5333                            NaN                            NaN
# 5334                            NaN                            NaN
# 5335                            NaN                            NaN
# 5336                            NaN                            NaN
# 5337                            NaN                            NaN
# 5338                            NaN                            NaN
# 5339                            NaN                            NaN
# 5340                            NaN                            NaN
# 5341                            NaN                            NaN
# 5342                            NaN                            NaN
# 5343                            NaN                            NaN
# 5344                            NaN                            NaN
# 5345                            NaN                            NaN
# 5346                            NaN                            NaN
# 5347                            NaN                            NaN
# 5348                            NaN                            NaN
#
#       UNIQUE KEY     VEHICLE TYPE CODE 1             VEHICLE TYPE CODE 2  \
# 0        3454728       PASSENGER VEHICLE               PASSENGER VEHICLE
# 1        3453352       PASSENGER VEHICLE               PASSENGER VEHICLE
# 2        3454271       PASSENGER VEHICLE               PASSENGER VEHICLE
# 3        3453995       PASSENGER VEHICLE               PASSENGER VEHICLE
# 4        3454727       PASSENGER VEHICLE               PASSENGER VEHICLE
# 5        3453945       PASSENGER VEHICLE               PASSENGER VEHICLE
# 6        3453118       PASSENGER VEHICLE                           OTHER
# 7        3454133       PASSENGER VEHICLE               PASSENGER VEHICLE
# 8        3455995       PASSENGER VEHICLE               PASSENGER VEHICLE
# 9        3454038       PASSENGER VEHICLE                             NaN
# 10       3453676  SMALL COM VEH(4 TIRES)               PASSENGER VEHICLE
# 11       3453944       PASSENGER VEHICLE               PASSENGER VEHICLE
# 12       3454098       PASSENGER VEHICLE               PASSENGER VEHICLE
# 13       3455680       PASSENGER VEHICLE               PASSENGER VEHICLE
# 14       3455694       PASSENGER VEHICLE                           OTHER
# 15       3456265       PASSENGER VEHICLE               PASSENGER VEHICLE
# 16       3453631       PASSENGER VEHICLE                             NaN
# 17       3456057                   OTHER               PASSENGER VEHICLE
# 18       3453813       PASSENGER VEHICLE               PASSENGER VEHICLE
# 19       3453743                   OTHER                             NaN
# 20       3454097       PASSENGER VEHICLE               PASSENGER VEHICLE
# 21       3455800       PASSENGER VEHICLE                         BICYCLE
# 22       3454575       PASSENGER VEHICLE               PASSENGER VEHICLE
# 23       3453094                   OTHER               PASSENGER VEHICLE
# 24       3452988       PASSENGER VEHICLE                           OTHER
# 25       3454354       PASSENGER VEHICLE                           OTHER
# 26       3455868       PASSENGER VEHICLE                             NaN
# 27       3454265       PASSENGER VEHICLE                             NaN
# 28       3454059       PASSENGER VEHICLE               PASSENGER VEHICLE
# 29       3493941       PASSENGER VEHICLE                           OTHER
# ...          ...                     ...                             ...
# 5319     3513781       PASSENGER VEHICLE                             NaN
# 5320     3460061       PASSENGER VEHICLE                             VAN
# 5321     3458789       PASSENGER VEHICLE               PASSENGER VEHICLE
# 5322     3458872       PASSENGER VEHICLE               PASSENGER VEHICLE
# 5323     3460043       PASSENGER VEHICLE               PASSENGER VEHICLE
# 5324     3458428       PASSENGER VEHICLE                           OTHER
# 5325     3458397       PASSENGER VEHICLE                             NaN
# 5326     3460059       PASSENGER VEHICLE               PASSENGER VEHICLE
# 5327     3458490       PASSENGER VEHICLE               PASSENGER VEHICLE
# 5328     3458555       PASSENGER VEHICLE               PASSENGER VEHICLE
# 5329     3458398       PASSENGER VEHICLE                           OTHER
# 5330     3458823  SMALL COM VEH(4 TIRES)          SMALL COM VEH(4 TIRES)
# 5331     3458499       PASSENGER VEHICLE               PASSENGER VEHICLE
# 5332     3459130       PASSENGER VEHICLE                           OTHER
# 5333     3461169       PASSENGER VEHICLE               PASSENGER VEHICLE
# 5334     3458348       PASSENGER VEHICLE               PASSENGER VEHICLE
# 
# We filter the data: removing columns (features) and rows (collisions) so that we end up with a `numpy` array `X` of collisions with valid latitutes and longitudes.

# %%
loc_collisions_table = collisions_table[np.isfinite(collisions_table['LATITUDE'])] #remove rows with NaNs
loc_collisions_table['TIME_HOUR'] = loc_collisions_table.TIME.apply(lambda x: float(x.split(':')[0]) + float(x.split(':')[1])/60.)
Xcol = loc_collisions_table.as_matrix(columns=['LONGITUDE','LATITUDE','TIME_HOUR'])
Xcol #display the data as a N-by-4 numpy array
# Out:
# /Users/jamesm/anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# array([[-73.8426132 ,  40.669946  ,   9.75      ],
#        [-73.9096721 ,  40.8016264 ,   9.73333333],
#        [-73.8312982 ,  40.8891934 ,   9.61666667],
#        ...,
#        [-73.9725871 ,  40.7533182 ,  14.25      ],
#        [-73.7784205 ,  40.6790298 ,  14.25      ],
#        [-73.9040958 ,  40.7210307 ,  14.25      ]])

# %% [markdown]
# ### Standardizing the data
# It is good practice to standardize the data, that is, to transform the data such that it has zero mean and unit standard deviation. This helps with hyperparameter selection and parameter exploration. But sometimes it's useful to work in the original space, so be sure to save the transformation variables for later.

# %%
tr_mn = Xcol.mean(axis=0)
tr_sd = (Xcol-tr_mn).std(axis=0)
Xcol1 = (Xcol-tr_mn)/tr_sd
#X = (X1-tr_mn)/tr_var
print('transformation variables:\n mean=',tr_mn,'std=',tr_sd)
print('X=\n',Xcol1)
#check:
print('check transformed X properties:\n mean=',Xcol1.mean(axis=0),'std=',Xcol1.std(axis=0))
# Out:
# transformation variables:
#  mean= [-73.91901381  40.72145239  13.69823791] std= [ 0.08740379  0.07928329  5.55553749]
# X=
#  [[ 0.87411096 -0.64965    -0.71068513]
#  [ 0.10687995  1.01123472 -0.71368514]
#  [ 1.00356759  2.11571719 -0.73468521]
#  ...,
#  [-0.61294008  0.40192346  0.0993175 ]
#  [ 1.60854935 -0.53507604  0.0993175 ]
#  [ 0.17067924 -0.00531874  0.0993175 ]]
# check transformed X properties:
#  mean= [  9.36951360e-14  -6.13649684e-14  -5.29832133e-17] std= [ 1.  1.  1.]

# %% [markdown]
# ### Visualize the data
# Now we are going to make a simple visualization of the data. Since `X` consists of 2-dimensional points we use a 2-dimensional scatter.

# %%
import seaborn as sns
sns.set(color_codes=True)
ax = sns.lmplot("LONGITUDE","LATITUDE", data=loc_collisions_table, fit_reg=False)

# %% [markdown]
# ### Task 4
#
# Apply your *kmeans* implementation to the NYC collisions data. Visualize the results, including the cluster assignments. What do you find?

# %%
K = 3
mu3, R3 = kmeans(Xcol1[:,:2],K)
print('cluster centers',mu3)
#titles = ['%i data points, average time of day = %.1f hours' % (R3.sum(axis=0)[k], mu3[k,2]*tr_sd[2]+tr_mn[2]) for k in range(K)]
#plot_clusters_2D(Xcol1[:,:2]*tr_sd[:2]+tr_mn[:2],R3,
#                 mu3*tr_sd[:2]+tr_mn[:2],
#                 separate=True) #,titles=titles)
#plot_clusters_2D(Xcol1[:,:2]*tr_sd[:2]+tr_mn[:2],R3,
#                 mu3*tr_sd[:2]+tr_mn[:2],
#                 separate=True) #,titles=titles)
# Out:
# cluster centers [[-0.72968579 -0.84060602]
#  [ 1.23576927 -0.14909324]
#  [-0.06860418  1.01964794]]
