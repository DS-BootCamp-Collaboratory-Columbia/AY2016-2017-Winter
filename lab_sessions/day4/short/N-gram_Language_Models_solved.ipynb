# %% [markdown]
# # N-Gram Language Models #

# %% [markdown]
# Language models are one of the most important concepts in Natural Language Processing (NLP). They help us assign probabilities to sequence of words, such as sentences or phrases. Their application spans beyond NLP. For example, language models help us obtain better speech recognition, optical character recognition (OCR) and information retrieval results, to name a few. Given a sentence $S$ with a set of $w_i$ words, $i=1,2,...,n$, language models formally define the probability of the sentence as the probability of having the particular sequence of words:
# $$ \Large p(S)=p(w_1, w_2, w_3, ... , w_n) $$
#
# They also help us predict the probability of a specific word given the previous words in the sentence:
#
# $$ \Large p(w | w_{-1}, w_{-2}..w_{-k}) $$
#
# The probability of a sentence is computed using the chain rule:
#
# $$ \Large p(S)=p(w_1, w_2, w_3, ... , w_n) = \prod_i^n {p(w_i|w_1,w_2,...,w_{i-1})} $$
#
# When computing this probability we use the Markov assumption which simplifies the computation of the above probability:
#
# $$ \Large p(S)=p(w_1, w_2, w_3, ... , w_n) \approx \prod_i^n {p(w_i|w_{i-k},w_{i-(k-1)},...,w_{i-1})} $$
#
# The Markov assumption states that the conditional probability of a word $w_i$, given all of the previous words in the sentence, could be approximated by considering only the $k$ previous words.

# %% [markdown]
# ### N-Gram Models ###

# %% [markdown]
# #### Unigram Model ####
# The unigram language model is the simplest of the n-gram models. Under this model the probability of the sentence $S$ is simply a product of the probabilities of each individual word in the sentence:
#
# $$ \Large p(S) \approx \prod_i^n {p(w_i)} $$
#
# N-gram probabilities are computed using Maximum Likelihood Estimates (MLE). For the unigram language model we compute MLE by counting the number of times word $w_i$ occurred in the collection and we divide that number by the total number of words $v$ in the collection:
# $$ \Large p(w_i) = \frac{count(w_i)}{\sum_{i=1}^{v}{count(w_i)}} $$
#
# #### Bigram Model ####
# In the bigram model the probability of a word is conditioned only on the previous word:
# $$ \Large p(S) \approx \prod_i^n {p(w_i|w_{i-1})} $$
#
# The MLE for the bigram LM is computed by dividing the number of times words $w_i$ and $w_{i-1}$ occured together in the collection with the number of occurances of word $w_i$, $count(w_i)$ :
#
# $$ \Large p(w_i|w_{i-1}) = \frac{count(w_i|w_{i-1})}{count(w_i)} $$
#
# #### Trigram Model ####
# In the trigram model the probability of a word is conditioned on the previous two words:
# $$ \Large p(S) \approx \prod_i^n {p(w_i|w_{i-1},w_{i-2})} $$
#
# The MLE for the trigram LM is computed by dividing the number of times words $w_i$, $w_{i-1}$, $w_{i-2}$ occurred together in the collection with the count for $w_{i-1}$ and $w_{i-2}$ occurring together, $count(w_{i-1},w_{i-2})$:
#
# $$ \Large p(w_i|w_{i-1},w_{i-2}) = \frac{count(w_i|w_{i-1},w_{i-2})}{count(w_{i-1},w_{i-2})} $$

# %% [markdown]
# ## Example ##
# In this task we are going to compute bigram and trigram language models using a novel. Rather than implementing language models on our own we are going to use the nltk package.

# %% [markdown]
# Look into the books folder and choose one of the ten books that you would like to compute language models over. In the example below we are using the novel "Siddhartha" by Herman Hesse. Load the book and extract words and sentences:

# %%
import nltk
import itertools
book= open('./books/hesse_siddhartha.txt','r').read()

words = nltk.word_tokenize(book)
words = [word.lower() for word in words]
sentences = nltk.sent_tokenize(book)
tokenized_sentences = []
for sentence in sentences:
	words = nltk.word_tokenize(sentence)
	words = [word.lower() for word in words]
	tokenized_sentences.append(words)

# %% [markdown]
# Compute bigram language model:

# %%
#First compute the bigrams (i.e. the tuple of words that occur together)
bigram_model  = nltk.bigrams(words)
#Then compute the frequency for each bigram
bigram_frequency_word = nltk.ConditionalFreqDist(bigram_model)
#To get the bigram probabilities we would need to normalize the bigram frequencies:
bigram_probability_word = nltk.ConditionalProbDist(bigram_frequency_word, nltk.MLEProbDist)

#Let's compute the bigram probabilities constraining on sentences:
bigram_frequency_sent = nltk.ConditionalFreqDist((word[0],word[1]) for word in list( itertools.chain (*[nltk.bigrams(i) for i in tokenized_sentences])))
bigram_probability_sent = nltk.ConditionalProbDist(bigram_frequency_sent, nltk.MLEProbDist)

#Let's print the bigram probabilities computed over sentences:
bigram_probability = bigram_probability_sent
bigram_frequency = bigram_frequency_sent

all_bigrams2 = {}
for source_word in bigram_probability:
	prob_words = bigram_probability[source_word].samples()
	denom = len(prob_words)
	all_bigrams2[source_word]={}
	for target_word in prob_words:
		prob = bigram_probability[source_word].prob(target_word)
		all_bigrams2[source_word][target_word] = prob
		print ("p("+target_word+"|"+source_word+")={0:.4f}".format(prob))
# Out:
# p(by|effected)=1.0000
# p(,|willingness)=0.3333
# p(to|willingness)=0.3333
# p(delights|willingness)=0.3333
# p(hermit|forlorn)=1.0000
# p(disciples|gotama's)=0.3333
# p(sermon|gotama's)=0.3333
# p(favourite|gotama's)=0.3333
# p(.|area)=1.0000
# p(,|pleased)=1.0000
# p(,|folded)=0.7500
# p(.|folded)=0.2500
# p(.|rumours)=1.0000
# p(the|informed)=1.0000
# p(golden|shone)=0.2500
# p(,|shone)=0.2500
# p(or|shone)=0.2500
# p(into|shone)=0.2500
# p(siddhartha|follow)=0.1250
# p(,|follow)=0.1250
# p(his|follow)=0.1250
# p(him|follow)=0.3750
# p(that|follow)=0.1250
# p(you|follow)=0.1250
# p(--|brahmans.)=1.0000
# p(which|features)=0.3333
# p(of|features)=0.3333
# p(,|features)=0.3333
# p(of|readiness)=1.0000
# p(up|woke)=1.0000
# p(buddha|alleged)=1.0000
# p(effected|is)=0.0031
# p(where|is)=0.0062
# p(full|is)=0.0031
# p(n't|is)=0.0278
# p(searching|is)=0.0031
# p(hard|is)=0.0031
# p(taking|is)=0.0031
# p(shaking|is)=0.0031
# p(good|is)=0.0216
# p(useful|is)=0.0031
# p(his|is)=0.0062
# p(easy|is)=0.0031
# p(now|is)=0.0123
# p(one|is)=0.0093
# p(harming|is)=0.0031
# p(alive|is)=0.0031
# p(no|is)=0.0370
# p(inside|is)=0.0031
# p(becoming|is)=0.0031
# p(fasting|is)=0.0031
# p(:|is)=0.0031
# p(space|is)=0.0031
# p(already|is)=0.0093
# p(as|is)=0.0093
# p(one-sided|is)=0.0062
# p(stronger|is)=0.0031
# p(precious|is)=0.0031
# p(it|is)=0.0123
# p(offering|is)=0.0031
# p(present|is)=0.0031
# p(right|is)=0.0031
# p(little|is)=0.0062
# p(the|is)=0.0494
# p(very|is)=0.0154
# p(atman|is)=0.0031
# p(accustomed|is)=0.0031
# p(special|is)=0.0031
# p(settled|is)=0.0031
# p(so|is)=0.0031
# p(going|is)=0.0062
# p(late|is)=0.0031
# p(our|is)=0.0031
# p(waiting|is)=0.0062
# p(still|is)=0.0062
# p(near|is)=0.0031
# p(red|is)=0.0031
# p(small|is)=0.0031
# p(fleeing|is)=0.0031
# p(nevertheless|is)=0.0062
# p(salvation|is)=0.0031
# p(trying|is)=0.0031
# p(better|is)=0.0062
# p(to|is)=0.0093
# p(just|is)=0.0123
# p(up|is)=0.0031
# p(turning|is)=0.0062
# p(nirvana|is)=0.0031
# p(beginning|is)=0.0062
# p(neither|is)=0.0031
# p(your|is)=0.0062
# p(breaking|is)=0.0031
# p(nothing|is)=0.0123
# p(how|is)=0.0123
# p(in|is)=0.0062
# p(holding|is)=0.0031
# p(also|is)=0.0247
# p(dead|is)=0.0031
# p(dangerous|is)=0.0031
# p(not|is)=0.0494
# p(excellent|is)=0.0031
# p(obsessed|is)=0.0031
# p(true|is)=0.0031
# p(time|is)=0.0031
# p(contained|is)=0.0031
# p(coming|is)=0.0154
# p(meditation|is)=0.0031
# p(life|is)=0.0031
# p(perfectly|is)=0.0031
# p(soul|is)=0.0031
# p(within|is)=0.0031
# p(unlikely|is)=0.0031
# p(called|is)=0.0093
# p(why|is)=0.0062
# p(drawn|is)=0.0031
# p(blown|is)=0.0031
# p(.|is)=0.0031
# p(divine|is)=0.0062
# p(never|is)=0.0216
# p(mine|is)=0.0031
# p(my|is)=0.0154
# p(brahman|is)=0.0062
# p(that|is)=0.0154
# p(oily|is)=0.0031
# p(worthless|is)=0.0031
# p(perfect|is)=0.0093
# p(giving|is)=0.0031
# p(satyam|is)=0.0031
# p(necessary|is)=0.0062
# p(willing|is)=0.0062
# p(foolish|is)=0.0031
# p(eternal|is)=0.0031
# p(over|is)=0.0062
# p(leaving|is)=0.0031
# p(proud|is)=0.0031
# p(always|is)=0.0031
# p(great|is)=0.0031
# p(and|is)=0.0031
# p(putting|is)=0.0031
# p(only|is)=0.0031
# p(unable|is)=0.0031
# p(fading|is)=0.0031
# p(able|is)=0.0093
# p(holy|is)=0.0031
# p(starting|is)=0.0031
# p(possible|is)=0.0031
# p(,|is)=0.0370
# p(indeed|is)=0.0031
# p(like|is)=0.0062
# p(eternally|is)=0.0031
# p(when|is)=0.0031
# p(with|is)=0.0031
# p(for|is)=0.0031
# p(worrying|is)=0.0031
# p(venerable|is)=0.0031
# p(put|is)=0.0031
# p(siddhartha|is)=0.0123
# p(everywhere|is)=0.0062
# p(proven|is)=0.0031
# p(such|is)=0.0031
# p(what|is)=0.0401
# p(beautiful|is)=0.0031
# p(left|is)=0.0031
# p(invaded|is)=0.0031
# p(enough|is)=0.0031
# p(vasudeva|is)=0.0031
# p(this|is)=0.0154
# p(spreading|is)=0.0031
# p(much|is)=0.0031
# p(connected|is)=0.0031
# p(a|is)=0.0586
# p(of|is)=0.0031
# p(kamala|is)=0.0031
# p(for|fasted)=1.0000
# p(,|cavities)=1.0000
# p(at|mirror)=1.0000
# p(off|shake)=1.0000
# p(,|speeches)=1.0000
# p(pupils|contracted)=1.0000
# p(the|ask)=0.2000
# p(for|ask)=0.3000
# p(no|ask)=0.1000
# p(and|ask)=0.1000
# p(one|ask)=0.1000
# p(,|ask)=0.1000
# p(you|ask)=0.1000
# p(it|notice)=1.0000
# p(,|ah)=1.0000
# p(and|quietly)=0.0714
# p(to|quietly)=0.0357
# p(flowing|quietly)=0.0357
# p(looked|quietly)=0.0357
# p(lowered|quietly)=0.0357
# p(dangling|quietly)=0.1071
# p(moving|quietly)=0.0357
# p(,|quietly)=0.4286
# p(in|quietly)=0.0357
# p(his|quietly)=0.0714
# p(.|quietly)=0.0714
# p(;|quietly)=0.0357
# p(sheep|male)=0.5000
# p(and|male)=0.5000
# p(point|the)=0.0005
# p(habit|the)=0.0010
# p(position|the)=0.0005
# p(circle|the)=0.0005
# p(cycle|the)=0.0039
# p(heat|the)=0.0005
# p(scent|the)=0.0010
# p(cheerfulness|the)=0.0010
# p(creation|the)=0.0005
# p(innumerable|the)=0.0005
# p(priest|the)=0.0010
# p(symbols|the)=0.0010
# p(perfection|the)=0.0010
# p(laughter|the)=0.0010
# p(butterfly|the)=0.0005
# p(discussions|the)=0.0005
# p(debtor|the)=0.0005
# p(quietly|the)=0.0005
# p(sake|the)=0.0015
# p(atman|the)=0.0034
# p(ablutions|the)=0.0005
# p(urge|the)=0.0005
# p(celebration|the)=0.0005
# p(voice|the)=0.0049
# p(magic|the)=0.0005
# p(courtesans|the)=0.0005
# p(source|the)=0.0020
# p(ferry|the)=0.0034
# p(upanishades|the)=0.0005
# p(offerings|the)=0.0020
# p(dust|the)=0.0005
# p(good|the)=0.0015
# p(face|the)=0.0044
# p(wise|the)=0.0039
# p(most|the)=0.0088
# p(moving|the)=0.0010
# p(driver|the)=0.0005
# p(forest|the)=0.0166
# p(non-self|the)=0.0010
# p(gloomy|the)=0.0005
# p(bow|the)=0.0015
# p(mountains|the)=0.0015
# p(business|the)=0.0020
# p(window|the)=0.0010
# p(mind|the)=0.0005
# p(rich|the)=0.0024
# p(voices|the)=0.0005
# p(other|the)=0.0068
# p(life|the)=0.0034
# p(yellow|the)=0.0024
# p(tongue|the)=0.0005
# p(hated|the)=0.0005
# p(depth|the)=0.0005
# p(hidden|the)=0.0005
# p(meantime|the)=0.0005
# p(transparent|the)=0.0005
# p(runaway|the)=0.0005
# p(front|the)=0.0005
# p(wrinkles|the)=0.0005
# p(village|the)=0.0015
# p(teaching|the)=0.0005
# p(last|the)=0.0034
# p(teacher|the)=0.0005
# p(nameless|the)=0.0005
# p(loss|the)=0.0005
# p(quietness|the)=0.0005
# p(only|the)=0.0020
# p(relief|the)=0.0005
# p(glory|the)=0.0005
# p(caste|the)=0.0005
# p(burning|the)=0.0015
# p(bluish|the)=0.0005
# p(pure|the)=0.0005
# p(streets|the)=0.0005
# p(fearful|the)=0.0005
# p(act|the)=0.0005
# p(ears|the)=0.0005
# p(buddha|the)=0.0147
# p(fragrance|the)=0.0005
# p(longing|the)=0.0005
# p(sight|the)=0.0010
# p(mirror|the)=0.0005
# p(hardness|the)=0.0005
# p(childlike|the)=0.0044
# p(sandy|the)=0.0005
# p(times|the)=0.0005
# p(core|the)=0.0005
# p(guard|the)=0.0005
# p(sunshine|the)=0.0010
# p(seat|the)=0.0010
# p(pangs|the)=0.0005
# p(origin|the)=0.0010
# p(stranger|the)=0.0010
# p(right|the)=0.0015
# p(merchants'|the)=0.0005
# p(young|the)=0.0064
# p(daytime|the)=0.0005
# p(deepest|the)=0.0005
# p(gotama|the)=0.0010
# p(beat|the)=0.0005
# p(thirty|the)=0.0005
# p(pleasure-garden|the)=0.0015
# p(robe|the)=0.0010
# p(realisation|the)=0.0005
# p(pale|the)=0.0010
# p(bottom|the)=0.0010
# p(conversation|the)=0.0005
# p(permission|the)=0.0005
# p(direct|the)=0.0005
# p(essential|the)=0.0010
# p(pike|the)=0.0010
# p(holiness|the)=0.0005
# p(following|the)=0.0005
# p(near|the)=0.0005
# p(pleasure-grove|the)=0.0005
# p(younger|the)=0.0010
# p(earth-coloured|the)=0.0005
# p(searching|the)=0.0005
# p(pilgrim|the)=0.0005
# p(thousand|the)=0.0010
# p(rational|the)=0.0005
# p(wide|the)=0.0005
# p(brahmans|the)=0.0059
# p(joyful|the)=0.0005
# p(nirvana|the)=0.0029
# p(trade|the)=0.0010
# p(table|the)=0.0005
# p(om|the)=0.0034
# p(leaving|the)=0.0005
# p(money|the)=0.0005
# p(mourning|the)=0.0005
# p(splendid|the)=0.0005
# p(venerable|the)=0.0024
# p(street-vendor|the)=0.0005
# p(gift|the)=0.0005
# p(mother|the)=0.0005
# p(majority|the)=0.0005
# p(maid|the)=0.0010
# p(feet|the)=0.0005
# p(stove|the)=0.0010
# p(beams|the)=0.0005
# p(lands|the)=0.0005
# p(milk|the)=0.0005
# p(multitude|the)=0.0010
# p(story|the)=0.0015
# p(community|the)=0.0015
# p(sacrifices|the)=0.0015
# p(damp|the)=0.0005
# p(possible|the)=0.0005
# p(boats|the)=0.0010
# p(arrow|the)=0.0015
# p(greedy|the)=0.0005
# p(two|the)=0.0049
# p(perfect|the)=0.0005
# p(stream|the)=0.0015
# p(importance|the)=0.0005
# p(golden|the)=0.0005
# p(habits|the)=0.0005
# p(pestilence|the)=0.0005
# p(blind|the)=0.0010
# p(feeling|the)=0.0020
# p(suffering|the)=0.0024
# p(service|the)=0.0015
# p(mute|the)=0.0005
# p(field|the)=0.0005
# p(wine|the)=0.0005
# p(love|the)=0.0024
# p(musicians|the)=0.0005
# p(essence|the)=0.0005
# p(eyes|the)=0.0010
# p(sky|the)=0.0044
# p(best|the)=0.0015
# p(beautiful|the)=0.0020
# p(completion|the)=0.0005
# p(veil|the)=0.0005
# p(bite|the)=0.0005
# p(unpleasant|the)=0.0005
# p(fields|the)=0.0005
# p(moonlight|the)=0.0005
# p(ground|the)=0.0054
# p(sensation|the)=0.0005
# p(hands|the)=0.0005
# p(invocation|the)=0.0005
# p(banana|the)=0.0005
# p(bushes|the)=0.0010
# p(smartest|the)=0.0010
# p(passion|the)=0.0005
# p(believers|the)=0.0005
# p(stakes|the)=0.0005
# p(white|the)=0.0005
# p(rain|the)=0.0010
# p(coronation|the)=0.0005
# p(spirit|the)=0.0010
# p(failure|the)=0.0005
# p(rice|the)=0.0005
# p(small|the)=0.0029
# p(ones|the)=0.0010
# p(guest|the)=0.0005
# p(inn|the)=0.0010
# p(lake|the)=0.0005
# p(doors|the)=0.0005
# p(brushwood|the)=0.0005
# p(path|the)=0.0073
# p(courtesan|the)=0.0015
# p(profits|the)=0.0005
# p(book|the)=0.0010
# p(fellow-members|the)=0.0005
# p(senses|the)=0.0034
# p(joys|the)=0.0005
# p(rainy|the)=0.0015
# p(enchantment|the)=0.0005
# p(lukewarm|the)=0.0005
# p(hut|the)=0.0073
# p(motionless|the)=0.0005
# p(flowing|the)=0.0005
# p(cornucopia|the)=0.0005
# p(day|the)=0.0039
# p(bitter|the)=0.0005
# p(teachers|the)=0.0010
# p(alleys|the)=0.0005
# p(listeners|the)=0.0005
# p(arrogant|the)=0.0005
# p(old|the)=0.0083
# p(parable|the)=0.0005
# p(divine|the)=0.0020
# p(separation|the)=0.0005
# p(dispute|the)=0.0010
# p(lanes|the)=0.0005
# p(thought|the)=0.0024
# p(boat|the)=0.0068
# p(flabby|the)=0.0005
# p(secret|the)=0.0020
# p(image|the)=0.0015
# p(common|the)=0.0005
# p(days|the)=0.0015
# p(root|the)=0.0005
# p(word|the)=0.0020
# p(ferrymen|the)=0.0015
# p(penitent|the)=0.0005
# p(dying|the)=0.0020
# p(morning|the)=0.0049
# p(universe|the)=0.0005
# p(pristine|the)=0.0010
# p(worldly|the)=0.0010
# p(thirst|the)=0.0010
# p(farmer|the)=0.0005
# p(wisest|the)=0.0010
# p(hair|the)=0.0015
# p(gamblers|the)=0.0010
# p(shadow|the)=0.0010
# p(first|the)=0.0083
# p(hundreds|the)=0.0005
# p(world|the)=0.0230
# p(depths|the)=0.0005
# p(scene|the)=0.0005
# p(seams|the)=0.0005
# p(bed|the)=0.0005
# p(form|the)=0.0010
# p(bodies|the)=0.0005
# p(bamboo-wood|the)=0.0005
# p(sanctity|the)=0.0005
# p(weeping|the)=0.0005
# p(reflecting|the)=0.0005
# p(night|the)=0.0064
# p(future|the)=0.0010
# p(exercises|the)=0.0005
# p(mouth|the)=0.0015
# p(large|the)=0.0015
# p(fastest|the)=0.0005
# p(immaterial|the)=0.0005
# p(penitents|the)=0.0015
# p(height|the)=0.0005
# p(stupid|the)=0.0010
# p(self|the)=0.0054
# p(irreproachable|the)=0.0005
# p(spring|the)=0.0005
# p(joy|the)=0.0005
# p(conscious|the)=0.0005
# p(basics|the)=0.0005
# p(latter|the)=0.0005
# p(servants|the)=0.0015
# p(smart|the)=0.0005
# p(kindness|the)=0.0005
# p(branches|the)=0.0005
# p(still|the)=0.0005
# p(darkness|the)=0.0005
# p(oar|the)=0.0020
# p(stable|the)=0.0010
# p(slightest|the)=0.0005
# p(open|the)=0.0005
# p(goal|the)=0.0039
# p(luminous|the)=0.0005
# p(opposite|the)=0.0015
# p(glistening|the)=0.0005
# p(silence|the)=0.0005
# p(gray|the)=0.0005
# p(pumpkin|the)=0.0005
# p(merchant|the)=0.0049
# p(novices|the)=0.0005
# p(harvest|the)=0.0005
# p(unexpressable|the)=0.0005
# p(ascetics|the)=0.0015
# p(marvellous|the)=0.0005
# p(raft|the)=0.0005
# p(door|the)=0.0024
# p(dancing|the)=0.0005
# p(farmers|the)=0.0005
# p(news|the)=0.0010
# p(verse|the)=0.0005
# p(gap|the)=0.0010
# p(glorious|the)=0.0010
# p(eternity|the)=0.0010
# p(random|the)=0.0010
# p(straw|the)=0.0010
# p(likes|the)=0.0005
# p(sound|the)=0.0015
# p(thinker|the)=0.0005
# p(disappointed|the)=0.0005
# p(realm|the)=0.0005
# p(stove's|the)=0.0005
# p(ever|the)=0.0010
# p(brahman|the)=0.0078
# p(scroll|the)=0.0005
# p(just|the)=0.0015
# p(man|the)=0.0015
# p(causes|the)=0.0015
# p(rolled|the)=0.0005
# p(goat|the)=0.0005
# p(pleasures|the)=0.0005
# p(weird|the)=0.0005
# p(scriptures|the)=0.0005
# p(ultimate|the)=0.0020
# p(holy|the)=0.0049
# p(bo-tree|the)=0.0005
# p(books|the)=0.0005
# p(things|the)=0.0015
# p(richest|the)=0.0005
# p(pleasure|the)=0.0005
# p(rapids|the)=0.0010
# p(boy|the)=0.0161
# p(dryness|the)=0.0005
# p(advice|the)=0.0005
# p(new|the)=0.0010
# p(sal-wood|the)=0.0005
# p(houses|the)=0.0005
# p(smashing|the)=0.0005
# p(ferryman|the)=0.0122
# p(daemons|the)=0.0010
# p(present|the)=0.0005
# p(garden|the)=0.0034
# p(mystery|the)=0.0005
# p(country|the)=0.0005
# p(fisher|the)=0.0005
# p(people|the)=0.0029
# p(courtesy|the)=0.0005
# p(trees|the)=0.0010
# p(moment|the)=0.0010
# p(breath|the)=0.0005
# p(wish|the)=0.0020
# p(creatures|the)=0.0005
# p(ability|the)=0.0005
# p(highest|the)=0.0024
# p(desired|the)=0.0005
# p(teachings|the)=0.0142
# p(murky|the)=0.0005
# p(friendship|the)=0.0005
# p(reason|the)=0.0005
# p(rumbling|the)=0.0005
# p(lamentation|the)=0.0005
# p(disgust|the)=0.0005
# p(oneness|the)=0.0039
# p(afternoon|the)=0.0005
# p(final|the)=0.0015
# p(father|the)=0.0044
# p(disease|the)=0.0005
# p(very|the)=0.0024
# p(lady|the)=0.0005
# p(shy|the)=0.0005
# p(hasty|the)=0.0005
# p(stars|the)=0.0034
# p(glow|the)=0.0005
# p(crystal|the)=0.0005
# p(corners|the)=0.0005
# p(midst|the)=0.0015
# p(entrance|the)=0.0024
# p(next|the)=0.0020
# p(squares|the)=0.0005
# p(vision|the)=0.0005
# p(lotus|the)=0.0005
# p(losses|the)=0.0005
# p(workers|the)=0.0005
# p(enlightenment|the)=0.0005
# p(huge|the)=0.0005
# p(moon|the)=0.0029
# p(warrior|the)=0.0005
# p(innermost|the)=0.0020
# p(women|the)=0.0005
# p(knowing|the)=0.0005
# p(thicket|the)=0.0010
# p(land|the)=0.0020
# p(beats|the)=0.0005
# p(beloved|the)=0.0005
# p(teeth|the)=0.0005
# p(villages|the)=0.0005
# p(towns|the)=0.0010
# p(agony|the)=0.0010
# p(links|the)=0.0005
# p(cold|the)=0.0005
# p(words|the)=0.0034
# p(room|the)=0.0015
# p(trunk|the)=0.0010
# p(indestructibility|the)=0.0010
# p(pious|the)=0.0005
# p(humblest|the)=0.0005
# p(food|the)=0.0010
# p(meals|the)=0.0005
# p(tremendous|the)=0.0005
# p(family|the)=0.0005
# p(monk|the)=0.0015
# p(reflection|the)=0.0005
# p(flower|the)=0.0005
# p(run-away|the)=0.0010
# p(mango|the)=0.0015
# p(one|the)=0.0039
# p(rosy|the)=0.0005
# p(noblemen|the)=0.0005
# p(beggar|the)=0.0005
# p(dead|the)=0.0010
# p(enlightened|the)=0.0010
# p(foolishness|the)=0.0010
# p(blue|the)=0.0015
# p(lustful|the)=0.0005
# p(rice-field|the)=0.0010
# p(venerability|the)=0.0005
# p(pain|the)=0.0024
# p(acts|the)=0.0005
# p(sacred|the)=0.0015
# p(cage|the)=0.0015
# p(head|the)=0.0005
# p(scholar|the)=0.0010
# p(knowledgeable|the)=0.0015
# p(orgies|the)=0.0005
# p(past|the)=0.0029
# p(lakshmi|the)=0.0005
# p(manner|the)=0.0005
# p(tip|the)=0.0005
# p(usual|the)=0.0010
# p(sin|the)=0.0005
# p(sail|the)=0.0005
# p(devote|the)=0.0005
# p(exercise|the)=0.0005
# p(visible|the)=0.0015
# p(indestructible|the)=0.0005
# p(pains|the)=0.0005
# p(thorny|the)=0.0005
# p(heads|the)=0.0005
# p(cheerful|the)=0.0005
# p(look|the)=0.0005
# p(workings|the)=0.0005
# p(nights|the)=0.0005
# p(followers|the)=0.0005
# p(alms-dish|the)=0.0010
# p(arrangement|the)=0.0005
# p(poison|the)=0.0005
# p(object|the)=0.0010
# p(city|the)=0.0103
# p(heavenly|the)=0.0015
# p(contents|the)=0.0010
# p(time|the)=0.0034
# p(jetavana|the)=0.0005
# p(river|the)=0.0406
# p(restlessness|the)=0.0005
# p(servant|the)=0.0015
# p(tired|the)=0.0005
# p(bows|the)=0.0005
# p(desire|the)=0.0010
# p(busy|the)=0.0005
# p(years|the)=0.0010
# p(spectacle|the)=0.0005
# p(possibility|the)=0.0005
# p(flow|the)=0.0020
# p(end|the)=0.0029
# p(barber|the)=0.0005
# p(hour|the)=0.0034
# p(bath|the)=0.0005
# p(consciousness|the)=0.0005
# p(waterfall|the)=0.0010
# p(hours|the)=0.0005
# p(coconut-tree|the)=0.0005
# p(greatest|the)=0.0005
# p(loincloth|the)=0.0005
# p(abandon|the)=0.0005
# p(sunset|the)=0.0005
# p(whorehouses|the)=0.0005
# p(mask|the)=0.0005
# p(shoulder|the)=0.0005
# p(gods|the)=0.0054
# p(ferry-boat|the)=0.0005
# p(stairs|the)=0.0005
# p(tree|the)=0.0015
# p(true|the)=0.0005
# p(banyan|the)=0.0010
# p(wrists|the)=0.0005
# p(friends|the)=0.0010
# p(beginning|the)=0.0020
# p(pretty|the)=0.0005
# p(mango-trees|the)=0.0005
# p(knowledge|the)=0.0020
# p(green|the)=0.0005
# p(body|the)=0.0020
# p(gestures|the)=0.0005
# p(heart|the)=0.0020
# p(job|the)=0.0005
# p(singing|the)=0.0005
# p(farewell|the)=0.0005
# p(eternal|the)=0.0034
# p(gold-beetle|the)=0.0005
# p(maja|the)=0.0010
# p(singular|the)=0.0010
# p(dry|the)=0.0005
# p(evening|the)=0.0049
# p(use|the)=0.0005
# p(myth|the)=0.0010
# p(bird|the)=0.0029
# p(flesh|the)=0.0005
# p(jackals|the)=0.0010
# p(fear|the)=0.0010
# p(moaning|the)=0.0005
# p(herd|the)=0.0005
# p(silently|the)=0.0005
# p(forests|the)=0.0020
# p(thinking|the)=0.0010
# p(sinner|the)=0.0015
# p(test|the)=0.0005
# p(air|the)=0.0015
# p(brown|the)=0.0010
# p(salutation|the)=0.0005
# p(decision|the)=0.0005
# p(mat|the)=0.0005
# p(funeral|the)=0.0005
# p(shady|the)=0.0005
# p(disputes|the)=0.0005
# p(hornbill-bird|the)=0.0005
# p(samana|the)=0.0034
# p(entire|the)=0.0015
# p(terrible|the)=0.0005
# p(camp|the)=0.0005
# p(thing|the)=0.0010
# p(shoes|the)=0.0005
# p(helper|the)=0.0005
# p(school|the)=0.0005
# p(pilgrims|the)=0.0015
# p(state|the)=0.0005
# p(maids|the)=0.0005
# p(speaker|the)=0.0005
# p(executioner|the)=0.0005
# p(monks|the)=0.0029
# p(plague|the)=0.0005
# p(fasting|the)=0.0005
# p(eye|the)=0.0005
# p(rocks|the)=0.0005
# p(crescent|the)=0.0005
# p(happy|the)=0.0010
# p(high|the)=0.0015
# p(cistern|the)=0.0005
# p(fruit|the)=0.0005
# p(grove|the)=0.0088
# p(pointlessness|the)=0.0010
# p(fire|the)=0.0005
# p(riverbank|the)=0.0005
# p(dim|the)=0.0005
# p(purpose|the)=0.0015
# p(wheel|the)=0.0020
# p(gesture|the)=0.0010
# p(handsome|the)=0.0005
# p(thoughts|the)=0.0010
# p(pilgrimage|the)=0.0005
# p(sick|the)=0.0005
# p(salvation|the)=0.0005
# p(bananas|the)=0.0005
# p(merchandise|the)=0.0005
# p(mango-tree|the)=0.0010
# p(possessions|the)=0.0005
# p(rig-veda|the)=0.0005
# p(eightfold|the)=0.0005
# p(great|the)=0.0049
# p(light|the)=0.0020
# p(faces|the)=0.0005
# p(hedge|the)=0.0005
# p(master|the)=0.0010
# p(thousandfoldness|the)=0.0005
# p(perfected|the)=0.0029
# p(recitation|the)=0.0005
# p(unknown|the)=0.0005
# p(bamboo|the)=0.0005
# p(rumour|the)=0.0005
# p(place|the)=0.0015
# p(amount|the)=0.0005
# p(solely|the)=0.0005
# p(oldest|the)=0.0020
# p(priests|the)=0.0005
# p(whole|the)=0.0010
# p(water|the)=0.0078
# p(host|the)=0.0005
# p(scream|the)=0.0005
# p(delusion|the)=0.0005
# p(bondage|the)=0.0005
# p(mistress|the)=0.0005
# p(course|the)=0.0005
# p(injury|the)=0.0005
# p(concentration|the)=0.0005
# p(traveller|the)=0.0005
# p(knife|the)=0.0005
# p(same|the)=0.0210
# p(rules|the)=0.0015
# p(travellers|the)=0.0005
# p(sun|the)=0.0044
# p(parade|the)=0.0005
# p(uncertain|the)=0.0005
# p(paper|the)=0.0005
# p(stone|the)=0.0010
# p(hill|the)=0.0005
# p(healing|the)=0.0005
# p(textbooks|the)=0.0005
# p(gate|the)=0.0010
# p(banana-trees|the)=0.0005
# p(chimpanzee|the)=0.0005
# p(soul|the)=0.0029
# p(side|the)=0.0010
# p(sleep|the)=0.0015
# p(foot|the)=0.0005
# p(awakening|the)=0.0010
# p(music|the)=0.0005
# p(ways|the)=0.0005
# p(sakyamuni|the)=0.0010
# p(rest|the)=0.0005
# p(log|the)=0.0005
# p(cult|the)=0.0005
# p(kamaswami-people|the)=0.0005
# p(wrong|the)=0.0005
# p(way|the)=0.0039
# p(return|the)=0.0005
# p(baskets|the)=0.0005
# p(worth|the)=0.0005
# p(deeply|the)=0.0005
# p(autumn|the)=0.0005
# p(attention|the)=0.0005
# p(passenger|the)=0.0005
# p(bank|the)=0.0044
# p(dice|the)=0.0015
# p(more|the)=0.0020
# p(ordinary|the)=0.0005
# p(work|the)=0.0010
# p(skinny|the)=0.0005
# p(silent|the)=0.0005
# p(name|the)=0.0024
# p(submission|the)=0.0005
# p(deep|the)=0.0010
# p(eccentric|the)=0.0005
# p(rushing|the)=0.0015
# p(canes|the)=0.0005
# p(child|the)=0.0005
# p(middle|the)=0.0010
# p(verses|the)=0.0005
# p(shore|the)=0.0005
# p(sedan-chair|the)=0.0010
# p(house|the)=0.0020
# p(fig|the)=0.0010
# p(animal|the)=0.0005
# p(robber|the)=0.0010
# p(wound|the)=0.0029
# p(order|the)=0.0005
# p(famous|the)=0.0005
# p(mud|the)=0.0005
# p(street|the)=0.0024
# p(clear-thinking|the)=0.0005
# p(samanas|the)=0.0137
# p(flying|the)=0.0005
# p(distant|the)=0.0005
# p(shade|the)=0.0034
# p(current|the)=0.0015
# p(sea|the)=0.0015
# p(road|the)=0.0005
# p(fragrant|the)=0.0005
# p(smell|the)=0.0005
# p(fair|the)=0.0005
# p(custom|the)=0.0010
# p(strange|the)=0.0005
# p(process|the)=0.0010
# p(quiet|the)=0.0005
# p(forehead|the)=0.0010
# p(worshipped|the)=0.0005
# p(uniformity|the)=0.0005
# p(rice-cake|the)=0.0005
# p(meditation|the)=0.0005
# p(examples|the)=0.0005
# p(exalted|the)=0.0147
# p(curious|the)=0.0010
# p(art|the)=0.0024
# p(others|the)=0.0015
# p(bedroom|the)=0.0005
# p(sleeping|the)=0.0005
# p(town|the)=0.0029
# p(banks|the)=0.0015
# p(friend|the)=0.0020
# p(dealers|the)=0.0005
# p(awoken|the)=0.0005
# p(vessel|the)=0.0005
# p(pursuer|the)=0.0005
# p(repetitions|the)=0.0005
# p(chamber|the)=0.0024
# p(animals|the)=0.0005
# p(many|the)=0.0020
# p(net|the)=0.0005
# p(woman|the)=0.0034
# p(axe|the)=0.0010
# p(eleven-year-old|the)=0.0005
# p(sacrificial|the)=0.0005
# p(heron|the)=0.0010
# p(game|the)=0.0029
# p(meal|the)=0.0005
# p(learned|the)=0.0024
# p(need|the)=0.0005
# p(style|the)=0.0005
# p(fact|the)=0.0010
# p(devil|the)=0.0005
# p(less|the)=0.0005
# p(son|the)=0.0034
# p(four|the)=0.0005
# p(hearts|the)=0.0005
# p(ruins|the)=0.0005
# p(the|pursued)=1.0000
# p(to|home)=0.1250
# p(and|home)=0.3125
# p(at|home)=0.0625
# p(,|home)=0.3125
# p(in|home)=0.0625
# p(nowhere|home)=0.0625
# p(.|home)=0.0625
# p(--|worship.)=1.0000
# p(of|celebration)=1.0000
# p(:|settled)=1.0000
# p(.|feathers)=1.0000
# p(not|seemed)=0.0333
# p(to|seemed)=0.8000
# p(like|seemed)=0.0333
# p(indeed|seemed)=0.0333
# p(,|seemed)=0.0333
# p(near|seemed)=0.0333
# p(tall|seemed)=0.0333
# p(he|isn't)=1.0000
# p(were|offerings)=0.0667
# p(to|offerings)=0.2667
# p(?|offerings)=0.0667
# p(for|offerings)=0.0667
# p(,|offerings)=0.2667
# p(.|offerings)=0.2000
# p(;|offerings)=0.0667
# p(at|despised)=0.5000
# p(.|despised)=0.5000
# p(business|landlords)=1.0000
# p(,|dust)=0.2857
# p(was|dust)=0.1429
# p(.|dust)=0.2857
# p(of|dust)=0.1429
# p(in|dust)=0.1429
# p(in|partaking)=1.0000
# p(the|show)=0.2500
# p(his|show)=0.2500
# p(him|show)=0.2500
# p(threadbare|show)=0.2500
# p(,|treasures)=1.0000
# p(embarrassing|most)=0.0270
# p(forlorn|most)=0.0270
# p(and|most)=0.0270
# p(people|most)=0.0811
# p(easily|most)=0.0270
# p(extreme|most)=0.0270
# p(base|most)=0.0270
# p(was|most)=0.0270
# p(holy|most)=0.0270
# p(important|most)=0.0811
# p(shameful|most)=0.0270
# p(intimate|most)=0.0270
# p(venerable|most)=0.0811
# p(hurriedly|most)=0.0270
# p(suitable|most)=0.0270
# p(beautiful|most)=0.0541
# p(as|most)=0.0270
# p(,|most)=0.0270
# p(foolish|most)=0.0541
# p(wretched|most)=0.0270
# p(of|most)=0.1892
# p(quickly|most)=0.0541
# p(,|knees)=0.6667
# p(.|knees)=0.3333
# p(and|seventy)=0.5000
# p(years|seventy)=0.5000
# p(like|flexible)=1.0000
# p(in|criminal)=1.0000
# p(by|,)=0.0027
# p(nobody|,)=0.0006
# p(surrounded|,)=0.0006
# p(destroying|,)=0.0002
# p(good|,)=0.0004
# p(felt|,)=0.0025
# p(kindly|,)=0.0002
# p(treasure|,)=0.0002
# p(let's|,)=0.0002
# p(cheerfulness|,)=0.0002
# p(rare|,)=0.0002
# p(is|,)=0.0034
# p(wore|,)=0.0004
# p(differently|,)=0.0004
# p(shouts|,)=0.0002
# p(anybody|,)=0.0002
# p(lay|,)=0.0002
# p(scorned|,)=0.0004
# p(desiring|,)=0.0002
# p(quietly|,)=0.0002
# p(practising|,)=0.0004
# p(the|,)=0.0545
# p(wasted|,)=0.0004
# p(standing|,)=0.0002
# p(ablutions|,)=0.0002
# p(these|,)=0.0017
# p(embraced|,)=0.0006
# p(magic|,)=0.0002
# p(from|,)=0.0042
# p(fleeing|,)=0.0004
# p(breathed|,)=0.0008
# p(loses|,)=0.0004
# p(offerings|,)=0.0002
# p(wise|,)=0.0004
# p(most|,)=0.0002
# p(roundness|,)=0.0002
# p(wisdom|,)=0.0002
# p(into|,)=0.0027
# p(struck|,)=0.0002
# p(he|,)=0.0627
# p(follow|,)=0.0002
# p(fuming|,)=0.0002
# p(shines|,)=0.0004
# p(leave|,)=0.0002
# p(remember|,)=0.0002
# p(give|,)=0.0004
# p(could|,)=0.0011
# p(satisfy|,)=0.0002
# p(life|,)=0.0004
# p(thus|,)=0.0057
# p(given|,)=0.0004
# p(another|,)=0.0002
# p(torn|,)=0.0002
# p(resting|,)=0.0002
# p(awaited|,)=0.0004
# p(hating|,)=0.0004
# p(took|,)=0.0011
# p(became|,)=0.0013
# p(practised|,)=0.0004
# p(remembered|,)=0.0002
# p(consented|,)=0.0002
# p(headed|,)=0.0004
# p(chiefly|,)=0.0002
# p(decayed|,)=0.0002
# p(taught|,)=0.0008
# p(teaching|,)=0.0002
# p(bid|,)=0.0002
# p(clouds|,)=0.0002
# p(wo|,)=0.0006
# p(and|,)=0.0785
# p(therefore|,)=0.0004
# p(sacrificing|,)=0.0002
# p(only|,)=0.0027
# p(''|,)=0.0186
# p(thousand-fold|,)=0.0002
# p(intent|,)=0.0002
# p(death|,)=0.0002
# p(noon|,)=0.0002
# p(touched|,)=0.0002
# p(listen|,)=0.0004
# p(tortured|,)=0.0002
# p(listening|,)=0.0008
# p(feed|,)=0.0002
# p(siddhartha|,)=0.0215
# p(everywhere|,)=0.0004
# p(listened|,)=0.0015
# p(buddha|,)=0.0002
# p(unsown|,)=0.0002
# p(longing|,)=0.0002
# p(vasudeva|,)=0.0034
# p(close|,)=0.0002
# p(myself|,)=0.0004
# p(forgive|,)=0.0002
# p(childlike|,)=0.0004
# p(exhaled|,)=0.0002
# p(of|,)=0.0122
# p(perhaps|,)=0.0027
# p(live|,)=0.0004
# p(also|,)=0.0004
# p(young|,)=0.0002
# p(buying|,)=0.0002
# p(threw|,)=0.0002
# p(spices|,)=0.0002
# p(inside|,)=0.0002
# p(subdued|,)=0.0002
# p(instead|,)=0.0002
# p(sought|,)=0.0004
# p(sitting|,)=0.0004
# p(wondrous|,)=0.0002
# p(black|,)=0.0002
# p(naked|,)=0.0004
# p(once|,)=0.0015
# p(stole|,)=0.0002
# p(completely|,)=0.0008
# p(shaggy|,)=0.0002
# p(beautifully|,)=0.0002
# p(feeling|,)=0.0002
# p(overcame|,)=0.0002
# p(so|,)=0.0074
# p(blood|,)=0.0002
# p(realized|,)=0.0002
# p(near|,)=0.0004
# p(govinda|,)=0.0080
# p(year|,)=0.0006
# p(calm|,)=0.0002
# p(bright|,)=0.0002
# p(searching|,)=0.0006
# p(suddenly|,)=0.0002
# p(sparkling|,)=0.0002
# p(got|,)=0.0004
# p(permit|,)=0.0002
# p(ready|,)=0.0002
# p(up|,)=0.0006
# p(joyful|,)=0.0002
# p(floated|,)=0.0002
# p(mild|,)=0.0002
# p(entered|,)=0.0002
# p(read|,)=0.0011
# p(leaving|,)=0.0002
# p(ascetics|,)=0.0002
# p(money|,)=0.0004
# p(seem|,)=0.0002
# p(mourning|,)=0.0002
# p(holding|,)=0.0002
# p(void|,)=0.0002
# p(love|,)=0.0004
# p(dull|,)=0.0004
# p(tell|,)=0.0002
# p(locked|,)=0.0002
# p(pursued|,)=0.0002
# p(charming|,)=0.0002
# p(rejected|,)=0.0004
# p(know|,)=0.0002
# p(knowledge|,)=0.0002
# p(speaking|,)=0.0002
# p(greedy|,)=0.0002
# p(since|,)=0.0019
# p(something|,)=0.0027
# p(are|,)=0.0017
# p(several|,)=0.0002
# p(stream|,)=0.0002
# p(turned|,)=0.0017
# p(enticed|,)=0.0002
# p(blind|,)=0.0002
# p(closed|,)=0.0002
# p(friendly|,)=0.0004
# p(fell|,)=0.0002
# p(suffering|,)=0.0011
# p(patiently|,)=0.0002
# p(will|,)=0.0013
# p(soon|,)=0.0002
# p(those|,)=0.0004
# p(animals|,)=0.0002
# p(him|,)=0.0002
# p(thousands|,)=0.0002
# p(forced|,)=0.0006
# p(tolerance|,)=0.0002
# p(looked|,)=0.0011
# p(beautiful|,)=0.0008
# p(patient|,)=0.0002
# p(talking|,)=0.0002
# p(cautious|,)=0.0002
# p(longingly|,)=0.0006
# p(have|,)=0.0032
# p(allowed|,)=0.0002
# p(down|,)=0.0002
# p(mourners|,)=0.0002
# p(physicians|,)=0.0002
# p(isn't|,)=0.0002
# p(at|,)=0.0036
# p(clearer|,)=0.0002
# p(distorted|,)=0.0002
# p(heard|,)=0.0002
# p(repeated|,)=0.0002
# p(much|,)=0.0002
# p(strongly|,)=0.0004
# p(laughing|,)=0.0002
# p(moonlight|,)=0.0002
# p(wind|,)=0.0002
# p(unrelenting|,)=0.0002
# p(who|,)=0.0112
# p(no|,)=0.0040
# p(rose|,)=0.0002
# p(disappointment|,)=0.0002
# p(washing|,)=0.0002
# p(beating|,)=0.0002
# p(making|,)=0.0002
# p(want|,)=0.0006
# p(opened|,)=0.0006
# p(continue|,)=0.0002
# p(accustomed|,)=0.0006
# p(vain|,)=0.0002
# p(performing|,)=0.0002
# p(flew|,)=0.0002
# p(modestly|,)=0.0002
# p(small|,)=0.0002
# p(thoroughly|,)=0.0002
# p(farewell|,)=0.0004
# p(ignorant|,)=0.0002
# p(woven|,)=0.0002
# p(were|,)=0.0013
# p(watched|,)=0.0002
# p(eternal|,)=0.0002
# p(until|,)=0.0034
# p(tall|,)=0.0002
# p(while|,)=0.0019
# p(kind|,)=0.0002
# p(bearing|,)=0.0006
# p(had|,)=0.0097
# p(travelling|,)=0.0004
# p(glowing|,)=0.0004
# p(often|,)=0.0006
# p(lukewarm|,)=0.0002
# p(hut|,)=0.0002
# p(motionless|,)=0.0002
# p(flowing|,)=0.0002
# p(committed|,)=0.0002
# p(old|,)=0.0002
# p(has|,)=0.0006
# p(sat|,)=0.0011
# p(divine|,)=0.0002
# p(returned|,)=0.0004
# p(every|,)=0.0034
# p(anything|,)=0.0002
# p(four|,)=0.0002
# p(that|,)=0.0186
# p(wild|,)=0.0002
# p(secret|,)=0.0002
# p(staying|,)=0.0002
# p(said|,)=0.0006
# p(lured|,)=0.0002
# p(then|,)=0.0036
# p(prohibited|,)=0.0002
# p(deeply|,)=0.0002
# p(youth|,)=0.0002
# p(repulsive|,)=0.0002
# p('ere|,)=0.0002
# p(thirst|,)=0.0002
# p(entangled|,)=0.0002
# p(his|,)=0.0141
# p(let|,)=0.0025
# p(my|,)=0.0125
# p(may|,)=0.0004
# p(somewhat|,)=0.0002
# p(pondering|,)=0.0002
# p(smiling|,)=0.0004
# p(plucked|,)=0.0002
# p(always|,)=0.0027
# p(together|,)=0.0002
# p(entirely|,)=0.0002
# p(women|,)=0.0002
# p(hunger|,)=0.0002
# p(generated|,)=0.0002
# p(understanding|,)=0.0002
# p(herbs|,)=0.0002
# p(performed|,)=0.0002
# p(upward|,)=0.0002
# p(many|,)=0.0040
# p(went|,)=0.0006
# p(waited|,)=0.0004
# p(delude|,)=0.0002
# p(suffered|,)=0.0006
# p(wonderful|,)=0.0002
# p(timidness|,)=0.0002
# p(stupid|,)=0.0002
# p(heading|,)=0.0002
# p(actually|,)=0.0002
# p(servants|,)=0.0002
# p(smart|,)=0.0006
# p(whores|,)=0.0002
# p(confessed|,)=0.0002
# p(wherever|,)=0.0002
# p(late|,)=0.0002
# p(our|,)=0.0002
# p(weighed|,)=0.0002
# p(prayer|,)=0.0002
# p(lovely|,)=0.0002
# p(sloth|,)=0.0002
# p(nit|,)=0.0002
# p(on|,)=0.0023
# p(out|,)=0.0013
# p(put|,)=0.0002
# p(destined|,)=0.0002
# p(open|,)=0.0002
# p(goal|,)=0.0002
# p(bashful|,)=0.0002
# p(about|,)=0.0004
# p(well|,)=0.0004
# p(everyone|,)=0.0011
# p(precisely|,)=0.0004
# p(gray|,)=0.0002
# p(filled|,)=0.0017
# p(how|,)=0.0059
# p(flowed|,)=0.0004
# p(unexpressable|,)=0.0002
# p(deceptive|,)=0.0002
# p(floating|,)=0.0002
# p(strive|,)=0.0002
# p(already|,)=0.0006
# p(seems|,)=0.0002
# p(after|,)=0.0023
# p(welcome|,)=0.0004
# p(bent|,)=0.0002
# p(though|,)=0.0030
# p(being|,)=0.0030
# p(none|,)=0.0002
# p(impenetrable|,)=0.0002
# p(renounced|,)=0.0006
# p(brahman|,)=0.0002
# p(just|,)=0.0040
# p(presenting|,)=0.0002
# p(whether|,)=0.0015
# p(flash|,)=0.0002
# p(pulled|,)=0.0002
# p(carrying|,)=0.0004
# p(foolish|,)=0.0006
# p(leaned|,)=0.0002
# p(grabbed|,)=0.0002
# p(over|,)=0.0004
# p(belonging|,)=0.0002
# p(attentively|,)=0.0002
# p(desperate|,)=0.0002
# p(perceived|,)=0.0002
# p(kamaswami|,)=0.0006
# p(ashamed|,)=0.0002
# p(commanded|,)=0.0002
# p(lost|,)=0.0021
# p(previous|,)=0.0002
# p(particularly|,)=0.0002
# p(thumped|,)=0.0002
# p(really|,)=0.0006
# p(stopped|,)=0.0002
# p(losing|,)=0.0002
# p(still|,)=0.0008
# p(touching|,)=0.0002
# p(both|,)=0.0013
# p(pampered|,)=0.0002
# p(told|,)=0.0002
# p(pride|,)=0.0002
# p(bracelets|,)=0.0002
# p(received|,)=0.0004
# p(where|,)=0.0063
# p(too|,)=0.0006
# p(people|,)=0.0004
# p(saw|,)=0.0046
# p(few|,)=0.0008
# p(dressed|,)=0.0002
# p(easy|,)=0.0002
# p(now|,)=0.0019
# p(was|,)=0.0118
# p(picked|,)=0.0004
# p(desired|,)=0.0006
# p(its|,)=0.0002
# p(teachings|,)=0.0002
# p(clemency|,)=0.0002
# p(someone|,)=0.0004
# p(melting|,)=0.0002
# p(wearing|,)=0.0006
# p(expressed|,)=0.0004
# p(disembarking|,)=0.0002
# p(oneness|,)=0.0004
# p(toilsome|,)=0.0002
# p(very|,)=0.0011
# p(bustling|,)=0.0002
# p(warriors|,)=0.0002
# p(again|,)=0.0008
# p(stars|,)=0.0004
# p(some|,)=0.0006
# p(according|,)=0.0004
# p(you're|,)=0.0002
# p(red|,)=0.0002
# p(am|,)=0.0002
# p(content|,)=0.0002
# p(greeting|,)=0.0004
# p(gave|,)=0.0008
# p(possibly|,)=0.0004
# p(to|,)=0.0220
# p(colourful|,)=0.0002
# p(conducting|,)=0.0002
# p(here|,)=0.0017
# p(proud|,)=0.0002
# p(supple|,)=0.0002
# p(despicable|,)=0.0002
# p(unmoved|,)=0.0002
# p(nor|,)=0.0017
# p(knowing|,)=0.0002
# p(wrapped|,)=0.0004
# p(do|,)=0.0023
# p(or|,)=0.0034
# p(understand|,)=0.0002
# p(within|,)=0.0002
# p(even|,)=0.0030
# p(but|,)=0.0150
# p(finds|,)=0.0002
# p(cold|,)=0.0002
# p(tiredness|,)=0.0011
# p(words|,)=0.0002
# p(deceitful|,)=0.0002
# p(believed|,)=0.0002
# p(short|,)=0.0002
# p(inescapable|,)=0.0002
# p(giving|,)=0.0002
# p(food|,)=0.0002
# p(quiet|,)=0.0013
# p(shared|,)=0.0002
# p(between|,)=0.0004
# p(beloved|,)=0.0002
# p(because|,)=0.0034
# p(twice|,)=0.0002
# p(showed|,)=0.0004
# p(dark|,)=0.0002
# p(smoothly|,)=0.0002
# p(won|,)=0.0004
# p(in|,)=0.0188
# p(one|,)=0.0017
# p(when|,)=0.0139
# p(with|,)=0.0110
# p(having|,)=0.0006
# p(strong|,)=0.0002
# p(consisted|,)=0.0002
# p(princes|,)=0.0002
# p(walked|,)=0.0006
# p(sucked|,)=0.0002
# p(i|,)=0.0287
# p(clenched|,)=0.0002
# p(slowly|,)=0.0011
# p(businessmen|,)=0.0002
# p(undertook|,)=0.0002
# p(piled|,)=0.0002
# p(lamentingly|,)=0.0002
# p(rainbows|,)=0.0002
# p(full|,)=0.0030
# p(empty|,)=0.0008
# p(possessions|,)=0.0002
# p(mortal|,)=0.0006
# p(tried|,)=0.0002
# p(regarding|,)=0.0002
# p(indestructible|,)=0.0002
# p(her|,)=0.0013
# p(clothes|,)=0.0002
# p(look|,)=0.0002
# p(as|,)=0.0093
# p(followers|,)=0.0002
# p(tiny|,)=0.0002
# p(devoted|,)=0.0002
# p(clear|,)=0.0002
# p(driven|,)=0.0002
# p(strangers|,)=0.0004
# p(might|,)=0.0002
# p(drinking|,)=0.0002
# p(pure|,)=0.0004
# p(envied|,)=0.0002
# p(sir|,)=0.0019
# p(tired|,)=0.0004
# p(shipping|,)=0.0002
# p(lovers|,)=0.0002
# p(devoured|,)=0.0002
# p(withered|,)=0.0004
# p(find|,)=0.0002
# p(farmers|,)=0.0002
# p(incessantly|,)=0.0002
# p(--|,)=0.0004
# p(hours|,)=0.0002
# p(growing|,)=0.0006
# p(insensitivity|,)=0.0002
# p(comforting|,)=0.0002
# p(be|,)=0.0002
# p(nothing|,)=0.0023
# p(offered|,)=0.0002
# p(begging|,)=0.0002
# p(aside|,)=0.0002
# p(drifted|,)=0.0004
# p(sometimes|,)=0.0002
# p(sweetly|,)=0.0002
# p(birthplace|,)=0.0002
# p(beginning|,)=0.0004
# p(pretty|,)=0.0004
# p(lamented|,)=0.0002
# p(laborious|,)=0.0004
# p(carried|,)=0.0004
# p(letter|,)=0.0002
# p(stems|,)=0.0002
# p(brought|,)=0.0002
# p(there|,)=0.0065
# p(scorched|,)=0.0002
# p(others|,)=0.0002
# p(singing|,)=0.0002
# p(compare|,)=0.0002
# p(fiery|,)=0.0002
# p(your|,)=0.0011
# p(fleeting|,)=0.0002
# p(frightened|,)=0.0002
# p(paralysed|,)=0.0002
# p(sensing|,)=0.0002
# p(under|,)=0.0004
# p(breathing|,)=0.0002
# p(their|,)=0.0006
# p(stepped|,)=0.0004
# p(dreams|,)=0.0002
# p(brushed|,)=0.0002
# p(you|,)=0.0114
# p(joy|,)=0.0002
# p(seeing|,)=0.0008
# p(fear|,)=0.0004
# p(soft|,)=0.0002
# p(almost|,)=0.0006
# p(alone|,)=0.0002
# p(vomits|,)=0.0002
# p(towards|,)=0.0004
# p(silently|,)=0.0002
# p(loving|,)=0.0004
# p(whenever|,)=0.0008
# p(thinking|,)=0.0017
# p(this|,)=0.0158
# p(brown|,)=0.0002
# p(we|,)=0.0019
# p(among|,)=0.0013
# p(neither|,)=0.0015
# p(insight|,)=0.0002
# p(delicate|,)=0.0004
# p(samana|,)=0.0013
# p(watching|,)=0.0002
# p(poisoned|,)=0.0002
# p(called|,)=0.0004
# p(walking|,)=0.0006
# p(painful|,)=0.0002
# p(shoes|,)=0.0004
# p(thirsty|,)=0.0002
# p(would|,)=0.0019
# p(fine|,)=0.0004
# p(eager|,)=0.0002
# p(monks|,)=0.0004
# p(like|,)=0.0036
# p(vanity|,)=0.0002
# p(tending|,)=0.0002
# p(stood|,)=0.0004
# p(whatever|,)=0.0002
# p(rocks|,)=0.0002
# p(lonely|,)=0.0006
# p(ran|,)=0.0006
# p(high|,)=0.0002
# p(than|,)=0.0013
# p(drop|,)=0.0004
# p(vacuous|,)=0.0002
# p(brightly|,)=0.0002
# p(miracles|,)=0.0002
# p(mumbling|,)=0.0002
# p(nurtured|,)=0.0002
# p(made|,)=0.0013
# p(except|,)=0.0011
# p(waiting|,)=0.0004
# p(handsome|,)=0.0002
# p(worries|,)=0.0002
# p(impetuously|,)=0.0002
# p(experienced|,)=0.0002
# p(through|,)=0.0021
# p(stank|,)=0.0002
# p(sympathy|,)=0.0002
# p(subject|,)=0.0002
# p(better|,)=0.0002
# p(laughed|,)=0.0002
# p(all|,)=0.0076
# p(sansara|,)=0.0002
# p(such|,)=0.0004
# p(whom|,)=0.0008
# p(they|,)=0.0065
# p(whose|,)=0.0019
# p(left|,)=0.0002
# p(before|,)=0.0013
# p(rested|,)=0.0002
# p(wouldn't|,)=0.0002
# p(sadly|,)=0.0002
# p(shook|,)=0.0002
# p(receiving|,)=0.0004
# p(sin|,)=0.0002
# p(screamed|,)=0.0002
# p(unstoppable|,)=0.0002
# p(looking|,)=0.0006
# p(today|,)=0.0004
# p(stronger|,)=0.0004
# p(smiled|,)=0.0004
# p(chatted|,)=0.0002
# p(if|,)=0.0036
# p(spoke|,)=0.0017
# p(worthless|,)=0.0002
# p(place|,)=0.0002
# p(kneeling|,)=0.0002
# p(you've|,)=0.0002
# p(enriched|,)=0.0002
# p(shuddering|,)=0.0002
# p(met|,)=0.0002
# p(priests|,)=0.0002
# p(flowers|,)=0.0002
# p(pleasures|,)=0.0002
# p(coincidence|,)=0.0002
# p(think|,)=0.0002
# p(water|,)=0.0002
# p(eyebrows|,)=0.0002
# p(covetousness|,)=0.0002
# p(came|,)=0.0006
# p(asked|,)=0.0006
# p(fasting|,)=0.0004
# p(thought|,)=0.0011
# p(without|,)=0.0065
# p(greedily|,)=0.0002
# p(sun|,)=0.0002
# p(finding|,)=0.0002
# p(gotama|,)=0.0006
# p(ten|,)=0.0002
# p(lived|,)=0.0004
# p(a|,)=0.0211
# p(kamala|,)=0.0034
# p(strangely|,)=0.0002
# p(occasionally|,)=0.0002
# p(bring|,)=0.0006
# p(mothers|,)=0.0002
# p(crafts|,)=0.0002
# p(placed|,)=0.0002
# p(filling|,)=0.0002
# p(desires|,)=0.0002
# p(admonition|,)=0.0002
# p(wants|,)=0.0002
# p(led|,)=0.0004
# p(gathered|,)=0.0002
# p(river|,)=0.0006
# p(more|,)=0.0023
# p(getting|,)=0.0002
# p(lasted|,)=0.0002
# p(silent|,)=0.0002
# p(deep|,)=0.0002
# p(bowed|,)=0.0004
# p(voices|,)=0.0002
# p(regarded|,)=0.0002
# p(three|,)=0.0002
# p(certain|,)=0.0002
# p(not|,)=0.0072
# p(gets|,)=0.0008
# p(oh|,)=0.0118
# p(sit|,)=0.0004
# p(it|,)=0.0106
# p(come|,)=0.0002
# p(dear|,)=0.0002
# p(yet|,)=0.0002
# p(purer|,)=0.0002
# p(petted|,)=0.0002
# p(samanas|,)=0.0002
# p(yes|,)=0.0008
# p(distant|,)=0.0002
# p(shade|,)=0.0002
# p(an|,)=0.0019
# p(infinitely|,)=0.0006
# p(biting|,)=0.0002
# p(created|,)=0.0002
# p(strange|,)=0.0002
# p(lose|,)=0.0002
# p(knew|,)=0.0011
# p(each|,)=0.0017
# p(taking|,)=0.0002
# p(found|,)=0.0006
# p(faithfulness|,)=0.0002
# p(upriver|,)=0.0002
# p(started|,)=0.0006
# p(birds|,)=0.0002
# p(accept|,)=0.0002
# p(treated|,)=0.0002
# p(drawn|,)=0.0002
# p(joined|,)=0.0002
# p(however|,)=0.0002
# p(move|,)=0.0002
# p(never|,)=0.0013
# p(foamed|,)=0.0002
# p(friend|,)=0.0008
# p(ferryman|,)=0.0006
# p(children|,)=0.0004
# p(``|,)=0.0093
# p(which|,)=0.0209
# p(err|,)=0.0002
# p(real|,)=0.0002
# p(far|,)=0.0002
# p(ate|,)=0.0004
# p(stayed|,)=0.0008
# p(everything|,)=0.0032
# p(wiggling|,)=0.0002
# p(obeyed|,)=0.0002
# p(she|,)=0.0055
# p(shall|,)=0.0002
# p(starting|,)=0.0004
# p(paced|,)=0.0004
# p(burden|,)=0.0002
# p(died|,)=0.0002
# p(hesitantly|,)=0.0002
# p(dwell|,)=0.0002
# p(for|,)=0.0089
# p(deprived|,)=0.0002
# p(learned|,)=0.0017
# p(striving|,)=0.0002
# p(what|,)=0.0046
# p(worshipped|,)=0.0002
# p(comb|,)=0.0002
# p(shine|,)=0.0002
# p(long|,)=0.0004
# p(less|,)=0.0004
# p(willing|,)=0.0002
# p(son|,)=0.0002
# p(mocking|,)=0.0002
# p(did|,)=0.0032
# p(answering|,)=0.0002
# p(glistened|,)=0.0002
# p(and|pumpkin)=1.0000
# p(his|presented)=0.5000
# p(so|presented)=0.5000
# p(leaf|falling)=0.3333
# p(leaves|falling)=0.6667
# p(,|swiftly)=0.2500
# p(along|swiftly)=0.2500
# p(and|swiftly)=0.2500
# p(away|swiftly)=0.2500
# p(,|sleeping)=0.2857
# p(.|sleeping)=0.1429
# p(man|sleeping)=0.2857
# p(in|sleeping)=0.2857
# p('s|oarsman)=1.0000
# p(thinking|unlearn)=1.0000
# p(not|could)=0.2632
# p(turn|could)=0.0175
# p(tell|could)=0.0175
# p(n't|could)=0.0351
# p(remember|could)=0.0175
# p(kidnap|could)=0.0175
# p(give|could)=0.0175
# p(only|could)=0.0351
# p(no|could)=0.0175
# p(do|could)=0.0175
# p(approve|could)=0.0175
# p(teach|could)=0.0175
# p(have|could)=0.1053
# p(also|could)=0.0175
# p(love|could)=0.0175
# p(you|could)=0.1053
# p(never|could)=0.0175
# p(demonstrate|could)=0.0175
# p(bring|could)=0.0175
# p(i|could)=0.0351
# p(win|could)=0.0175
# p(be|could)=0.0526
# p(accept|could)=0.0175
# p(it|could)=0.0175
# p(escape|could)=0.0175
# p(he|could)=0.0175
# p(force|could)=0.0175
# p(hurt|could)=0.0175
# p(in|daily)=0.3333
# p(,|daily)=0.6667
# p(joy|prohibited)=1.0000
# p(and|careful)=1.0000
# p(,|seems)=0.1250
# p(to|seems)=0.8750
# p(his|annihilating)=1.0000
# p(of|boasted)=1.0000
# p(against|insensitivity)=1.0000
# p(.|sneak)=1.0000
# p(up|rolled)=1.0000
# p(voice|slurred)=1.0000
# p(himself|hating)=0.5000
# p(it|hating)=0.5000
# p(diversity|coincidental)=0.5000
# p(and|coincidental)=0.5000
# p(the|see)=0.1351
# p(that|see)=0.1081
# p(his|see)=0.0270
# p(:|see)=0.0811
# p(such|see)=0.0270
# p(what|see)=0.0270
# p(everything|see)=0.0270
# p(worth|see)=0.0270
# p(all|see)=0.0270
# p(how|see)=0.0270
# p(is|see)=0.0270
# p(it|see)=0.0270
# p(,|see)=0.1351
# p(him|see)=0.0811
# p(whatever|see)=0.0270
# p(you|see)=0.1622
# p(.|see)=0.0270
# p(old|becomes)=0.1667
# p(one|becomes)=0.1667
# p(a|becomes)=0.3333
# p(morning|becomes)=0.1667
# p(void|becomes)=0.1667
# p(scared|became)=0.0400
# p(lovable|became)=0.0400
# p(motionless|became)=0.0400
# p(disobedient|became)=0.0400
# p(confused|became)=0.0400
# p(her|became)=0.0400
# p(unbearable|became)=0.0400
# p(aware|became)=0.2400
# p(embarrassed|became)=0.0400
# p(angry|became)=0.0800
# p(mute|became)=0.0400
# p(almost|became)=0.0400
# p(understandable|became)=0.0400
# p(,|became)=0.0400
# p(calm|became)=0.0400
# p(to|became)=0.0400
# p(more|became)=0.0800
# p(worthy|became)=0.0400
# p(,|meantime)=1.0000
# p(by|upset)=1.0000
# p(that|consented)=1.0000
# p(up|caught)=0.3333
# p(sight|caught)=0.3333
# p(hold|caught)=0.3333
# p(of|confession)=0.5000
# p(into|confession)=0.5000
# p(up|waking)=1.0000
# p(had|vision)=1.0000
# p(by|threatened)=1.0000
# p(his|bid)=0.8571
# p(him|bid)=0.1429
# p(,|clouds)=1.0000
# p(for|teacher)=0.0556
# p(who|teacher)=0.0556
# p(.|teacher)=0.1111
# p(?|teacher)=0.0556
# p(teachings|teacher)=0.0556
# p(would|teacher)=0.0556
# p(,|teacher)=0.4444
# p(had|teacher)=0.0556
# p(;|teacher)=0.1111
# p(him|defeated)=0.3333
# p(as|defeated)=0.3333
# p(and|defeated)=0.3333
# p(out|throwing)=1.0000
# p(of|quietness)=1.0000
# p(in|sacrificing)=1.0000
# p(of|blow)=1.0000
# p(taking|eternally)=1.0000
# p(for|chore)=1.0000
# p(trading|merchants)=1.0000
# p(waters|perfumed)=0.5000
# p(hair|perfumed)=0.5000
# p(been|indeed)=0.0833
# p(like|indeed)=0.0833
# p(a|indeed)=0.0833
# p(have|indeed)=0.0833
# p(awakened|indeed)=0.0833
# p(,|indeed)=0.1667
# p(his|indeed)=0.0833
# p(.|indeed)=0.1667
# p(was|indeed)=0.0833
# p(no|indeed)=0.0833
# p(as|regard)=1.0000
# p(,|caste)=0.8000
# p(of|caste)=0.2000
# p(,|noon)=1.0000
# p(the|touched)=0.0909
# p(siddhartha|touched)=0.1818
# p(siddhartha's|touched)=0.0909
# p(his|touched)=0.2727
# p(a|touched)=0.0909
# p(with|touched)=0.0909
# p(hers|touched)=0.0909
# p(and|touched)=0.0909
# p(.|salutations)=1.0000
# p(shade|bluish)=1.0000
# p(one|pure)=0.2500
# p(as|pure)=0.2500
# p(teachings|pure)=0.2500
# p(his|pure)=0.2500
# p(.|expertise)=1.0000
# p(inscription|fearful)=0.3333
# p(but|fearful)=0.3333
# p(man|fearful)=0.3333
# p(after|hour)=0.0645
# p(the|hour)=0.0323
# p(appointed|hour)=0.0323
# p(or|hour)=0.0323
# p(he|hour)=0.0323
# p(,|hour)=0.4516
# p(sped|hour)=0.0323
# p(when|hour)=0.0645
# p(of|hour)=0.2258
# p(;|hour)=0.0323
# p(,|mean)=0.5000
# p(by|mean)=0.2500
# p(.|mean)=0.2500
# p(which|vice)=1.0000
# p(,|sight)=0.2500
# p(of|sight)=0.7500
# p(were|gods)=0.0625
# p(together|gods)=0.0625
# p(and|gods)=0.1250
# p(?|gods)=0.1250
# p(not|gods)=0.0625
# p(,|gods)=0.2500
# p(are|gods)=0.0625
# p(.|gods)=0.2500
# p(me|forgive)=1.0000
# p(lust|sensual)=1.0000
# p(,|business-affairs)=1.0000
# p(or|childlike)=0.0526
# p(face|childlike)=0.0526
# p(,|childlike)=0.0526
# p(people|childlike)=0.6316
# p(person|childlike)=0.1579
# p(.|childlike)=0.0526
# p(,|reside)=0.5000
# p(in|reside)=0.5000
# p(to|transmitted)=1.0000
# p(tiredness|flabby)=1.0000
# p(part|second)=0.2500
# p(,|second)=0.2500
# p(time|second)=0.2500
# p(or|second)=0.2500
# p(of|follower)=1.0000
# p(evil|avoid)=1.0000
# p(,|loyalty)=1.0000
# p(:|shoulder)=0.1429
# p(,|shoulder)=0.2857
# p(with|shoulder)=0.1429
# p(of|shoulder)=0.1429
# p(.|shoulder)=0.2857
# p(them|makes)=0.5000
# p(when|makes)=0.5000
# p(righteously|live)=0.0500
# p(for|live)=0.0500
# p(to|live)=0.1000
# p(by|live)=0.0500
# p(and|live)=0.0500
# p(?|live)=0.0500
# p(again|live)=0.0500
# p(instead|live)=0.0500
# p(it|live)=0.0500
# p(according|live)=0.0500
# p(in|live)=0.2000
# p(on|live)=0.0500
# p(,|live)=0.0500
# p(with|live)=0.0500
# p(of|live)=0.0500
# p(.|live)=0.0500
# p(across|blown)=0.5000
# p(and|blown)=0.5000
# p(,|bondage)=0.5000
# p(of|bondage)=0.5000
# p(,|buying)=0.5000
# p(bananas|buying)=0.5000
# p(the|smash)=1.0000
# p(;|confirmation)=1.0000
# p(by|gotama)=0.0227
# p(and|gotama)=0.0455
# p(for|gotama)=0.0227
# p('s|gotama)=0.1818
# p(walked|gotama)=0.0227
# p(had|gotama)=0.0227
# p(as|gotama)=0.0227
# p(:|gotama)=0.0227
# p(returning|gotama)=0.0227
# p(has|gotama)=0.0227
# p(looked|gotama)=0.0227
# p(,|gotama)=0.3636
# p(taught|gotama)=0.0227
# p(in|gotama)=0.0227
# p(was|gotama)=0.0227
# p(.|gotama)=0.0682
# p(spoke|gotama)=0.0227
# p(teaches|gotama)=0.0227
# p(accepted|gotama)=0.0227
# p(shelter|sought)=0.0909
# p(his|sought)=0.0909
# p(to|sought)=0.6364
# p(refuge|sought)=0.0909
# p(another|sought)=0.0909
# p(his|spreads)=1.0000
# p(,|wood)=1.0000
# p(away|slip)=1.0000
# p(,|shocked)=0.5000
# p(.|shocked)=0.5000
# p(from|stole)=1.0000
# p(up|heating)=1.0000
# p(gesture|noticeable)=1.0000
# p(.|eyelids)=1.0000
# p(he|instructions)=0.5000
# p(every|instructions)=0.5000
# p(,|beyond)=0.5000
# p(.|beyond)=0.5000
# p(,|permission)=0.3333
# p(to|permission)=0.6667
# p(him|attracts)=1.0000
# p(,|hospitality)=1.0000
# p(you|kidnap)=1.0000
# p(--|essential)=0.3333
# p(existence|essential)=0.3333
# p(properties|essential)=0.3333
# p(looking|worthwhile)=1.0000
# p(,|indignantly)=1.0000
# p(the|realized)=0.1000
# p(her|realized)=0.1000
# p(this|realized)=0.1000
# p(:|realized)=0.2000
# p(,|realized)=0.1000
# p(that|realized)=0.4000
# p(and|copper)=1.0000
# p(,|hopeless)=1.0000
# p(in|()=0.3333
# p(but|()=0.3333
# p(?|()=0.3333
# p(were|noble)=0.2500
# p(and|noble)=0.2500
# p(promises|noble)=0.2500
# p(thoughts|noble)=0.2500
# p(.|moods)=1.0000
# p(,|memory)=0.8000
# p(.|memory)=0.2000
# p(mind|rational)=1.0000
# p(,|warnings)=1.0000
# p(me|permit)=0.6667
# p(you|permit)=0.3333
# p(golden|wide)=0.3333
# p(road|wide)=0.3333
# p(water|wide)=0.3333
# p(the|up)=0.0423
# p(fear|up)=0.0141
# p(after|up)=0.0141
# p(to|up)=0.1831
# p(and|up)=0.0704
# p(garments|up)=0.0141
# p(again|up)=0.0563
# p(money|up)=0.0141
# p(disgust|up)=0.0141
# p(all|up)=0.0141
# p(or|up)=0.0282
# p(water|up)=0.0141
# p(,|up)=0.2817
# p(from|up)=0.0563
# p(in|up)=0.0704
# p(;|up)=0.0141
# p(.|up)=0.0282
# p(a|up)=0.0141
# p(with|up)=0.0563
# p(,|trade)=0.6000
# p(more|trade)=0.2000
# p(.|trade)=0.2000
# p(to|beginning)=0.1111
# p(and|beginning)=0.2222
# p(proudly|beginning)=0.1111
# p(,|beginning)=0.1111
# p(with|beginning)=0.1111
# p(of|beginning)=0.2222
# p(.|beginning)=0.1111
# p(him|provide)=1.0000
# p(day|suitable)=0.5000
# p(match|suitable)=0.5000
# p(the|read)=0.3333
# p(for|read)=0.0556
# p(and|read)=0.0556
# p(?|read)=0.0556
# p(:|read)=0.0556
# p(it|read)=0.0556
# p(out|read)=0.0556
# p(this|read)=0.0556
# p(in|read)=0.1111
# p(them|read)=0.0556
# p(,|read)=0.0556
# p(a|read)=0.0556
# p(unknown|previously)=1.0000
# p(for|money)=0.0333
# p(or|money)=0.0333
# p(to|money)=0.0667
# p(would|money)=0.0333
# p(and|money)=0.1000
# p(?|money)=0.0333
# p(,|money)=0.3667
# p(in|money)=0.1333
# p(.|money)=0.1333
# p(!|money)=0.0333
# p(with|money)=0.0333
# p(,|mourning)=0.3333
# p(for|mourning)=0.3333
# p(.|mourning)=0.3333
# p(.|splendid)=1.0000
# p(teacher|venerable)=0.0476
# p(samanas|venerable)=0.0476
# p(,|venerable)=0.0476
# p(teachings|venerable)=0.0476
# p(on|venerable)=0.0476
# p(brahmans|venerable)=0.0476
# p(one|venerable)=0.6667
# p(father|venerable)=0.0476
# p(whom|street-vendor)=1.0000
# p(,|anger)=1.0000
# p(me|tell)=0.3571
# p(the|tell)=0.0714
# p(her|tell)=0.1071
# p(this|tell)=0.0357
# p(him|tell)=0.1786
# p(us|tell)=0.0357
# p(you|tell)=0.1786
# p(.|tell)=0.0357
# p(on|stiff)=0.5000
# p(legs|stiff)=0.5000
# p(him|rejected)=1.0000
# p(,|eccentric)=1.0000
# p(the|reduce)=1.0000
# p(by|standing)=0.0952
# p(alone|standing)=0.0476
# p(at|standing)=0.0476
# p(there|standing)=0.2381
# p(here|standing)=0.0952
# p(behind|standing)=0.0476
# p(like|standing)=0.0476
# p(,|standing)=0.0952
# p(out|standing)=0.0476
# p(in|standing)=0.0952
# p(between|standing)=0.0952
# p(where|standing)=0.0476
# p(of|outside)=0.3333
# p(and|outside)=0.3333
# p(.|outside)=0.3333
# p(of|lands)=1.0000
# p(sky|starry)=1.0000
# p(and|world)=0.0882
# p(here|world)=0.0147
# p(has|world)=0.0147
# p(''|world)=0.0147
# p(gone|world)=0.0147
# p(in|world)=0.0147
# p(through|world)=0.0147
# p(was|world)=0.0294
# p(is|world)=0.0147
# p(melted|world)=0.0147
# p(for|world)=0.0294
# p(to|world)=0.0147
# p(like|world)=0.0147
# p(?|world)=0.0294
# p(tasted|world)=0.0147
# p(as|world)=0.0294
# p(i|world)=0.0294
# p(which|world)=0.0294
# p(!|world)=0.0147
# p(circling|world)=0.0147
# p(void|world)=0.0147
# p(itself|world)=0.0147
# p(,|world)=0.3088
# p(a|world)=0.0147
# p(.|world)=0.0735
# p(every|world)=0.0147
# p(of|world)=0.0882
# p(beyond|world)=0.0147
# p(!|free)=0.1250
# p(himself|free)=0.1250
# p(myself|free)=0.1250
# p(again|free)=0.1250
# p(,|free)=0.2500
# p(will|free)=0.2500
# p(second-|represented)=1.0000
# p(over|hovered)=1.0000
# p(.|nest)=1.0000
# p(and|entities)=1.0000
# p(reports|these)=0.0370
# p('times|these)=0.0185
# p(so|these)=0.0370
# p(and|these)=0.0185
# p(pleasures|these)=0.0185
# p(ugly|these)=0.0185
# p(people|these)=0.0926
# p(things|these)=0.0556
# p(most|these)=0.0185
# p(waters|these)=0.0185
# p(verses|these)=0.0370
# p(thoughts|these)=0.0370
# p(days|these)=0.0185
# p(many|these)=0.0370
# p(had|these)=0.0185
# p(beautiful|these)=0.0185
# p(there|these)=0.0185
# p(teachings|these)=0.0926
# p(which|these)=0.0185
# p(are|these)=0.0370
# p(words|these)=0.0370
# p(recent|these)=0.0370
# p(waves|these)=0.0185
# p(figures|these)=0.0370
# p(three|these)=0.0370
# p(urges|these)=0.0185
# p(simple|these)=0.0185
# p(,|these)=0.0556
# p(habits|these)=0.0185
# p(foolish|these)=0.0185
# p(wretched|these)=0.0185
# p(clothes|these)=0.0185
# p(,|tomorrow)=0.7143
# p(morning|tomorrow)=0.1429
# p(and|tomorrow)=0.1429
# p(the|voice)=0.0227
# p(and|voice)=0.0455
# p(said|voice)=0.0227
# p(without|voice)=0.0227
# p(,|voice)=0.2045
# p(would|voice)=0.0227
# p(if|voice)=0.0227
# p(when|voice)=0.0227
# p(.|voice)=0.0909
# p(commanded|voice)=0.0227
# p(hovered|voice)=0.0227
# p(inside|voice)=0.0227
# p(he|voice)=0.0227
# p(:|voice)=0.0455
# p(sang|voice)=0.0227
# p(talking|voice)=0.0227
# p(sounded|voice)=0.0455
# p(which|voice)=0.0227
# p(assumed|voice)=0.0227
# p(had|voice)=0.0682
# p(in|voice)=0.0682
# p(of|voice)=0.0909
# p(any|voice)=0.0227
# p(clothes|lack)=0.5000
# p(of|lack)=0.5000
# p(,|trying)=0.3333
# p(to|trying)=0.6667
# p(manner|animallike)=1.0000
# p(of|smelled)=1.0000
# p(for|suffering)=0.0227
# p(time|suffering)=0.0227
# p(nor|suffering)=0.0227
# p(and|suffering)=0.1364
# p(because|suffering)=0.0227
# p(a|suffering)=0.0227
# p(began|suffering)=0.0227
# p(,|suffering)=0.2955
# p(or|suffering)=0.0227
# p(had|suffering)=0.0227
# p(on|suffering)=0.0227
# p(was|suffering)=0.0682
# p(infinitely|suffering)=0.0227
# p(of|suffering)=0.0682
# p(.|suffering)=0.2045
# p(,|awakened)=0.3333
# p(as|awakened)=0.3333
# p(and|awakened)=0.3333
# p(he|patiently)=1.0000
# p(grew|nails)=1.0000
# p(,|positions)=0.3333
# p(and|positions)=0.6667
# p(urges|prevailing)=1.0000
# p(of|bowl)=1.0000
# p(dead|peacefully)=1.0000
# p(of|corners)=1.0000
# p(the|please)=0.1667
# p(not|please)=0.1667
# p(forgive|please)=0.1667
# p(my|please)=0.1667
# p(,|please)=0.1667
# p(you|please)=0.1667
# p(his|forced)=0.3750
# p(him|forced)=0.2500
# p(upon|forced)=0.1250
# p(himself|forced)=0.1250
# p(,|forced)=0.1250
# p(--|eyes)=0.0149
# p(stayed|eyes)=0.0149
# p(and|eyes)=0.1194
# p(with|eyes)=0.0149
# p(still|eyes)=0.0149
# p(beheld|eyes)=0.0149
# p(fixed|eyes)=0.0149
# p(quietly|eyes)=0.0149
# p(;|eyes)=0.0149
# p(see|eyes)=0.0149
# p(were|eyes)=0.0448
# p(to|eyes)=0.0149
# p(glistening|eyes)=0.0149
# p(?|eyes)=0.0149
# p(:|eyes)=0.0149
# p(became|eyes)=0.0299
# p(looked|eyes)=0.0149
# p(read|eyes)=0.0149
# p(smile|eyes)=0.0149
# p(today|eyes)=0.0149
# p(turned|eyes)=0.0149
# p(,|eyes)=0.3433
# p(have|eyes)=0.0149
# p(a|eyes)=0.0149
# p(.|eyes)=0.1343
# p(closed|eyes)=0.0299
# p(him|cling)=1.0000
# p(.|palm-trees)=1.0000
# p(?|upbringing)=1.0000
# p(that|realised)=1.0000
# p(,|talking)=0.4444
# p(to|talking)=0.3333
# p(about|talking)=0.1111
# p(.|talking)=0.1111
# p(this|dreamed)=1.0000
# p(for|fate)=0.1429
# p(had|fate)=0.1429
# p(,|fate)=0.2857
# p(of|fate)=0.1429
# p(is|fate)=0.1429
# p(with|fate)=0.1429
# ...
# p(suffering|all)=0.0159
# p(dying|all)=0.0053
# p(passions|all)=0.0053
# p(reached|all)=0.0053
# p(sobering|all)=0.0053
# p(those|all)=0.0106
# p(pleasure|all)=0.0053
# p(important|all)=0.0053
# p(joy|all)=0.0106
# p(alone|all)=0.0053
# p(teachings|all)=0.0053
# p(manifestations|all)=0.0053
# p(beautiful|all)=0.0053
# p(resistance|all)=0.0053
# p(i|all)=0.0265
# p(thinking|all)=0.0053
# p(this|all)=0.0476
# p(afraid|all)=0.0053
# p(have|all)=0.0053
# p(secrets|all)=0.0106
# p(of|all)=0.1799
# p(success|whom)=0.0714
# p(siddhartha|whom)=0.0714
# p(he|whom)=0.3571
# p(else|whom)=0.0714
# p(would|whom)=0.0714
# p(had|whom)=0.0714
# p(even|whom)=0.0714
# p(i|whom)=0.2143
# p(would|language)=0.3333
# p(.|language)=0.6667
# p(path|eightfold)=1.0000
# p(,|faces)=0.4000
# p(of|faces)=0.2000
# p(rested|faces)=0.2000
# p(in|faces)=0.2000
# p(your|choosing)=1.0000
# p(,|imitation)=1.0000
# p(,|invisibly)=1.0000
# p(worshipper|obedient)=1.0000
# p(--|brow)=0.5000
# p(,|brow)=0.5000
# p(in|screamed)=0.5000
# p(and|screamed)=0.5000
# p(character|changed)=0.1667
# p(and|changed)=0.1667
# p(a|changed)=0.1667
# p(their|changed)=0.1667
# p(as|changed)=0.1667
# p(.|changed)=0.1667
# p(fig|cracked)=1.0000
# p(in|skill)=1.0000
# p(neck|tall)=0.5000
# p(and|tall)=0.5000
# p(.|approval)=1.0000
# p(to|place)=0.2174
# p(where|place)=0.1739
# p(?|place)=0.0435
# p(there|place)=0.0435
# p(in|place)=0.0435
# p(,|place)=0.3478
# p(more|place)=0.0435
# p(he|place)=0.0435
# p(and|place)=0.0435
# p(and|kneeling)=1.0000
# p(by|enriched)=1.0000
# p()|.)=0.0063
# p(''|.)=0.9938
# p(by|solely)=0.6667
# p(important|solely)=0.3333
# p(,|breathes)=1.0000
# p(,|coincidence)=1.0000
# p(and|child-like)=1.0000
# p(siddhartha|bitterly)=1.0000
# p(himself|soiling)=1.0000
# p(you|recognising)=1.0000
# p(,|delusion)=1.0000
# p(,|manners)=1.0000
# p(the|identify)=1.0000
# p(giving|woman)=0.0435
# p(for|woman)=0.0435
# p(and|woman)=0.1304
# p(:|woman)=0.0870
# p('s|woman)=0.0870
# p(again|woman)=0.0435
# p(whom|woman)=0.0435
# p(does|woman)=0.0435
# p(before|woman)=0.0435
# p(on|woman)=0.0435
# p(,|woman)=0.2174
# p(was|woman)=0.0435
# p(with|woman)=0.0435
# p(.|woman)=0.0870
# p(the|perform)=0.5000
# p(,|perform)=0.2500
# p(magic|perform)=0.2500
# p(,|layers)=1.0000
# p(,|developing)=1.0000
# p(,|lunatic)=1.0000
# p(one|greeted)=0.1667
# p(him|greeted)=0.3333
# p(her|greeted)=0.1667
# p(you|greeted)=0.1667
# p(vasudeva|greeted)=0.1667
# p(oneself|tormenting)=0.5000
# p(yourself|tormenting)=0.5000
# p(.|whisper)=1.0000
# p(,|atharva-veda)=1.0000
# p(call|textbooks)=1.0000
# p(now|happier)=1.0000
# p(,|numbness)=1.0000
# p(with|viciousness)=1.0000
# p(,|property)=1.0000
# p(,|spot)=0.2000
# p(of|spot)=0.2000
# p(?|spot)=0.2000
# p(.|spot)=0.4000
# p(please|shall)=0.0500
# p(not|shall)=0.1000
# p(let|shall)=0.0500
# p(come|shall)=0.0500
# p(know|shall)=0.0500
# p(spent|shall)=0.0500
# p(all|shall)=0.0500
# p(be|shall)=0.1000
# p(become|shall)=0.0500
# p(live|shall)=0.0500
# p(also|shall)=0.1000
# p(i|shall)=0.0500
# p(reach|shall)=0.1000
# p(find|shall)=0.1000
# p(teach|shall)=0.0500
# p(said|disbelievers)=1.0000
# p(loudly|exclaimed)=0.1000
# p(lamentingly|exclaimed)=0.1000
# p(siddhartha|exclaimed)=0.1000
# p(:|exclaimed)=0.2000
# p(,|exclaimed)=0.1000
# p(kamala|exclaimed)=0.2000
# p(kamaswami|exclaimed)=0.1000
# p(.|exclaimed)=0.1000
# p(,|hurt)=0.5000
# p(you|hurt)=0.5000
# p(by|punished)=1.0000
# p(house|mother's)=1.0000
# p(in|reflected)=0.3333
# p(back|reflected)=0.3333
# p(face|reflected)=0.3333
# p(often|kamala)=0.0123
# p(knew|kamala)=0.0123
# p(kissed|kamala)=0.0123
# p(and|kamala)=0.0123
# p(herself|kamala)=0.0123
# p(owned|kamala)=0.0123
# p(interrupted|kamala)=0.0123
# p(exclaimed|kamala)=0.0123
# p(has|kamala)=0.0123
# p(smiled|kamala)=0.0123
# p(also|kamala)=0.0123
# p(was|kamala)=0.0370
# p(collapsed|kamala)=0.0123
# p(is|kamala)=0.0123
# p(.|kamala)=0.0864
# p(walking|kamala)=0.0123
# p(felt|kamala)=0.0123
# p(laughed|kamala)=0.0123
# p(never|kamala)=0.0123
# p(siddhartha|kamala)=0.0123
# p(listened|kamala)=0.0123
# p(:|kamala)=0.0123
# p(thanked|kamala)=0.0123
# p(pointed|kamala)=0.0123
# p(approached|kamala)=0.0123
# p('s|kamala)=0.1111
# p(loudly|kamala)=0.0123
# p(!|kamala)=0.0247
# p(returned|kamala)=0.0123
# p(had|kamala)=0.0741
# p(,|kamala)=0.3210
# p(a|kamala)=0.0123
# p(looked|kamala)=0.0247
# p(by|rest)=0.1111
# p(now|rest)=0.1111
# p(,|rest)=0.3333
# p(under|rest)=0.1111
# p(.|rest)=0.1111
# p(between|rest)=0.1111
# p(with|rest)=0.1111
# p(little|cared)=1.0000
# p(,|month)=1.0000
# p(the|handle)=1.0000
# p(awake|strangely)=0.3333
# p(well|strangely)=0.3333
# p(clear|strangely)=0.3333
# p(the|occasionally)=0.1667
# p(,|occasionally)=0.1667
# p(dreaming|occasionally)=0.1667
# p(that|occasionally)=0.3333
# p(they|occasionally)=0.1667
# p(of|workings)=1.0000
# p(nursing|mothers)=1.0000
# p(,|simultaneously)=0.5000
# p(and|simultaneously)=0.5000
# p(,|crafts)=1.0000
# p(,|breach)=1.0000
# p(,|fishes)=0.5000
# p(and|fishes)=0.5000
# p(his|placed)=0.7143
# p(him|placed)=0.1429
# p(two|placed)=0.1429
# p(its|discover)=1.0000
# p(disobedient|stubbornly)=1.0000
# p(are|followers)=0.2500
# p(of|followers)=0.7500
# p(the|because)=0.0769
# p(to|because)=0.0385
# p(he|because)=0.2692
# p(hunger|because)=0.0385
# p(we|because)=0.0385
# p(i|because)=0.0385
# p(suddenly|because)=0.0385
# p(it|because)=0.1154
# p(,|because)=0.0769
# p(salvation|because)=0.0385
# p(of|because)=0.1154
# p(you|because)=0.1154
# p(spoke|passenger)=1.0000
# p(him|cheat)=1.0000
# p(despair|bitter)=0.3333
# p(drink|bitter)=0.3333
# p(.|bitter)=0.3333
# p(for|gold)=1.0000
# p(and|embarrassment)=1.0000
# p(life|dreary)=0.5000
# p(and|dreary)=0.5000
# p(,|wool)=1.0000
# p(a|buy)=0.5000
# p(an|buy)=0.5000
# p(time|certain)=0.2500
# p(insights|certain)=0.2500
# p(contempt|certain)=0.2500
# p(thoughts|certain)=0.2500
# p(river|rushing)=0.2000
# p(along|rushing)=0.2000
# p(waters|rushing)=0.2000
# p(water|rushing)=0.4000
# p(mother|oh)=0.0152
# p(most|oh)=0.0152
# p(samana|oh)=0.0455
# p(excellent|oh)=0.0152
# p(exalted|oh)=0.0758
# p(perfected|oh)=0.0152
# p(govinda|oh)=0.2576
# p(stranger|oh)=0.0152
# p(yes|oh)=0.0455
# p(charitable|oh)=0.0152
# p(venerable|oh)=0.0909
# p(siddhartha|oh)=0.0909
# p(my|oh)=0.0303
# p(seeker|oh)=0.0152
# p(brown|oh)=0.0152
# p(son|oh)=0.0152
# p(friend|oh)=0.0909
# p(,|oh)=0.0455
# p(sir|oh)=0.0303
# p(kamala|oh)=0.0152
# p(honourable|oh)=0.0303
# p(how|oh)=0.0152
# p(,|tiny)=1.0000
# p(of|stories)=1.0000
# p(,|chance)=1.0000
# p(and|hips)=0.5000
# p(.|hips)=0.5000
# p(to|come)=0.3902
# p(and|come)=0.0244
# p(?|come)=0.0732
# p(up|come)=0.0244
# p(over|come)=0.0488
# p(back|come)=0.0732
# p(,|come)=0.1707
# p(from|come)=0.0488
# p(in|come)=0.0488
# p('|come)=0.0244
# p(into|come)=0.0244
# p(he|come)=0.0244
# p(with|come)=0.0244
# p(arrivals|constant)=1.0000
# p(.|shore)=1.0000
# p(hell|upholstered)=1.0000
# p(things|non-eternal)=1.0000
# p(lying|snake)=0.2500
# p(was|snake)=0.2500
# p(is|snake)=0.2500
# p(fled|snake)=0.2500
# p(courtesan|famous)=1.0000
# p(head|shaven)=1.0000
# p(in|succeed)=1.0000
# p(walking|continued)=0.1429
# p(thinking|continued)=0.1429
# p(to|continued)=0.1429
# p(fleeing|continued)=0.1429
# p(:|continued)=0.1429
# p(,|continued)=0.2857
# p(,|together)=0.2000
# p(was|together)=0.1333
# p(.|together)=0.0667
# p(by|together)=0.0667
# p(with|together)=0.5333
# p(he|vomiting)=1.0000
# p(memory|distant)=0.1111
# p(spot|distant)=0.1111
# p(to|distant)=0.1111
# p(and|distant)=0.1111
# p(son|distant)=0.1111
# p(,|distant)=0.1111
# p(hight|distant)=0.1111
# p(target|distant)=0.1111
# p(beach|distant)=0.1111
# p(had|purchase)=1.0000
# p(to|spell)=0.1250
# p(?|spell)=0.1250
# p(,|spell)=0.3750
# p(on|spell)=0.1250
# p(of|spell)=0.1250
# p(.|spell)=0.1250
# p(,|current)=0.3333
# p(of|current)=0.3333
# p(.|current)=0.3333
# p(by|discovered)=0.3333
# p(all|discovered)=0.3333
# p(kamala|discovered)=0.3333
# p(;|staff)=1.0000
# p(myth|fragrant)=0.3333
# p(of|fragrant)=0.3333
# p(,|fragrant)=0.3333
# p(by|puzzled)=1.0000
# p(in|refuge)=0.6250
# p(,|refuge)=0.0625
# p(with|refuge)=0.3125
# p(most|fades)=1.0000
# p(,|smell)=0.5000
# p(of|smell)=0.5000
# p(sick|deadly)=1.0000
# p(in|peels)=1.0000
# p(,|fair)=0.6667
# p(hands|fair)=0.3333
# p(or|dryness)=1.0000
# p(the|knew)=0.0444
# p(everything|knew)=0.0667
# p(and|knew)=0.0222
# p(so|knew)=0.0222
# p(deep|knew)=0.0222
# p(himself|knew)=0.0222
# p(neither|knew)=0.0222
# p(,|knew)=0.0222
# p(his|knew)=0.0222
# p(many|knew)=0.0444
# p(.|knew)=0.0444
# p(to|knew)=0.0222
# p(about|knew)=0.0667
# p(:|knew)=0.0222
# p(what|knew)=0.0444
# p(that|knew)=0.1556
# p(infinitely|knew)=0.0222
# p(this|knew)=0.0222
# p(how|knew)=0.0667
# p(it|knew)=0.0889
# p(from|knew)=0.0222
# p(nothing|knew)=0.0444
# p(more|knew)=0.0222
# p(little|knew)=0.0444
# p(me|kid)=1.0000
# p(passed|seasons)=0.5000
# p(and|seasons)=0.5000
# p(,|banana-eaters)=1.0000
# p('|'hard)=1.0000
# p(and|strangers)=1.0000
# p(,|falcon)=1.0000
# p(living|moderate)=1.0000
# p(to|coming)=0.0833
# p(into|coming)=0.1667
# p(back|coming)=0.0833
# p(from|coming)=0.5000
# p(towards|coming)=0.0833
# p(across|coming)=0.0833
# p(,|meditation)=0.5714
# p(had|meditation)=0.0714
# p(of|meditation)=0.0714
# p(?|meditation)=0.1429
# p(.|meditation)=0.1429
# p(on|progressed)=1.0000
# p(the|spread)=1.0000
# p(for|conclusion)=1.0000
# p(a|plunging)=1.0000
# p(in|cousin)=1.0000
# p(my|deceptively)=1.0000
# p(the|asked)=0.2093
# p(for|asked)=0.0698
# p(to|asked)=0.0465
# p(.|asked)=0.0698
# p(siddhartha|asked)=0.0465
# p(govinda|asked)=0.0930
# p(again|asked)=0.0233
# p(:|asked)=0.0698
# p(with|asked)=0.0233
# p(hesitantly|asked)=0.0233
# p(whether|asked)=0.0233
# p(himself|asked)=0.0233
# p(how|asked)=0.0233
# p(it|asked)=0.0233
# p(his|asked)=0.0465
# p(him|asked)=0.1163
# p(kamala|asked)=0.0233
# p(many|asked)=0.0233
# p(about|asked)=0.0233
# p(part|divine)=0.0909
# p(arrow|divine)=0.0909
# p(and|divine)=0.0909
# p(lived|divine)=0.0909
# p(voice|divine)=0.0909
# p(buddha|divine)=0.0909
# p(,|divine)=0.0909
# p(voices|divine)=0.0909
# p(forgiveness|divine)=0.0909
# p(grace|divine)=0.0909
# p(.|divine)=0.0909
# p(came|never)=0.0196
# p(and|never)=0.0196
# p(again|never)=0.0784
# p(convince|never)=0.0196
# p(talked|never)=0.0196
# p(subservient|never)=0.0196
# p(been|never)=0.0588
# p(come|never)=0.0196
# p(since|never)=0.0196
# p(he|never)=0.0588
# p(fully|never)=0.0196
# p(one-sided|never)=0.0196
# p(touched|never)=0.0196
# p(returned|never)=0.0196
# p(listened|never)=0.0196
# p(something|never)=0.0196
# p(satisfied|never)=0.0196
# p(thought|never)=0.0392
# p(rule|never)=0.0196
# p(upset|never)=0.0196
# p(i|never)=0.0392
# p(be|never)=0.0392
# p(before|never)=0.2549
# p(,|never)=0.0196
# p(stopped|never)=0.0196
# p(afraid|never)=0.0196
# p(entirely|never)=0.0392
# p(any|never)=0.0196
# p(happened|somehow)=1.0000
# p(it|divide)=1.0000
# p(legs|slender)=1.0000
# p(the|friend)=0.0149
# p(siddhartha|friend)=0.0149
# p(.|friend)=0.1493
# p(and|friend)=0.0448
# p(?|friend)=0.0149
# p('s|friend)=0.0299
# p(will|friend)=0.0149
# p(as|friend)=0.0149
# p(!|friend)=0.0299
# p(govinda|friend)=0.0299
# p(had|friend)=0.0149
# p(,|friend)=0.4627
# p(was|friend)=0.0299
# p(advised|friend)=0.0149
# p(aside|friend)=0.0149
# p(of|friend)=0.0597
# p(is|friend)=0.0149
# p(with|friend)=0.0299
# p(to|confess)=0.6667
# p(that|confess)=0.3333
# p(,|journey)=0.3333
# p(away|journey)=0.3333
# p(.|journey)=0.3333
# p(were|children)=0.0833
# p(,|children)=0.3333
# p(and|children)=0.0833
# p(have|children)=0.0833
# p(from|children)=0.0833
# p(--|children)=0.0833
# p(already|children)=0.0833
# p(are|children)=0.0833
# p(with|children)=0.0833
# p(,|repentance)=1.0000
# p(go|``)=0.0054
# p(at|``)=0.0027
# p(climbing|``)=0.0027
# p(bring|``)=0.0027
# p(well|``)=0.0136
# p(perhaps|``)=0.0027
# p(all|``)=0.0054
# p(writing|``)=0.0027
# p(i'm|``)=0.0027
# p(would|``)=0.0082
# p(many|``)=0.0054
# p(is|``)=0.0109
# p(presumable|``)=0.0027
# p(no|``)=0.0191
# p(listen|``)=0.0054
# p(not|``)=0.0082
# p(whatever|``)=0.0027
# p(look|``)=0.0027
# p(as|``)=0.0054
# p(ask|``)=0.0027
# p(did|``)=0.0082
# p(ah|``)=0.0054
# p(it|``)=0.0490
# p(right|``)=0.0027
# p(certainly|``)=0.0027
# p(once|``)=0.0027
# p(the|``)=0.0054
# p(very|``)=0.0027
# p(oh|``)=0.0136
# p(again|``)=0.0054
# p(so|``)=0.0163
# p(things|``)=0.0054
# p(our|``)=0.0027
# p(dear|``)=0.0054
# p(yesterday|``)=0.0054
# p(still|``)=0.0027
# p(stop|``)=0.0027
# p(govinda|``)=0.0082
# p(farewell|``)=0.0054
# p(bent|``)=0.0027
# p(were|``)=0.0027
# p(to|``)=0.0082
# p(yes|``)=0.0163
# p(permit|``)=0.0027
# p(everyone|``)=0.0027
# p(most|``)=0.0027
# p(here|``)=0.0054
# p(om|``)=0.0054
# p(if|``)=0.0136
# p(be|``)=0.0027
# p(nothing|``)=0.0054
# p(how|``)=0.0218
# p(,|``)=0.0027
# p(simple|``)=0.0027
# p(often|``)=0.0027
# p(already|``)=0.0027
# p(excellent|``)=0.0027
# p(give|``)=0.0054
# p(do|``)=0.0163
# p(today|``)=0.0054
# p(an|``)=0.0027
# p(now|``)=0.0136
# p(instantly|``)=0.0027
# p(why|``)=0.0054
# p(but|``)=0.0436
# p(are|``)=0.0054
# p(however|``)=0.0027
# p(you've|``)=0.0027
# p(never|``)=0.0027
# p(bend|``)=0.0027
# p(there|``)=0.0082
# p(friend|``)=0.0027
# p(that|``)=0.0191
# p(pardon|``)=0.0027
# p(speak|``)=0.0027
# p(from|``)=0.0027
# p(far|``)=0.0027
# p(early|``)=0.0027
# p(your|``)=0.0082
# p(before|``)=0.0027
# p(o|``)=0.0054
# p(then|``)=0.0027
# p(will|``)=0.0054
# p(and|``)=0.0218
# p(they|``)=0.0027
# p(can|``)=0.0027
# p(hurry|``)=0.0027
# p(she|``)=0.0027
# p(soon|``)=0.0027
# p(he|``)=0.0082
# p(one|``)=0.0054
# p(too|``)=0.0027
# p(when|``)=0.0054
# p(you|``)=0.1090
# p(with|``)=0.0054
# p(let|``)=0.0109
# p(siddhartha|``)=0.0191
# p(my|``)=0.0027
# p(what|``)=0.0245
# p(beautiful|``)=0.0027
# p(i|``)=0.1553
# p(this|``)=0.0218
# p(always|``)=0.0027
# p(we|``)=0.0109
# p(get|``)=0.0027
# p(surely|``)=0.0082
# p(a|``)=0.0136
# p(as|fresh)=1.0000
# p(by|awoken)=0.1667
# p(,|awoken)=0.1667
# p(one|awoken)=0.1667
# p(in|awoken)=0.1667
# p(again|awoken)=0.1667
# p(hundreds|awoken)=0.1667
# p(,|real)=0.5714
# p(life|real)=0.1429
# p(.|real)=0.2857
# p(to|strictly)=1.0000
# p(infinitely|achieving)=1.0000
# p(,|wife)=0.6667
# p(had|wife)=0.3333
# p(,|chamber)=0.4286
# p(and|chamber)=0.1429
# p(he|chamber)=0.2857
# p(;|chamber)=0.1429
# p(the|stayed)=0.0625
# p(for|stayed)=0.0625
# p(motionless|stayed)=0.0625
# p(where|stayed)=0.0625
# p(there|stayed)=0.0625
# p(in|stayed)=0.1875
# p(rigidly|stayed)=0.0625
# p(on|stayed)=0.0625
# p(behind|stayed)=0.2500
# p(with|stayed)=0.1250
# p(,|obey)=0.3333
# p(like|obey)=0.3333
# p(your|obey)=0.3333
# p(the|times)=0.0385
# p(were|times)=0.0385
# p(always|times)=0.0385
# p(and|times)=0.0385
# p(for|times)=0.0385
# p(:|times)=0.0385
# p(--|times)=0.0385
# p(only|times)=0.0385
# p(i|times)=0.0769
# p(all|times)=0.0385
# p(to|times)=0.0385
# p(been|times)=0.0385
# p(he|times)=0.1538
# p(,|times)=0.1923
# p(of|times)=0.0769
# p(.|times)=0.0769
# p(,|require)=1.0000
# p(of|net)=1.0000
# p(smelled|everything)=0.0169
# p(came|everything)=0.0169
# p(and|everything)=0.0169
# p(hard|everything)=0.0169
# p(could|everything)=0.0169
# p(in|everything)=0.0339
# p(good|everything)=0.0169
# p(has|everything)=0.0339
# p(shown|everything)=0.0169
# p(hostile|everything)=0.0169
# p(,|everything)=0.1695
# p(out|everything)=0.0169
# p(was|everything)=0.0678
# p(together|everything)=0.0169
# p(died|everything)=0.0169
# p(.|everything)=0.0847
# p(for|everything)=0.0169
# p(can|everything)=0.0169
# p(to|everything)=0.0169
# p(siddhartha|everything)=0.0169
# p(?|everything)=0.0169
# p(--|everything)=0.0169
# p(which|everything)=0.0169
# p(only|everything)=0.0169
# p(!|everything)=0.0169
# p(is|everything)=0.1186
# p(always|everything)=0.0169
# p(else|everything)=0.0169
# p(he|everything)=0.1017
# p(enter|everything)=0.0169
# p(,|frost)=1.0000
# p(and|disobedient)=0.5000
# p(heart|disobedient)=0.5000
# p(.|fly)=1.0000
# p(are|hearts)=0.3333
# p(of|hearts)=0.3333
# p(.|hearts)=0.3333
# p(was|flourishing)=1.0000
# p(for|space)=0.5000
# p(and|space)=0.5000
# p(letters|important)=0.1667
# p(affairs|important)=0.1667
# p(thing|important)=0.6667
# p(after|hesitantly)=0.3333
# p(he|hesitantly)=0.3333
# p(and|hesitantly)=0.3333
# p(:|answered)=0.7500
# p(govinda|answered)=0.2500
# p(,|bows)=0.5000
# p(with|bows)=0.5000
# p(down|truthful)=1.0000
# p(,|tough)=0.5000
# p(against|tough)=0.5000
# p(for|striving)=1.0000
# p(a|uttered)=1.0000
# p(``|call)=0.1429
# p(them|call)=0.1429
# p(out|call)=0.1429
# p(`things|call)=0.1429
# p(magic|call)=0.1429
# p(of|call)=0.1429
# p(yourself|call)=0.1429
# p(the|worshipped)=0.3333
# p(river|worshipped)=0.3333
# p(but|worshipped)=0.3333
# p(of|style)=1.0000
# p(yet|shine)=0.2500
# p(on|shine)=0.2500
# p(at|shine)=0.2500
# p(.|shine)=0.2500
# p(him|passing)=1.0000
# p(servants|four)=0.3333
# p(or|four)=0.3333
# p(main|four)=0.3333
# p(the|did)=0.0337
# p(not|did)=0.5393
# p(they|did)=0.0112
# p(and|did)=0.0112
# p(n't|did)=0.0112
# p(sense|did)=0.0112
# p(his|did)=0.0112
# p(we|did)=0.0225
# p(as|did)=0.0112
# p(i|did)=0.0337
# p(she|did)=0.0112
# p(this|did)=0.0112
# p(you|did)=0.0787
# p(he|did)=0.1236
# p(it|did)=0.0225
# p(,|did)=0.0112
# p(.|did)=0.0112
# p(many|did)=0.0112
# p(any|did)=0.0112
# p(see|did)=0.0112
# p(to|answering)=1.0000
# p(,|chess-board)=1.0000
# p(of|glistened)=1.0000
# p(,|benevolence)=0.5000
# p(of|benevolence)=0.5000
# p(my|alongside)=1.0000
# p(me|telling)=0.5000
# p(you|telling)=0.5000

# %%
#We could also obtain bigram probabilities for specific words:
bigram_probability.conditions()
query = bigram_probability["suffering"].prob("was")
print (str(query))
# Out:
# 0.06818181818181818

# %% [markdown]
# Compute trigram language model:

# %%
#First compute the trigrams:
trigram_model  = nltk.trigrams(words)
#Then compute the frequency for each trigram:
trigram_words = (((word[0], word[1]), word[2]) for word in trigram_model)
trigram_frequency_word = nltk.ConditionalFreqDist(trigram_words)
#To get the trigram probabilities we would need to normalize the trigram frequencies:
trigram_probability_word = nltk.ConditionalProbDist(trigram_frequency_word, nltk.MLEProbDist)
#Let's compute the trigram probabilities constraining on sentences:
trigram_frequency_sent = nltk.ConditionalFreqDist(((word[0], word[1]), word[2])  for word in list( itertools.chain (*[nltk.trigrams(i) for i in tokenized_sentences])))
trigram_probability_sent = nltk.ConditionalProbDist(trigram_frequency_sent, nltk.MLEProbDist)

#Let's print the trigram probabilities computed over sentences:
trigram_probability = trigram_probability_sent
trigram_frequency = trigram_frequency_sent
all_trigrams2 = {}
for source_word in trigram_probability:
	prob_words = trigram_probability[source_word].samples()
	denom = len(prob_words)
	all_trigrams2[source_word]={}
	for target_word in prob_words:
		prob = trigram_probability[source_word].prob(target_word)
		freq = trigram_frequency[source_word][target_word]
		prob2 = (1.0)*freq/denom
		all_trigrams2[source_word][target_word] = prob
		print ("p("+target_word+"|"+source_word[0]+","+source_word[1]+")={0:.4f}".format(prob))
# Out:
# p(all|for,them)=0.5000
# p(.|for,them)=0.5000
# p(friendly|waited,,)=0.5000
# p(watching|waited,,)=0.5000
# p(a|,,such)=0.5000
# p(is|,,such)=0.5000
# p(his|doubt,in)=1.0000
# p(all|talking,to)=0.3333
# p(himself|talking,to)=0.3333
# p(you|talking,to)=0.3333
# p(alone|samanas,slept)=1.0000
# p(''|food,:)=1.0000
# p(would|'',we)=1.0000
# p(shadow|light,and)=0.5000
# p(peace|light,and)=0.5000
# p(me|happened,to)=0.2500
# p(slip|happened,to)=0.1250
# p(meet|happened,to)=0.1250
# p(glance|happened,to)=0.1250
# p(him|happened,to)=0.2500
# p(you|happened,to)=0.1250
# p(father|chiefly,his)=1.0000
# p(without|alone,,)=0.3333
# p(he|alone,,)=0.3333
# p(i|alone,,)=0.3333
# p(runaway|following,the)=1.0000
# p(down|fall,straight)=1.0000
# p(of|the,foolishness)=1.0000
# p(,|talked,about)=0.3333
# p(what|talked,about)=0.3333
# p(it|talked,about)=0.3333
# p(so|was,right)=1.0000
# p(,|not,full)=1.0000
# p(made|offerings,were)=1.0000
# p(evil|to,avoid)=1.0000
# p(me|mystery,of)=0.5000
# p(what|mystery,of)=0.5000
# p(!|such,feats)=1.0000
# p(from|give,away)=1.0000
# p(.|of,truth)=1.0000
# p(.|just,listening)=1.0000
# p(perfume|fragrance,of)=1.0000
# p(and|him,again)=1.0000
# p(had|'',she)=0.1111
# p(admitted|'',she)=0.1111
# p(called|'',she)=0.1111
# p(said|'',she)=0.6667
# p(in|becomes,old)=1.0000
# p(knew|,,nobody)=0.6667
# p(may|,,nobody)=0.3333
# p(the|already,tasted)=1.0000
# p(lying|a,snake)=0.3333
# p(was|a,snake)=0.3333
# p(is|a,snake)=0.3333
# p(.|washing,clothes)=1.0000
# p(the|siddhartha,entered)=1.0000
# p(positions|naked,in)=1.0000
# p(was|mountains,,)=0.5000
# p(everywhere|mountains,,)=0.5000
# p(eyes|filled,her)=1.0000
# p(be|soon,i'll)=1.0000
# p(him|had,drawn)=1.0000
# p(killing|achieved,by)=0.5000
# p(scolding|achieved,by)=0.5000
# p(''|title,?)=1.0000
# p(have|,,farmers)=1.0000
# p(.|do,yourself)=1.0000
# p(him|she,controlled)=1.0000
# p(split|men,had)=0.5000
# p(lived|men,had)=0.5000
# p(,|many,thoughts)=1.0000
# p(young|saw,the)=0.0476
# p(lady|saw,the)=0.0476
# p(sedan-chair|saw,the)=0.0476
# p(servants|saw,the)=0.0952
# p(bananas|saw,the)=0.0476
# p(reflection|saw,the)=0.0476
# p(face|saw,the)=0.1905
# p(pike|saw,the)=0.0476
# p(bodies|saw,the)=0.0476
# p(stars|saw,the)=0.0476
# p(life|saw,the)=0.0476
# p(sun|saw,the)=0.0476
# p(cheerfulness|saw,the)=0.0476
# p(river|saw,the)=0.0476
# p(white|saw,the)=0.0476
# p(boy|saw,the)=0.0476
# p(heads|saw,the)=0.0476
# p(samanas|and,venerable)=1.0000
# p(.|no,goal)=1.0000
# p(,|another,time)=0.5000
# p(.|another,time)=0.5000
# p(and|the,robber)=0.5000
# p(is|the,robber)=0.5000
# p(deeply|,,more)=0.0909
# p(curious|,,more)=0.0909
# p(lovely|,,more)=0.0909
# p(willing|,,more)=0.0909
# p(comprehensible|,,more)=0.0909
# p(on|,,more)=0.0909
# p(firmly|,,more)=0.0909
# p(involved|,,more)=0.0909
# p(a|,,more)=0.0909
# p(clearly|,,more)=0.0909
# p(supple|,,more)=0.0909
# p(walked|before,he)=0.2500
# p(had|before,he)=0.7500
# p(passing|life,still)=1.0000
# p(to|will,seek)=1.0000
# p(``|continued,,)=1.0000
# p(not|body,definitely)=1.0000
# p(all|forsaken,by)=1.0000
# p(,|very,reason)=1.0000
# p(where|ferryman,about)=1.0000
# p(looked|attentively,he)=1.0000
# p(forest|the,sal-wood)=1.0000
# p(,|his,possession)=1.0000
# p(of|get,out)=1.0000
# p(correctly|'ve,remembered)=1.0000
# p(very|did,sense)=1.0000
# p(by|been,standing)=0.5000
# p(here|been,standing)=0.5000
# p(days|for,many)=0.1111
# p(long|for,many)=0.1111
# p(things|for,many)=0.1111
# p(years|for,many)=0.5556
# p(hours|for,many)=0.1111
# p(you|payment,from)=1.0000
# p(the|mirror,at)=1.0000
# p(thirsty|learn,,)=1.0000
# p(when|tale,,)=1.0000
# p(the|said,,)=0.1111
# p(``|said,,)=0.5556
# p(everything|said,,)=0.1111
# p(this|said,,)=0.1111
# p(not|said,,)=0.1111
# p(a|and,whispered)=0.5000
# p(to|and,whispered)=0.5000
# p(would|as,time)=1.0000
# p(who|his,son)=0.0526
# p(to|his,son)=0.0526
# p(appeared|his,son)=0.0526
# p(and|his,son)=0.1053
# p(?|his,son)=0.0526
# p(again|his,son)=0.0526
# p(merged|his,son)=0.0526
# p(had|his,son)=0.0526
# p(did|his,son)=0.0526
# p(,|his,son)=0.3158
# p(was|his,son)=0.0526
# p(.|his,son)=0.0526
# p(;|his,son)=0.0526
# p(the|course,to)=1.0000
# p(to|were,able)=1.0000
# p(,|own,life)=1.0000
# p(,|reaches,them)=1.0000
# p(boy|and,pampered)=1.0000
# p(,|happened,today)=1.0000
# p(people|ate,other)=1.0000
# p(it|not,seen)=1.0000
# p(.|happier,now)=1.0000
# p(shameful|the,most)=0.0556
# p(embarrassing|the,most)=0.0556
# p(forlorn|the,most)=0.0556
# p(and|the,most)=0.0556
# p(venerable|the,most)=0.1111
# p(suitable|the,most)=0.0556
# p(beautiful|the,most)=0.0556
# p(as|the,most)=0.0556
# p(intimate|the,most)=0.0556
# p(holy|the,most)=0.0556
# p(,|the,most)=0.0556
# p(foolish|the,most)=0.1111
# p(wretched|the,most)=0.0556
# p(important|the,most)=0.1667
# p(could|thing,he)=1.0000
# p(his|height,of)=1.0000
# p(which|river,over)=1.0000
# p(your|dust,in)=1.0000
# p(,|been,right)=1.0000
# p(talk|with,bad)=1.0000
# p(and|his,disciples)=1.0000
# p(open|through,the)=0.0417
# p(eyes|through,the)=0.0417
# p(window|through,the)=0.0417
# p(lanes|through,the)=0.0417
# p(air|through,the)=0.0417
# p(land|through,the)=0.1667
# p(door|through,the)=0.0417
# p(alleys|through,the)=0.0417
# p(things|through,the)=0.0417
# p(world|through,the)=0.0417
# p(forest|through,the)=0.1250
# p(rice-field|through,the)=0.0417
# p(small|through,the)=0.0833
# p(high|through,the)=0.0417
# p(villages|through,the)=0.0417
# p(grove|through,the)=0.0417
# p(garden|through,the)=0.0417
# p(flow|through,the)=0.0417
# p(through|had,passed)=0.2500
# p(,|had,passed)=0.5000
# p(on|had,passed)=0.2500
# p(a|teacher,for)=1.0000
# p(.|the,mango-trees)=1.0000
# p(was|loved,most)=1.0000
# p(also|thought,was)=0.5000
# p(to|thought,was)=0.5000
# p(voices|in,many)=0.5000
# p(an|in,many)=0.5000
# p(of|this,piece)=1.0000
# p(which|'',,)=0.5000
# p(was|'',,)=0.5000
# p(:|i,said)=0.5000
# p(?|i,said)=0.5000
# p(beard|shave,his)=1.0000
# p(,|many,questions)=0.5000
# p(he|many,questions)=0.5000
# p(to|never,subservient)=1.0000
# p(because|upon,today)=1.0000
# p(,|little,son)=0.5000
# p(would|little,son)=0.5000
# p(the|due,to)=0.3333
# p(a|due,to)=0.3333
# p(this|due,to)=0.3333
# p(,|through,thoughts)=1.0000
# p(had|young,ascetics)=1.0000
# p(to|fallen,victim)=1.0000
# p(every|and,awoke)=1.0000
# p(,|time,ago)=0.8000
# p(.|time,ago)=0.1000
# p(on|time,ago)=0.1000
# p(this|veneration,,)=1.0000
# p(was|,,welcome)=1.0000
# p(wrinkles|thousand,small)=1.0000
# p(would|why,he)=0.2000
# p(felt|why,he)=0.2000
# p(laughed|why,he)=0.2000
# p(had|why,he)=0.4000
# p(have|themselves,they)=1.0000
# p(of|a,numbing)=1.0000
# p(level|slightly,higher)=1.0000
# p(clothes|lacks,:)=1.0000
# p(silver|copper,and)=1.0000
# p(without|standing,alone)=1.0000
# p(a|nodded,for)=1.0000
# p(more|food,any)=1.0000
# p(?|venerable,teacher)=1.0000
# p(on|will,go)=0.5000
# p(to|will,go)=0.5000
# p(to|righteously,,)=1.0000
# p(,|but,now)=0.8571
# p(that|but,now)=0.1429
# p(most|determining,the)=1.0000
# p(,|the,relief)=1.0000
# p(which|and,nothing)=0.5000
# p(could|and,nothing)=0.5000
# p(.|all,distress)=1.0000
# p(whether|itself,,)=0.2000
# p(all|itself,,)=0.2000
# p(what|itself,,)=0.2000
# p(that|itself,,)=0.2000
# p(this|itself,,)=0.2000
# p(nor|neither,meat)=1.0000
# p(siddhartha|saw,young)=0.5000
# p(kamala|saw,young)=0.5000
# p(whatever|or,for)=0.5000
# p(an|or,for)=0.5000
# p(time|awoke,every)=1.0000
# p(,|and,magical)=1.0000
# p(woe|of,burning)=1.0000
# p(.|with,salutations)=1.0000
# p(face|this,reflected)=1.0000
# p(playing|be,merely)=1.0000
# p(just|his,feet)=0.2500
# p(,|his,feet)=0.7500
# p(,|there,again)=1.0000
# p(city|entering,this)=1.0000
# p(yearning|lamentation,of)=1.0000
# p(siddhartha|rose,;)=1.0000
# p(expressed|only,be)=1.0000
# p(nothing|men,said)=1.0000
# p(and|this,bright)=1.0000
# p(their|sky,in)=1.0000
# p(to|one,seeking)=1.0000
# p(every|new,on)=1.0000
# p(wonderful|what,a)=0.2500
# p(large|what,a)=0.2500
# p(path|what,a)=0.2500
# p(happy|what,a)=0.2500
# p(benevolence|the,cheerful)=1.0000
# p(the|,,how)=0.0714
# p(despicable|,,how)=0.0357
# p(rejecting|,,how)=0.0357
# p(he|,,how)=0.1429
# p(wise|,,how)=0.0357
# p(his|,,how)=0.0357
# p(could|,,how)=0.0714
# p(kind|,,how)=0.0357
# p(good|,,how)=0.0357
# p(grateful|,,how)=0.0357
# p(she|,,how)=0.0357
# p(shall|,,how)=0.0357
# p(closely|,,how)=0.0357
# p(should|,,how)=0.0714
# p(did|,,how)=0.0714
# p(distrustful|,,how)=0.0357
# p(peaceful|,,how)=0.0357
# p(still|,,how)=0.0357
# p(even|,,how)=0.0357
# p(clear|,,how)=0.0357
# p(once|,,how)=0.0357
# p(of|rosy,paths)=1.0000
# p(into|never,returned)=1.0000
# p(moving|of,apes)=1.0000
# p(,|same,place)=1.0000
# p(the|to,fill)=1.0000
# p(,|was,young)=1.0000
# p(in|a,hunter)=0.5000
# p(;|a,hunter)=0.5000
# p(,|;,indignant)=1.0000
# p(and|in,calmness)=1.0000
# p(did|perfection,,)=0.5000
# p(which|perfection,,)=0.5000
# p(knowledge|seeker,of)=1.0000
# p(acts|his,foolish)=1.0000
# p(floating|om,was)=1.0000
# p(when|sides,,)=1.0000
# p(me|but,tell)=0.7500
# p(us|but,tell)=0.2500
# p(that|spreading,around)=1.0000
# p(on|disdainfully,back)=1.0000
# p(path|obstructing,their)=1.0000
# p(the|lived,among)=1.0000
# p(,|stayed,rigidly)=1.0000
# p(was|the,sail)=1.0000
# p(the|many,of)=0.5000
# p(us|many,of)=0.5000
# p(passed|rainy,seasons)=1.0000
# p(senses|regained,his)=1.0000
# p(falling|people,with)=1.0000
# p(by|is,obsessed)=1.0000
# p(shipment|whether,a)=1.0000
# p(,|always,there)=1.0000
# p(,|a,hurry)=1.0000
# p(escapes|he,briefly)=1.0000
# p(sweet|which,tasted)=1.0000
# p(all|searching,,)=0.1000
# p(no|searching,,)=0.1000
# p(thus|searching,,)=0.1000
# p(''|searching,,)=0.1000
# p(this|searching,,)=0.1000
# p(was|searching,,)=0.1000
# p(so|searching,,)=0.1000
# p(timidness|searching,,)=0.1000
# p(you|searching,,)=0.1000
# p(but|searching,,)=0.1000
# p(,|,,teaching)=1.0000
# p(every|completely,filled)=1.0000
# p(teachings|the,teacher)=1.0000
# p(teacher|our,venerable)=1.0000
# p(the|siddhartha,asked)=0.5000
# p(his|siddhartha,asked)=0.5000
# p(savathi|arriving,at)=1.0000
# p(.|him,asleep)=1.0000
# p(many|it,teaches)=1.0000
# p(to|my,longing)=1.0000
# p(govinda|forget,,)=1.0000
# p(``|asking,:)=0.5000
# p(being|asking,:)=0.5000
# p(,|his,knees)=0.5000
# p(.|his,knees)=0.5000
# p(tiredness|the,flabby)=1.0000
# p(,|not,eternal)=0.5000
# p(is|not,eternal)=0.5000
# p(to|mother,,)=0.2500
# p(tell|mother,,)=0.2500
# p(and|mother,,)=0.5000
# p(from|him,apart)=1.0000
# p(,|the,flow)=0.2500
# p(of|the,flow)=0.7500
# p(pain|means,of)=0.1250
# p(the|means,of)=0.3750
# p(meditation|means,of)=0.1250
# p(teachings|means,of)=0.3750
# p(of|the,service)=0.6667
# p(and|the,service)=0.3333
# p(the|love,for)=0.3750
# p(his|love,for)=0.1250
# p(everything|love,for)=0.1250
# p(this|love,for)=0.2500
# p(you|love,for)=0.1250
# p(beggars|kindness,towards)=1.0000
# p(rushing|into,the)=0.0435
# p(nameless|into,the)=0.0217
# p(urge|into,the)=0.0217
# p(boat|into,the)=0.0435
# p(bushes|into,the)=0.0217
# p(crystal|into,the)=0.0217
# p(hut|into,the)=0.0217
# p(forests|into,the)=0.0652
# p(bamboo-wood|into,the)=0.0217
# p(life|into,the)=0.0435
# p(small|into,the)=0.0217
# p(habit|into,the)=0.0217
# p(stranger|into,the)=0.0217
# p(state|into,the)=0.0217
# p(community|into,the)=0.0435
# p(green|into,the)=0.0217
# p(hands|into,the)=0.0217
# p(cycle|into,the)=0.0217
# p(river|into,the)=0.0217
# p(shade|into,the)=0.0217
# p(body|into,the)=0.0217
# p(room|into,the)=0.0435
# p(world|into,the)=0.0217
# p(transparent|into,the)=0.0217
# p(forest|into,the)=0.0435
# p(ferryman|into,the)=0.0217
# p(water|into,the)=0.0652
# p(happy|into,the)=0.0217
# p(oneness|into,the)=0.0435
# p(city|into,the)=0.0217
# p(grove|into,the)=0.0435
# p(garden|into,the)=0.0435
# p(chamber|into,the)=0.0217
# p(a|felt,such)=1.0000
# p(home|been,without)=0.3333
# p(possessions|been,without)=0.3333
# p(food|been,without)=0.3333
# p(death|akin,to)=1.0000
# p(listened|upriver,,)=1.0000
# p(has|what,siddhartha)=0.5000
# p(and|what,siddhartha)=0.5000
# p(thirst|pain,nor)=1.0000
# p(and|from,teachings)=1.0000
# p(him|merchant,praised)=1.0000
# p(waiting|disgust,were)=1.0000
# p(desire|,,wild)=1.0000
# p(and|i,went)=1.0000
# p(things|many,sweet)=1.0000
# p(nevertheless|power,;)=1.0000
# p(life|person,'s)=1.0000
# p(,|something,new)=0.5000
# p(on|something,new)=0.5000
# p(by|struck,down)=1.0000
# p(his|not,open)=1.0000
# p(from|yet,shining)=1.0000
# p(this|gap,,)=0.3333
# p(where|gap,,)=0.3333
# p(with|gap,,)=0.3333
# p(master|awaited,the)=1.0000
# p(in|to,her)=0.1250
# p(:|to,her)=0.1250
# p(,|to,her)=0.2500
# p(boy|to,her)=0.1250
# p(;|to,her)=0.1250
# p(heart|to,her)=0.1250
# p(.|to,her)=0.1250
# p(he|burning,,)=1.0000
# p(and|laughed,brightly)=1.0000
# p(,|worldly,pleasures)=1.0000
# p(in|the,alleys)=1.0000
# p(redeemed|and,be)=0.3333
# p(a|and,be)=0.3333
# p(at|and,be)=0.3333
# p(city-house|before,his)=0.2000
# p(eyes|before,his)=0.8000
# p(,|princes,hunting)=1.0000
# p(stakes|with,high)=1.0000
# p(is|of,anathapindika)=1.0000
# p(sadness|as,much)=0.1429
# p(as|as,much)=0.5714
# p(and|as,much)=0.1429
# p(it|as,much)=0.1429
# p(for|he,fasted)=1.0000
# p(more|legs,any)=1.0000
# p(on|,,ascetics)=1.0000
# p(incarnation|,,previous)=1.0000
# p(stayed|rage,he)=1.0000
# p(so|victorious,,)=1.0000
# p(where|pavilion,,)=1.0000
# p(''|beautiful,?)=1.0000
# p(his|unsteadiness,in)=1.0000
# p('s|holding,one)=1.0000
# p(up|on,,)=0.2500
# p(she|on,,)=0.2500
# p(so|on,,)=0.2500
# p(wherever|on,,)=0.2500
# p(,|he,too)=0.2500
# p(felt|he,too)=0.2500
# p(is|he,too)=0.5000
# p(pampered|arrogant,and)=1.0000
# p(''|everything,!)=1.0000
# p(self-castigation|exercises,nor)=1.0000
# p(another|the,gift)=1.0000
# p(your|time,from)=1.0000
# p(of|the,point)=1.0000
# p(for|one,heading)=1.0000
# p(news|as,such)=1.0000
# p(pure|one,'s)=0.1429
# p(breath|one,'s)=0.1429
# p(thoughts|one,'s)=0.1429
# p(body|one,'s)=0.1429
# p(heart|one,'s)=0.1429
# p(own|one,'s)=0.2857
# p(the|lunch,,)=1.0000
# p(,|with,anguish)=1.0000
# p(full|face,smiling)=1.0000
# p(believers|so,the)=1.0000
# p(,|to,time)=0.5000
# p(that|to,time)=0.5000
# p(.|--,obedience)=1.0000
# p(in|found,amusement)=1.0000
# p(teacher|their,great)=1.0000
# p(of|joyful,because)=1.0000
# p(to|truly,wanted)=1.0000
# p(the|encompassed,by)=0.5000
# p(a|encompassed,by)=0.5000
# p(to|it,appears)=1.0000
# p(they|now,,)=0.0385
# p(oh|now,,)=0.0385
# p(siddhartha|now,,)=0.1538
# p(samana|now,,)=0.0385
# p(sensing|now,,)=0.0385
# p(everything|now,,)=0.0385
# p(only|now,,)=0.0385
# p(that|now,,)=0.0385
# p(i|now,,)=0.1154
# p(which|now,,)=0.0385
# p(today|now,,)=0.0385
# p(since|now,,)=0.0385
# p(his|now,,)=0.0385
# p(he|now,,)=0.1538
# p(was|now,,)=0.0385
# p(so|now,,)=0.0769
# p(you|now,,)=0.0385
# p(all|that,'s)=0.1667
# p(everything|that,'s)=0.3333
# p(like|that,'s)=0.1667
# p(their|that,'s)=0.1667
# p(not|that,'s)=0.1667
# p(the|,,seeing)=0.5000
# p(monks|,,seeing)=0.2500
# p(images|,,seeing)=0.2500
# p(himself|to,enjoy)=0.3333
# p(and|to,enjoy)=0.3333
# p(being|to,enjoy)=0.3333
# p(,|many,errors)=1.0000
# p(said|vasudeva,also)=1.0000
# p(out|ripped,him)=1.0000
# p(the|,,if)=0.0588
# p(this|,,if)=0.0588
# p(there|,,if)=0.0588
# p(it|,,if)=0.0588
# p(he|,,if)=0.2941
# p(a|,,if)=0.0588
# p(kamala|,,if)=0.0588
# p(only|,,if)=0.0588
# p(you|,,if)=0.1176
# p(i|,,if)=0.1765
# p(,|rather,die)=1.0000
# p(,|from,myself)=0.5000
# p(!|from,myself)=0.5000
# p(.|be,true)=1.0000
# p(his|sun,tanned)=1.0000
# p(often|it,,)=0.0149
# p(not|it,,)=0.0448
# p(or|it,,)=0.0149
# p(always|it,,)=0.0299
# p(miracles|it,,)=0.0149
# p(and|it,,)=0.0448
# p(because|it,,)=0.0149
# p(hating|it,,)=0.0149
# p(the|it,,)=0.0299
# p(could|it,,)=0.0299
# p(it|it,,)=0.0149
# p(only|it,,)=0.0149
# p(yes|it,,)=0.0149
# p(but|it,,)=0.0448
# p(do|it,,)=0.0149
# p(to|it,,)=0.0149
# p(''|it,,)=0.0896
# p(govinda|it,,)=0.0149
# p(in|it,,)=0.0299
# p(destroying|it,,)=0.0149
# p(when|it,,)=0.0149
# p(many|it,,)=0.0149
# p(with|it,,)=0.0149
# p(attentively|it,,)=0.0149
# p(each|it,,)=0.0149
# p(who|it,,)=0.0149
# p(her|it,,)=0.0149
# p(full|it,,)=0.0149
# p(sucked|it,,)=0.0149
# p(my|it,,)=0.0448
# p(that|it,,)=0.0299
# p(may|it,,)=0.0149
# p(suffered|it,,)=0.0149
# p(an|it,,)=0.0149
# p(i|it,,)=0.0448
# p(``|it,,)=0.0149
# p(which|it,,)=0.0149
# p(this|it,,)=0.0149
# p(giving|it,,)=0.0149
# p(became|it,,)=0.0149
# p(than|it,,)=0.0149
# p(he|it,,)=0.0746
# p(voices|it,,)=0.0149
# p(like|walked,quickly)=1.0000
# p(had|much,they)=1.0000
# p(use|'s,the)=1.0000
# p(fallen|night,had)=0.5000
# p(already|night,had)=0.5000
# p(the|or,from)=1.0000
# p(in|the,cold)=1.0000
# p(``|began,,)=0.3333
# p(he|began,,)=0.3333
# p(siddhartha|began,,)=0.3333
# p(--|ten,times)=0.3333
# p(been|ten,times)=0.3333
# p(for|ten,times)=0.3333
# p(my|i'm,wearing)=1.0000
# p(rising|tall,neck)=1.0000
# p(,|,,bracelets)=1.0000
# p(.|by,everyone)=1.0000
# p(,|many,days)=0.5000
# p(by|many,days)=0.5000
# p(.|in,heat)=1.0000
# p(this|had,realized)=1.0000
# p(their|themselves,and)=1.0000
# p(?|right,path)=1.0000
# p(.|the,universe)=1.0000
# p(,|runaway,son)=1.0000
# p(in|nevertheless,broken)=1.0000
# p(as|have,changed)=1.0000
# p(,|without,power)=1.0000
# p(life|his,worldly)=1.0000
# p(his|from,finding)=0.5000
# p(peace|from,finding)=0.5000
# p(the|n't,find)=1.0000
# p(is|me,it)=1.0000
# p(of|saw,none)=1.0000
# p(everything|shown,,)=1.0000
# p(of|the,wheel)=1.0000
# p(he|suddenly,,)=0.2500
# p(she|suddenly,,)=0.2500
# p(pride|suddenly,,)=0.2500
# p(as|suddenly,,)=0.2500
# p(for|childish,notions)=1.0000
# p(but|have,nothing)=1.0000
# p(a|friend,with)=0.5000
# p(this|friend,with)=0.5000
# p(beautiful|with,the)=0.0192
# p(people|with,the)=0.0385
# p(fragrance|with,the)=0.0192
# p(breath|with,the)=0.0192
# p(exalted|with,the)=0.0769
# p(ability|with,the)=0.0192
# p(bondage|with,the)=0.0192
# p(river|with,the)=0.0192
# p(teachings|with,the)=0.0385
# p(pleasures|with,the)=0.0192
# p(dice|with,the)=0.0192
# p(thought|with,the)=0.0192
# p(body|with,the)=0.0192
# p(eye|with,the)=0.0192
# p(penitents|with,the)=0.0192
# p(ever|with,the)=0.0192
# p(high|with,the)=0.0192
# p(luminous|with,the)=0.0192
# p(meals|with,the)=0.0192
# p(pestilence|with,the)=0.0192
# p(basics|with,the)=0.0192
# p(atman|with,the)=0.0192
# p(suffering|with,the)=0.0192
# p(universe|with,the)=0.0192
# p(same|with,the)=0.0192
# p(source|with,the)=0.0192
# p(glory|with,the)=0.0192
# p(wish|with,the)=0.0192
# p(salvation|with,the)=0.0192
# p(flow|with,the)=0.0192
# p(healing|with,the)=0.0192
# p(samanas|with,the)=0.0577
# p(first|with,the)=0.0385
# p(learned|with,the)=0.0192
# p(ascetics|with,the)=0.0192
# p(business|with,the)=0.0192
# p(trade|with,the)=0.0192
# p(current|with,the)=0.0192
# p(ferryman|with,the)=0.0192
# p(novices|with,the)=0.0192
# p(money|with,the)=0.0192
# p(wrong|with,the)=0.0192
# p(childlike|with,the)=0.0192
# p(nirvana|with,the)=0.0192
# p(n't|they,wo)=1.0000
# p(to|is,able)=1.0000
# p(if|acted,as)=1.0000
# p(from|siddhartha,;)=0.5000
# p(his|siddhartha,;)=0.5000
# p(,|of,prayer)=1.0000
# p(lost|he,ever)=0.5000
# p(loved|he,ever)=0.5000
# p(bee|a,buzzing)=1.0000
# p(he|foolish,act)=1.0000
# p(a|committed,,)=1.0000
# p(of|the,herd)=1.0000
# p(longer|were,no)=0.5000
# p(more|were,no)=0.2500
# p(past|were,no)=0.2500
# p(along|boy,ran)=0.5000
# p(away|boy,ran)=0.5000
# p(,|venerable,brahmans)=1.0000
# p(the|law,of)=0.5000
# p(causes|law,of)=0.5000
# p(visible|called,the)=1.0000
# p(the|remained,in)=0.5000
# p(his|remained,in)=0.5000
# p(into|sensations,turn)=1.0000
# p(,|many,brothers)=1.0000
# p(of|childlikeness,and)=1.0000
# p(?|is,fasting)=1.0000
# p(saw|parade,,)=1.0000
# p(,|his,servant)=1.0000
# p(,|faithful,friend)=1.0000
# p(he|worth,keeping)=1.0000
# p(the|content,,)=0.5000
# p(govinda|content,,)=0.5000
# p(they|contain,:)=1.0000
# p(him|had,brought)=1.0000
# p(of|n't,capable)=1.0000
# p(it|,,there)=0.0323
# p(were|,,there)=0.0645
# p(sky|,,there)=0.0323
# p(forest|,,there)=0.0323
# p(are|,,there)=0.0645
# p(he|,,there)=0.0323
# p(was|,,there)=0.3548
# p(everything|,,there)=0.0323
# p('ll|,,there)=0.0323
# p(is|,,there)=0.2903
# p(kamala|,,there)=0.0323
# p(and|a,green)=1.0000
# p(oh|what,,)=1.0000
# p(,|ever,rising)=1.0000
# p(,|,,rocks)=1.0000
# p(of|his,blissfulness)=1.0000
# p(symbols|scorn,the)=1.0000
# p(their|samana,under)=1.0000
# p(,|out,there)=0.5000
# p(yesterday|out,there)=0.5000
# p(knows|he,who)=0.1429
# p(ponderingly|he,who)=0.1429
# p(was|he,who)=0.1429
# p(would|he,who)=0.2857
# p(had|he,who)=0.2857
# p('s|in,govinda)=1.0000
# p(of|many,forms)=1.0000
# p(teacher|,,my)=0.0169
# p(many|,,my)=0.0169
# p(faithful|,,my)=0.0169
# p(honoured|,,my)=0.0169
# p(dear|,,my)=0.4237
# p(thirst|,,my)=0.0169
# p(love|,,my)=0.0169
# p(heart|,,my)=0.0169
# p(cousin|,,my)=0.0169
# p(present|,,my)=0.0169
# p(friend.|,,my)=0.0169
# p(duty|,,my)=0.0169
# p(eyes|,,my)=0.0169
# p(river|,,my)=0.0169
# p(benefactor|,,my)=0.0169
# p(learned|,,my)=0.0169
# p(friend|,,my)=0.2034
# p(words|,,my)=0.0169
# p(loving|,,my)=0.0169
# p(own|,,my)=0.0169
# p(path|,,my)=0.0339
# p(joy|,,my)=0.0169
# p(father|,,my)=0.0169
# p(but|washed,,)=1.0000
# p(people|still,the)=0.5000
# p(art|still,the)=0.5000
# p(a|spoke,with)=0.6667
# p(ecstasy|spoke,with)=0.3333
# p(do|--,why)=1.0000
# p(of|the,book)=1.0000
# p(his|little,of)=1.0000
# p(,|the,house)=0.2500
# p(and|the,house)=0.2500
# p(.|the,house)=0.5000
# p(.|beautiful,girl)=1.0000
# p(through|would,go)=0.2000
# p(on|would,go)=0.2000
# p(this|would,go)=0.2000
# p(out|would,go)=0.2000
# p(it|would,go)=0.2000
# p(deed|word,and)=0.3333
# p(breath|word,and)=0.3333
# p(siddhartha|word,and)=0.3333
# p(with|govinda,together)=1.0000
# p(the|was,rolling)=1.0000
# p(forms|of,many)=1.0000
# p(everything|everybody,and)=1.0000
# p(believe|you,actually)=1.0000
# p(thirst|in,new)=1.0000
# p(perhaps|unsaid,,)=1.0000
# p(and|or,bored)=1.0000
# p(age|of,old)=1.0000
# p(the|went,through)=1.0000
# p(this|everything,in)=0.5000
# p(your|everything,in)=0.5000
# p(his|by,annihilating)=1.0000
# p(,|other,hand)=0.5000
# p(.|other,hand)=0.5000
# p(,|awakening,one)=1.0000
# p(on|not,payed)=1.0000
# p(of|seventy,years)=1.0000
# p(?|without,money)=1.0000
# p(brothers|my,many)=1.0000
# p(on|was,written)=0.3333
# p(that|was,written)=0.3333
# p(there|was,written)=0.3333
# p(;|captured,him)=1.0000
# p(he|long,had)=1.0000
# p(them|two,of)=1.0000
# p(loss|each,big)=1.0000
# p(without|he,ran)=0.3333
# p(,|he,ran)=0.3333
# p(up|he,ran)=0.3333
# p(the|brahmans,,)=0.1429
# p(chiefly|brahmans,,)=0.1429
# p(among|brahmans,,)=0.1429
# p(where|brahmans,,)=0.1429
# p(year|brahmans,,)=0.1429
# p(he|brahmans,,)=0.1429
# p(and|brahmans,,)=0.1429
# p(on|already,progressed)=1.0000
# p(the|will,hear)=1.0000
# p(down|and,poured)=1.0000
# p(,|masterful,skills)=1.0000
# p(by|was,awoken)=1.0000
# p(and|new,path)=1.0000
# p(he|however,easily)=1.0000
# p(,|a,wife)=1.0000
# p(,|towards,beggars)=1.0000
# p(him|now,told)=1.0000
# p(om|speak,the)=1.0000
# p(thing|,,small)=1.0000
# p(.|and,penance)=1.0000
# p(his|not,heed)=1.0000
# p(,|weary,life)=1.0000
# p(priests|sick,,)=0.5000
# p(life|sick,,)=0.5000
# p(beautiful|'s,a)=0.5000
# p(visitor|'s,a)=0.5000
# p(oneness|inhale,the)=1.0000
# p(a|you've,changed)=1.0000
# p(no|noblemen,,)=1.0000
# p(pain|hunger,and)=1.0000
# p(quickly|i'll,learn)=1.0000
# p(his|plays,with)=1.0000
# p(,|the,ground)=0.3636
# p(.|the,ground)=0.3636
# p(of|the,ground)=0.0909
# p(with|the,ground)=0.0909
# p(;|the,ground)=0.0909
# p(long|bodies,through)=1.0000
# p(me|had,guided)=1.0000
# p(teachers|and,their)=0.2000
# p(goal|and,their)=0.2000
# p(course|and,their)=0.2000
# p(goals|and,their)=0.2000
# p(holy|and,their)=0.2000
# p(home|renounced,your)=0.3333
# p(free|renounced,your)=0.3333
# p(birth|renounced,your)=0.3333
# p(of|first,light)=1.0000
# p(!|oh,kamala)=1.0000
# p(still|was,there)=0.5000
# p(ever|was,there)=0.5000
# p(disgust|sucked,up)=1.0000
# p(mango-tree|owned,a)=0.2500
# p(house|owned,a)=0.2500
# p(small|owned,a)=0.2500
# p(garden|owned,a)=0.2500
# p(my|hospitality,,)=1.0000
# p(fear|so,without)=1.0000
# p(,|dangling,hand)=0.3333
# p(expressed|dangling,hand)=0.3333
# p(and|dangling,hand)=0.3333
# p(a|garden,for)=1.0000
# p(reality|actually,a)=1.0000
# p(,|'re,friendly)=1.0000
# p(the|news,of)=0.3333
# p(him|news,of)=0.3333
# p(siddhartha|news,of)=0.3333
# p(the|atman,in)=0.3333
# p(me|atman,in)=0.3333
# p(him|atman,in)=0.3333
# p(was|,,mortal)=0.6667
# p(?|,,mortal)=0.3333
# p(brahman|father,the)=1.0000
# p(,|saying,it)=1.0000
# p(and|proceed,swiftly)=1.0000
# p(complete|moment,of)=0.5000
# p(a|moment,of)=0.5000
# p(feel|help,but)=1.0000
# p(something|been,saying)=1.0000
# p(and|warrior,,)=1.0000
# p(the|``,get)=1.0000
# p(the|all,times)=0.5000
# p(of|all,times)=0.5000
# p(he|gambling,,)=1.0000
# p(end|to,their)=0.2000
# p(lives|to,their)=0.2000
# p(great|to,their)=0.2000
# p(children|to,their)=0.2000
# p(mind|to,their)=0.2000
# p(he|slower,,)=1.0000
# p(,|bottomless,pit)=1.0000
# p(simultaneously|be,there)=1.0000
# p(myself|,,delude)=1.0000
# p(is|and,red)=1.0000
# p(,|ranting,speeches)=1.0000
# p(himself|has,distinguished)=1.0000
# p(you|could,hurt)=1.0000
# p(;|,,thousands)=1.0000
# p(,|on,time)=1.0000
# p(rainbows|clouds,,)=1.0000
# p(him|affairs,with)=1.0000
# p(clanged|golden,bracelets)=0.5000
# p(over|golden,bracelets)=0.5000
# p(,|exalted,gotama)=0.3333
# p(has|exalted,gotama)=0.3333
# p(spoke|exalted,gotama)=0.3333
# p(have|life,you)=1.0000
# p(young|the,two)=0.3000
# p(ferrymen|the,two)=0.2000
# p(samanas|the,two)=0.2000
# p(of|the,two)=0.1000
# p(old|the,two)=0.2000
# p(shins|his,bare)=1.0000
# p(,|of,repentance)=1.0000
# p(and|will,stand)=1.0000
# p(,|every,month)=1.0000
# p(,|,,yes)=0.5000
# p(even|,,yes)=0.2500
# p(.|,,yes)=0.2500
# p(nights|short,the)=1.0000
# p(to|camp,started)=1.0000
# p(.|its,contents)=1.0000
# p(that|actually,believe)=1.0000
# p(taught|educated,and)=1.0000
# p(,|fine,shoes)=1.0000
# p(was|forms,,)=0.5000
# p(this|forms,,)=0.5000
# p(order|gave,the)=0.5000
# p(rice-cake|gave,the)=0.5000
# p(a|really,become)=1.0000
# p(for|is,unlikely)=1.0000
# p(the|gotama,,)=0.4375
# p(which|gotama,,)=0.0625
# p(consisted|gotama,,)=0.0625
# p(and|gotama,,)=0.0625
# p(at|gotama,,)=0.0625
# p(in|gotama,,)=0.0625
# p(he|gotama,,)=0.1250
# p(a|gotama,,)=0.1250
# p(,|my,benefactor)=1.0000
# p(by|but,solely)=1.0000
# p(,|and,learning)=1.0000
# p(touch|,,bashful)=1.0000
# p(,|destined,for)=1.0000
# p(the|,,perceived)=1.0000
# p(and|floated,along)=1.0000
# p(asked|courage,and)=1.0000
# p(heading|river,was)=0.3333
# p(river|river,was)=0.3333
# p(obstructing|river,was)=0.3333
# p(,|the,om)=0.4286
# p(silently|the,om)=0.1429
# p(was|the,om)=0.1429
# p(entered|the,om)=0.1429
# p(in|the,om)=0.1429
# p(for|and,known)=1.0000
# p(hurry|showing,any)=1.0000
# p(you|'m,greeting)=1.0000
# p(.|slim,hips)=1.0000
# p(think|today,i)=1.0000
# p(ca|whose,thoughts)=1.0000
# p(a|eyes,beheld)=1.0000
# p(women|pleases,the)=1.0000
# p(!|such,jokes)=1.0000
# p(still|,,govinda)=0.0263
# p(twenty|,,govinda)=0.0263
# p(rose|,,govinda)=0.0263
# p(listened|,,govinda)=0.0263
# p(stopped|,,govinda)=0.0263
# p(looked|,,govinda)=0.0263
# p(said|,,govinda)=0.0526
# p(who|,,govinda)=0.0263
# p(saw|,,govinda)=0.0263
# p(urged|,,govinda)=0.0263
# p(bowed|,,govinda)=0.0263
# p(realized|,,govinda)=0.0526
# p(!|,,govinda)=0.0526
# p(turned|,,govinda)=0.0263
# p(used|,,govinda)=0.0263
# p(,|,,govinda)=0.3684
# p(would|,,govinda)=0.0263
# p(also|,,govinda)=0.0263
# p(knew|,,govinda)=0.0263
# p(.|,,govinda)=0.0789
# p(knowledge|than,the)=0.2000
# p(service|than,the)=0.2000
# p(desire|than,the)=0.2000
# p(loincloth|than,the)=0.2000
# p(servant|than,the)=0.2000
# p(forms|and,worthless)=0.5000
# p(hull|and,worthless)=0.5000
# p(with|she,spoke)=1.0000
# p(.|my,reward)=1.0000
# p(.|pale,cheeks)=1.0000
# p(the|spent,with)=1.0000
# p(for|of,differentiation)=1.0000
# p(of|the,state)=1.0000
# p(the|gotama,taught)=1.0000
# p(,|fiery,thoughts)=1.0000
# p(female|male,and)=1.0000
# p(the|,,in)=0.3371
# p(spite|,,in)=0.0112
# p(jetavana|,,in)=0.0112
# p(stubborn|,,in)=0.0112
# p(some|,,in)=0.0112
# p(past|,,in)=0.0112
# p(his|,,in)=0.0225
# p(everything|,,in)=0.0112
# p(that|,,in)=0.0112
# p(their|,,in)=0.0112
# p(learning|,,in)=0.0112
# p(those|,,in)=0.0225
# p(calmness|,,in)=0.0112
# p(these|,,in)=0.0112
# p(you|,,in)=0.0112
# p(siddhartha|,,in)=0.0112
# p(fear|,,in)=0.0112
# p(her|,,in)=0.0112
# p(no|,,in)=0.0112
# p(its|,,in)=0.0337
# p(everyone|,,in)=0.0112
# p(my|,,in)=0.0337
# p(order|,,in)=0.1348
# p(words|,,in)=0.0112
# p(an|,,in)=0.0225
# p(which|,,in)=0.0674
# p(perfect|,,in)=0.0112
# p(this|,,in)=0.0337
# p(living|,,in)=0.0112
# p(it|,,in)=0.0112
# p(deep|,,in)=0.0112
# p(a|,,in)=0.0225
# p(themselves|,,in)=0.0112
# p(simple|,,in)=0.0112
# p(on|of,us)=0.2500
# p(across|of,us)=0.2500
# p(to|of,us)=0.2500
# p(,|of,us)=0.2500
# p(the|world,of)=0.5000
# p(thought|world,of)=0.1667
# p(unity|world,of)=0.1667
# p(appearances|world,of)=0.1667
# p(the|oneness,of)=0.5000
# p(all|oneness,of)=0.5000
# p(wished|sleepless,man)=1.0000
# p(curious|joyful,and)=0.5000
# p(beautiful|joyful,and)=0.5000
# p(on|a,castaway)=1.0000
# p(,|say,so)=1.0000
# p(.|',feathers)=1.0000
# p(noble|delicate,and)=1.0000
# p(while|into,himself)=0.5000
# p(like|into,himself)=0.5000
# p(one|move,from)=1.0000
# p(,|no,teachings)=0.5000
# p(will|no,teachings)=0.5000
# p(in|with,doubt)=0.5000
# p(.|with,doubt)=0.5000
# p(,|all,suffering)=0.3333
# p(time|all,suffering)=0.3333
# p(.|all,suffering)=0.3333
# p(goal|for,that)=1.0000
# p(in|was,shimmering)=1.0000
# p(.|completely,different)=1.0000
# p(,|they,parted)=0.5000
# p(.|they,parted)=0.5000
# p(popped|full,breast)=1.0000
# p(,|two,ferrymen)=0.5000
# p(which|two,ferrymen)=0.5000
# p(take|path,to)=0.2000
# p(the|path,to)=0.4000
# p(perfection|path,to)=0.2000
# p(himself|path,to)=0.2000
# p(:|tell,me)=0.1000
# p(,|tell,me)=0.6000
# p(something|tell,me)=0.1000
# p(some|tell,me)=0.1000
# p(this|tell,me)=0.1000
# p(man|an,unknown)=0.5000
# p(place|an,unknown)=0.5000
# p(her|,,tell)=1.0000
# p(,|ugly,spell)=1.0000
# p(being|of,me)=0.7500
# p(had|of,me)=0.2500
# p(hold|,,grabbed)=1.0000
# p(the|samanas,in)=1.0000
# p(which|secret,,)=1.0000
# p(rested|defeated,and)=1.0000
# p(assistant|barber,'s)=1.0000
# p(impatiently|swiftly,and)=1.0000
# p(front|directly,in)=1.0000
# p(brahmans|regarded,as)=0.3333
# p(a|regarded,as)=0.3333
# p(natural|regarded,as)=0.3333
# p(,|to,dust)=1.0000
# p(this|trick,of)=1.0000
# p(teachings|,,better)=1.0000
# p(some|imagined,,)=1.0000
# p(more|received,no)=1.0000
# p(,|his,saturated)=1.0000
# p(went|monks,,)=0.3333
# p(govinda|monks,,)=0.3333
# p(saw|monks,,)=0.3333
# p(all|still,lacked)=1.0000
# p(from|the,separation)=1.0000
# p(pilgrims|rather,many)=1.0000
# p(the|pile,on)=1.0000
# p(,|spring,forth)=1.0000
# p(,|her,hands)=1.0000
# p(to|help,you)=1.0000
# p(in|not,atman)=1.0000
# p(to|,,despicable)=1.0000
# p(as|and,fresh)=1.0000
# p(his|wine,from)=1.0000
# p(.|same,state)=1.0000
# p(in|previous,thoughts)=1.0000
# p(shall|my,glance)=0.3333
# p(before|my,glance)=0.3333
# p(.|my,glance)=0.3333
# p(siddhartha|secret,of)=1.0000
# p(``|smile,:)=1.0000
# p(spent|pilgrims,shall)=1.0000
# p(nothing|comprehensible,,)=1.0000
# p(if|profitable,,)=1.0000
# p(the|teacher,,)=0.1250
# p(for|teacher,,)=0.2500
# p(and|teacher,,)=0.1250
# p(not|teacher,,)=0.1250
# p(a|teacher,,)=0.1250
# p(whose|teacher,,)=0.1250
# p(i|teacher,,)=0.1250
# p(,|sleep,again)=1.0000
# p(devote|lose,or)=1.0000
# p(willingness|``,your)=0.3333
# p(son|``,your)=0.3333
# p(soul|``,your)=0.3333
# p(and|with,pumpkin-seeds)=1.0000
# p(,|the,thinker)=1.0000
# p(.|receive,thanks)=1.0000
# p(those|children,from)=1.0000
# p(with|drop,laden)=1.0000
# p(happily|curiously,and)=1.0000
# p(or|the,priest)=0.5000
# p(and|the,priest)=0.5000
# p(log|on,the)=0.0286
# p(stairs|on,the)=0.0286
# p(gestures|on,the)=0.0286
# p(forehead|on,the)=0.0286
# p(other|on,the)=0.1429
# p(same|on,the)=0.0571
# p(reflecting|on,the)=0.0286
# p(ground|on,the)=0.0857
# p(right|on,the)=0.0286
# p(squares|on,the)=0.0286
# p(fastest|on,the)=0.0286
# p(opposite|on,the)=0.0286
# p(shore|on,the)=0.0286
# p(sea|on,the)=0.0286
# p(way|on,the)=0.0571
# p(pilgrimage|on,the)=0.0286
# p(banks|on,the)=0.0286
# p(path|on,the)=0.1143
# p(job|on,the)=0.0286
# p(front|on,the)=0.0286
# p(mat|on,the)=0.0286
# p(sandy|on,the)=0.0286
# p(root|on,the)=0.0286
# p(bed|on,the)=0.0286
# p(from|this,respect)=1.0000
# p(one|so,this)=0.5000
# p(was|so,this)=0.5000
# p(his|realised,that)=0.5000
# p(everything|realised,that)=0.5000
# p(me|also,worrying)=1.0000
# p(?|moment,longer)=1.0000
# p(kamala|,,lovely)=1.0000
# p(do|therefore,i)=0.3333
# p(also|therefore,i)=0.3333
# p(am|therefore,i)=0.3333
# p(in|who,revel)=1.0000
# p(was|mouth,which)=1.0000
# p(the|not,walk)=1.0000
# p(the|of,all)=0.0690
# p(people|of,all)=0.0345
# p(things|of,all)=0.1034
# p(dependencies|of,all)=0.0345
# p(prayers|of,all)=0.0345
# p(life|of,all)=0.0345
# p(passions|of,all)=0.0345
# p(thoughts|of,all)=0.0345
# p(knowledge|of,all)=0.0345
# p(others|of,all)=0.0345
# p(.|of,all)=0.0690
# p(conceptions|of,all)=0.0345
# p(vices|of,all)=0.0345
# p(manifestations|of,all)=0.0345
# p(that|of,all)=0.0345
# p(hours|of,all)=0.0345
# p(i|of,all)=0.0690
# p(thinking|of,all)=0.0345
# p(,|of,all)=0.1034
# p(secrets|of,all)=0.0345
# p(peels|of,all)=0.0345
# p(of|of,all)=0.0345
# p(hopeless|and,ultimately)=1.0000
# p(kind|,,some)=0.3333
# p(news|,,some)=0.3333
# p(mocking|,,some)=0.3333
# p(and|that,way)=1.0000
# p(search|his,long)=1.0000
# p(the|soul,,)=0.1538
# p(fuming|soul,,)=0.0769
# p(flew|soul,,)=0.0769
# p(again|soul,,)=0.0769
# p(made|soul,,)=0.0769
# p(without|soul,,)=0.0769
# p(which|soul,,)=0.0769
# p(read|soul,,)=0.0769
# p(slowly|soul,,)=0.0769
# p(an|soul,,)=0.0769
# p(out|soul,,)=0.0769
# p(he|soul,,)=0.0769
# p(thousand|its,ten)=1.0000
# p(to|for,guests)=1.0000
# p(the|boats,by)=1.0000
# p(he|wished,that)=1.0000
# p(;|so,irrefutably)=1.0000
# p(prepared|were,already)=1.0000
# p(,|no,edges)=1.0000
# p(and|his,polite)=1.0000
# p(passion|of,quiet)=1.0000
# p(,|was,river)=1.0000
# p(to|the,mind)=1.0000
# p(do|``,and)=0.2500
# p(now|``,and)=0.1250
# p(would|``,and)=0.2500
# p(what|``,and)=0.1250
# p(when|``,and)=0.1250
# p(i|``,and)=0.1250
# p(one|,,just)=0.0526
# p(to|,,just)=0.2105
# p(like|,,just)=0.0526
# p(an|,,just)=0.0526
# p(as|,,just)=0.6316
# p(their|novices,taken)=1.0000
# p(him|still,awaiting)=1.0000
# p(son|the,handsome)=1.0000
# p(the|flew,over)=0.5000
# p(forest|flew,over)=0.5000
# p(ever|ever,and)=1.0000
# p(thing|be,the)=0.2000
# p(one|be,the)=0.2000
# p(most|be,the)=0.4000
# p(custom|be,the)=0.2000
# p(.|greedy,mouth)=1.0000
# p(yesterday|soon,as)=0.1250
# p(time|soon,as)=0.1250
# p(tomorrow|soon,as)=0.1250
# p(it|soon,as)=0.1250
# p(one|soon,as)=0.1250
# p(possible|soon,as)=0.2500
# p(i|soon,as)=0.1250
# p(kamala|different,games)=1.0000
# p(--|him,unconscious.)=1.0000
# p(of|the,shoulder)=1.0000
# p(ferryman|becomes,a)=0.5000
# p(bit|becomes,a)=0.5000
# p(the|to,calm)=1.0000
# p(.|is,full)=1.0000
# p(from|learned,this)=1.0000
# p(a|roof,for)=1.0000
# p(his|,,comb)=1.0000
# p(resembled|this,face)=1.0000
# p(and|blind,strength)=1.0000
# p(to|i,wanted)=1.0000
# p(saw|sight,,)=1.0000
# p(a|sleep,on)=1.0000
# p(his|finger,of)=0.5000
# p(this|finger,of)=0.5000
# p(nodded|beautiful,women)=1.0000
# p(,|must,praise)=1.0000
# p(after|one,another)=0.1667
# p(,|one,another)=0.3333
# p(.|one,another)=0.5000
# p(,|called,himself)=1.0000
# p(to|kamala,returned)=1.0000
# p(up|go,it)=1.0000
# p(the|eternal,in)=1.0000
# p(the|om,:)=1.0000
# p(when|impatient,,)=1.0000
# p(not|chest,has)=1.0000
# p(still|real,life)=1.0000
# p(for|the,love)=0.2000
# p(of|the,love)=0.8000
# p(,|over,him)=1.0000
# p(on|we,be)=1.0000
# p(,|other,things)=1.0000
# p(by|thus,loved)=1.0000
# p(.|a,drunkard)=1.0000
# p(effects|causes,and)=1.0000
# p(one|oh,perfected)=1.0000
# p(necessary|else,was)=0.2500
# p(to|else,was)=0.2500
# p(left|else,was)=0.2500
# p(searching|else,was)=0.2500
# p(his|assistant,shave)=1.0000
# p(jackals|and,lank)=1.0000
# p(,|against,myself)=1.0000
# p(but|insight,,)=0.5000
# p(again|insight,,)=0.5000
# p(,|,,businessmen)=1.0000
# p(,|have,peace)=1.0000
# p(without|thin,,)=0.3333
# p(and|thin,,)=0.3333
# p(with|thin,,)=0.3333
# p(i|perhaps,what)=1.0000
# p(buddha|this,alleged)=1.0000
# p(of|ferried,travellers)=1.0000
# p(trunk|against,its)=1.0000
# p(hermann|tale,by)=1.0000
# p(,|a,rumour)=1.0000
# p(under|robes,,)=1.0000
# p(was|its,midst)=1.0000
# p(the|belong,to)=0.6000
# p(?|belong,to)=0.2000
# p(kamala|belong,to)=0.2000
# p(insatiably|blindly,and)=1.0000
# p(''|dish,.)=1.0000
# p(.|starry,sky)=1.0000
# p(spells|with,magic)=1.0000
# p(,|for,sale)=1.0000
# p(--|the,scriptures)=1.0000
# p(the|,,differently)=1.0000
# p(.|can,fast)=1.0000
# p(restless|dreams,and)=1.0000
# p(of|the,contents)=1.0000
# p(suffering|to,relieve)=1.0000
# p(,|tasted,riches)=1.0000
# p(it|rather,because)=1.0000
# p(a|never,been)=0.3333
# p(able|never,been)=0.3333
# p(destitute|never,been)=0.3333
# p(more|been,much)=1.0000
# p(before|his,sickness)=1.0000
# p(his|,,bid)=1.0000
# p(with|he,spent)=1.0000
# p(?|your,amusement)=1.0000
# p(it|knife,in)=1.0000
# p(oh|still,,)=0.3333
# p(this|still,,)=0.3333
# p(even|still,,)=0.3333
# p(and|from,everywhere)=1.0000
# p(and|with,resistance)=1.0000
# p(the|would,be)=0.0769
# p(better|would,be)=0.0769
# p(its|would,be)=0.0769
# p(effected|would,be)=0.0769
# p(suffering|would,be)=0.0769
# p(hard|would,be)=0.0769
# p(nirvana|would,be)=0.0769
# p(spared|would,be)=0.0769
# p(useful|would,be)=0.0769
# p(such|would,be)=0.0769
# p(a|would,be)=0.1538
# p(calm|would,be)=0.0769
# p(never|clearly,as)=1.0000
# p(of|spices,,)=1.0000
# p(speaks|word,it)=1.0000
# p(zealously|trade,more)=1.0000
# p(.|that,ferry)=1.0000
# p(,|a,dying)=0.5000
# p(fish|a,dying)=0.5000
# p(also|this,pleasure)=1.0000
# p(on|had,kept)=1.0000
# p(such|who,knows)=0.5000
# p(what|who,knows)=0.5000
# p(waiting|robber,is)=1.0000
# p(food|beg,,)=1.0000
# p(would|part,and)=1.0000
# p(``|father,:)=1.0000
# p(will|--,nobody)=1.0000
# p(eyes|stranger,'s)=1.0000
# p(be|can,not)=0.7000
# p(love|can,not)=0.2000
# p(deny|can,not)=0.1000
# p(the|how,should)=0.1667
# p(he|how,should)=0.1667
# p(i|how,should)=0.3333
# p(this|how,should)=0.1667
# p(n't|how,should)=0.1667
# p(through|,,walking)=0.3333
# p(silently|,,walking)=0.3333
# p(swiftly|,,walking)=0.3333
# p(govinda|soon,,)=0.6667
# p(i|soon,,)=0.3333
# p(come|day,will)=1.0000
# p(child|a,healthy)=1.0000
# p(of|forcefully,out)=1.0000
# p(become|they,'ve)=1.0000
# p(?|,,admonition)=1.0000
# p(no|kamala,had)=0.1667
# p(given|kamala,had)=0.1667
# p(been|kamala,had)=0.3333
# p(sighed|kamala,had)=0.1667
# p(said|kamala,had)=0.1667
# p(the|disputes,of)=1.0000
# p(to|is,trying)=1.0000
# p(only|miserably,,)=0.5000
# p(and|miserably,,)=0.5000
# p(a|astonished,like)=1.0000
# p(,|looked,like)=0.5000
# p(a|looked,like)=0.5000
# p(,|for,money)=0.6667
# p(and|for,money)=0.3333
# p(,|,,kind)=1.0000
# p(pretty|do,many)=1.0000
# p(.|more,zealous)=1.0000
# p(him|kamala,interrupted)=1.0000
# p(through|vices,,)=1.0000
# p(.|here,siddhartha)=1.0000
# p(,|i,imagined)=1.0000
# p(teachers|us,by)=1.0000
# p(of|his,bowl)=1.0000
# p(for|ago,,)=0.0909
# p(she|ago,,)=0.0909
# p(you|ago,,)=0.0909
# p(or|ago,,)=0.0909
# p(and|ago,,)=0.0909
# p(as|ago,,)=0.0909
# p(oh|ago,,)=0.0909
# p(in|ago,,)=0.0909
# p(when|ago,,)=0.1818
# p(possibly|ago,,)=0.0909
# p(,|a,god)=0.3333
# p(to|a,god)=0.3333
# p(had|a,god)=0.3333
# p(he|how,could)=0.1429
# p(i|how,could)=0.2857
# p(you|how,could)=0.4286
# p(it|how,could)=0.1429
# p(,|without,judgement)=1.0000
# p(knew|which,i)=0.0769
# p(have|which,i)=0.3077
# p(like|which,i)=0.0769
# p(said|which,i)=0.0769
# p(sought|which,i)=0.1538
# p(am|which,i)=0.0769
# p(had|which,i)=0.0769
# p(can|which,i)=0.1538
# p(,|our,destination)=1.0000
# p(self|longer,my)=1.0000
# p(and|pestilence,,)=1.0000
# p(he|by,now)=1.0000
# p(for|this,request)=1.0000
# p(love|why,i)=0.5000
# p(am|why,i)=0.5000
# p(the|the,life)=0.1429
# p(,|the,life)=0.1429
# p(fading|the,life)=0.1429
# p(of|the,life)=0.4286
# p(which|the,life)=0.1429
# p(or|a,son)=0.5000
# p(of|a,son)=0.5000
# p(me|than,about)=1.0000
# p(on|beyond,,)=1.0000
# p(the|turned,to)=0.2500
# p(dust|turned,to)=0.2500
# p(siddhartha|turned,to)=0.2500
# p(icy|turned,to)=0.2500
# p(.|within,himself)=1.0000
# p(to|you,came)=1.0000
# p(whom|fate,of)=1.0000
# p(play|they,not)=1.0000
# p(the|home,to)=0.5000
# p(become|home,to)=0.5000
# p(his|always,obeyed)=1.0000
# p(mothers|loving,,)=1.0000
# p(out|to,carry)=1.0000
# p(far|was,already)=0.5000
# p(learning|was,already)=0.5000
# p(he|thing,that)=0.5000
# p(was|thing,that)=0.5000
# p(n't|thoughts,ca)=1.0000
# p(,|the,end)=0.1667
# p(of|the,end)=0.6667
# p(.|the,end)=0.1667
# p(.|his,language)=1.0000
# p(standing|saw,siddhartha)=1.0000
# p(n't|and,does)=1.0000
# p(,|his,sleep)=0.2500
# p(and|his,sleep)=0.5000
# p(.|his,sleep)=0.2500
# p(have|before,we)=1.0000
# p(cautious|intelligent,,)=1.0000
# p(for|forgive,me)=0.5000
# p(,|forgive,me)=0.5000
# p(bodies|escape,their)=1.0000
# p(after|back,hour)=1.0000
# p(doing|he,'s)=0.1667
# p(strong|he,'s)=0.1667
# p(looking|he,'s)=0.1667
# p(taking|he,'s)=0.3333
# p(with|he,'s)=0.1667
# p(he|voice,when)=1.0000
# p(the|his,hair)=0.1429
# p(,|his,hair)=0.5714
# p(and|his,hair)=0.1429
# p(which|his,hair)=0.1429
# p(.|dressed,people)=1.0000
# p(much|far,too)=1.0000
# p(,|,,quiet)=0.3333
# p(bubbles|,,quiet)=0.1667
# p(smile|,,quiet)=0.1667
# p(and|,,quiet)=0.1667
# p(voice|,,quiet)=0.1667
# p(and|``,hurry)=1.0000
# p(way|was,another)=1.0000
# p(words|said,with)=1.0000
# p(new|my,present)=0.5000
# p(path|my,present)=0.5000
# p(,|first,house)=1.0000
# p(before|differently,than)=1.0000
# p(a|but,with)=0.5000
# p(this|but,with)=0.5000
# p(it|and,unleash)=1.0000
# p(deepest|knowing,this)=1.0000
# p(he|know,what)=0.3333
# p(.|know,what)=0.6667
# p(the|it,are)=0.5000
# p(these|it,are)=0.5000
# p(hesse|by,hermann)=1.0000
# p(death|for,:)=1.0000
# p(and|reluctance,,)=1.0000
# p(,|through,realizations)=1.0000
# p(his|turned,against)=1.0000
# p(this|anything,of)=1.0000
# p(,|of,animals)=1.0000
# p(the|softly,sounded)=1.0000
# p(lose|shall,not)=0.5000
# p(be|shall,not)=0.5000
# p(,|self,again)=1.0000
# p(,|loved,everything)=0.5000
# p(siddhartha|loved,everything)=0.5000
# p(plan|abandon,your)=1.0000
# p(his|not,pay)=1.0000
# p(to|'s,wall)=1.0000
# p(i|awakened,,)=1.0000
# p(to|sink,down)=1.0000
# p(lost|thousands,,)=0.2000
# p(threw|thousands,,)=0.2000
# p(a|thousands,,)=0.2000
# p(which|thousands,,)=0.2000
# p(whose|thousands,,)=0.2000
# p(a|to,suffer)=1.0000
# p(,|such,places)=1.0000
# p(.|mocking,me)=1.0000
# p(him|worship,in)=1.0000
# p(,|the,ferry-boat)=1.0000
# p(he|more,similar)=0.3333
# p(to|more,similar)=0.6667
# p(are|we,monks)=1.0000
# p(offered|merchant,who)=1.0000
# p(which|no,gift)=0.5000
# p(i|no,gift)=0.5000
# p(love|after,celebrating)=1.0000
# p(,|,,silently)=1.0000
# p(the|separated,from)=1.0000
# p(,|and,trust)=1.0000
# p(under|seek,rest)=1.0000
# p(i|smart,as)=1.0000
# p(his|deep,was)=1.0000
# p(him|a,devour)=1.0000
# p(dreaming|,,occasionally)=1.0000
# p(full|his,steps)=1.0000
# p(to|as,alike)=1.0000
# p(house|very,first)=1.0000
# p(them|and,offered)=1.0000
# p(the|and,gullibly)=1.0000
# p(inscrutable|equanimity,his)=1.0000
# p(all|base,of)=1.0000
# p(?|so,good)=1.0000
# p(,|of,withering)=1.0000
# p(wasted|dreary,and)=1.0000
# p(denial|resistance,and)=1.0000
# p(,|pretty,kamala)=0.5000
# p(.|pretty,kamala)=0.5000
# p(taught|doctrines,,)=1.0000
# p(love|of,joyful)=1.0000
# p(teach|say,and)=1.0000
# p(more|wore,nothing)=1.0000
# p(because|spared,,)=1.0000
# p(,|new,life)=1.0000
# p(,|time,real)=1.0000
# p(this|wound,to)=1.0000
# p(and|),himself)=1.0000
# p(the|cowered,in)=1.0000
# p(people|even,bad)=1.0000
# p(give|things,to)=0.5000
# p(kamala|things,to)=0.5000
# p(,|n't,worry)=1.0000
# p(siddhartha|more,to)=1.0000
# p(;|with,ecstasy)=1.0000
# p(over|never,rule)=1.0000
# p(body|taught,my)=1.0000
# p(other|before,any)=1.0000
# p(.|divine,voices)=1.0000
# p(with|greedy,merchant)=1.0000
# p(seventy|sixty,and)=1.0000
# p(,|it,rot)=1.0000
# p(,|her,son)=1.0000
# p(,|here,blue)=1.0000
# p(i|often,,)=0.4000
# p(siddhartha|often,,)=0.2000
# p(they|often,,)=0.2000
# p(it|often,,)=0.2000
# p(people|of,rich)=1.0000
# p(something|you,found)=1.0000
# p(watched|;,siddhartha)=0.3333
# p(leaned|;,siddhartha)=0.3333
# p(stood|;,siddhartha)=0.3333
# p(target|very,distant)=1.0000
# p(much|doing,so)=1.0000
# p(,|spoke,slowly)=1.0000
# p(one|'s,virtues)=1.0000
# p(i|likes,,)=1.0000
# p(about|rarely,talked)=1.0000
# p(in|the,exercise)=1.0000
# p(sacrificing|repentance,,)=1.0000
# p(in|nurse,discontent)=1.0000
# p(with|in,living)=1.0000
# p(by|nor,others)=1.0000
# p(.|by,love)=1.0000
# p(me|``,permit)=1.0000
# p(,|listen,well)=0.5000
# p(!|listen,well)=0.5000
# p(for|people,,)=0.0500
# p(to|people,,)=0.0500
# p(bustling|people,,)=0.0500
# p(and|people,,)=0.0500
# p(govinda|people,,)=0.0500
# p(less|people,,)=0.0500
# p(those|people,,)=0.0500
# p(as|people,,)=0.0500
# p(of|people,,)=0.0500
# p(even|people,,)=0.0500
# p(accustomed|people,,)=0.0500
# p(businessmen|people,,)=0.0500
# p(had|people,,)=0.0500
# p(he|people,,)=0.1000
# p(a|people,,)=0.1000
# p(kamala|people,,)=0.0500
# p(whose|people,,)=0.0500
# p(with|people,,)=0.0500
# p(him|even,with)=0.5000
# p(your|even,with)=0.5000
# p(the|,,did)=0.0667
# p(he|,,did)=0.1333
# p(not|,,did)=0.8000
# p(of|among,hundreds)=1.0000
# p(from|your,son)=0.2500
# p(shall|your,son)=0.1250
# p('s|your,son)=0.1250
# p(,|your,son)=0.1250
# p(is|your,son)=0.2500
# p(.|your,son)=0.1250
# p(seemed|a,debtor)=1.0000
# p(,|``,instantly)=1.0000
# p(that|brahman,saw)=1.0000
# p(the|but,to)=0.3333
# p(depart|but,to)=0.3333
# p(leave|but,to)=0.3333
# p(start|entities,and)=1.0000
# p(to|great,,)=1.0000
# p(any|dissect,myself)=1.0000
# p(for|he,hesitated)=1.0000
# p(this|repetition,,)=1.0000
# p(me|missing,in)=1.0000
# p(,|a,fool)=0.5000
# p(on|a,fool)=0.5000
# p(him|not,touching)=1.0000
# p(,|same,paths)=1.0000
# p(away|throw,it)=1.0000
# p(not|he,would)=0.1250
# p(watch|he,would)=0.0625
# p(n't|he,would)=0.0625
# p(conceal|he,would)=0.0625
# p(join|he,would)=0.0625
# p(give|he,would)=0.0625
# p(only|he,would)=0.0625
# p(spent|he,would)=0.0625
# p(also|he,would)=0.1875
# p(kill|he,would)=0.0625
# p(have|he,would)=0.1250
# p(find|he,would)=0.0625
# p(,|,,magic)=1.0000
# p(by|was,puzzled)=1.0000
# p(,|mango,grove)=1.0000
# p(?|happy,fortune)=0.5000
# p(it|happy,fortune)=0.5000
# p(request|hear,this)=1.0000
# p(words|arguing,about)=1.0000
# p(men|glances,from)=1.0000
# p(one|great,perfected)=1.0000
# p(clear|so,strangely)=1.0000
# p(close|pulling,him)=1.0000
# p(.|seeks,unity)=1.0000
# p('s|against,kamala)=1.0000
# p(,|live,of)=1.0000
# p(desire|also,felt)=1.0000
# p(:|to,it)=0.0833
# p(would|to,it)=0.0833
# p(.|to,it)=0.2500
# p(!|to,it)=0.1667
# p(,|to,it)=0.4167
# p(:|is,settled)=1.0000
# p(so|trust,,)=0.5000
# p(i|trust,,)=0.5000
# p(of|no,driver)=1.0000
# p(woman|sat,a)=1.0000
# p(,|and,answers)=1.0000
# p(he|came,,)=0.3333
# p(who|came,,)=0.3333
# p(when|came,,)=0.3333
# p(of|bluish,shade)=1.0000
# p(a|someone,reads)=1.0000
# p(a|praying,in)=1.0000
# p(satisfied|even,have)=1.0000
# p(and|thousand,births)=1.0000
# p(the|among,all)=0.6667
# p(of|among,all)=0.3333
# p(dead|strike,him)=1.0000
# p(with|beat,stronger)=1.0000
# p(the|them,towards)=0.5000
# p(this|them,towards)=0.5000
# p(,|mere,appearances)=1.0000
# p(.|in,everything)=1.0000
# p(savage|heard,their)=1.0000
# p(,|a,warrior)=1.0000
# p(our|eternal,are)=1.0000
# p(your|sweetness,from)=0.5000
# p(it|sweetness,from)=0.5000
# p('s|into,siddhartha)=1.0000
# p(it|thing,from)=1.0000
# p(the|walked,through)=0.7500
# p(a|walked,through)=0.2500
# p(would|with,whom)=0.5000
# p(i|with,whom)=0.5000
# p(,|;,apparently)=1.0000
# p(to|in,talking)=1.0000
# p(the|what,of)=1.0000
# p(masterful|enjoyed,his)=1.0000
# p(the|,,than)=0.1667
# p(to|,,than)=0.1667
# p(obey|,,than)=0.1667
# p(offerings|,,than)=0.1667
# p(learning|,,than)=0.1667
# p(you|,,than)=0.1667
# p(ferry-boat|used,the)=1.0000
# p(passed|meditation,had)=1.0000
# p(friendly|into,his)=0.0714
# p(mind|into,his)=0.0714
# p(eyes|into,his)=0.1429
# p(body|into,his)=0.0714
# p(ear|into,his)=0.0714
# p(service|into,his)=0.0714
# p(boat|into,his)=0.0714
# p(soul|into,his)=0.0714
# p(black|into,his)=0.0714
# p(house|into,his)=0.0714
# p(shop|into,his)=0.0714
# p(mother's|into,his)=0.0714
# p(father|into,his)=0.0714
# p(?|why,not)=1.0000
# p(to|listen,and)=1.0000
# p(out|it,silently)=0.5000
# p(into|it,silently)=0.5000
# p(.|longer,back)=1.0000
# p(had|wise,brahmans)=1.0000
# p(dripping|water,was)=1.0000
# p(of|straw,hut)=1.0000
# p(,|was,green)=1.0000
# p(of|just,outside)=1.0000
# p(of|the,guard)=1.0000
# p(expressed|features,,)=1.0000
# p(the|nameless,,)=1.0000
# p(him|bath,for)=1.0000
# p(,|contracted,pupils)=1.0000
# p(.|gods,together)=1.0000
# p(,|;,rarely)=1.0000
# p(''|songs,,)=1.0000
# p(a|vasudeva,with)=1.0000
# p(this|obey,like)=1.0000
# p(most|your,teachings)=0.2000
# p(perfectly|your,teachings)=0.2000
# p(of|your,teachings)=0.2000
# p(is|your,teachings)=0.2000
# p(.|your,teachings)=0.2000
# p(hopes|plans,or)=1.0000
# p(a|shoes,of)=1.0000
# p(of|off,all)=1.0000
# p(,|falling,leaf)=1.0000
# p(live|we,perhaps)=1.0000
# p(,|by,it)=1.0000
# p(is|possibly,this)=1.0000
# p(an|brahman,as)=1.0000
# p(of|steps,full)=1.0000
# p('s|this,man)=0.2500
# p(,|this,man)=0.2500
# p(was|this,man)=0.2500
# p(had|this,man)=0.2500
# p(?|of,desires)=1.0000
# p(lost|old,,)=0.0833
# p(previous|old,,)=0.0833
# p(''|old,,)=0.0833
# p(tired|old,,)=0.1667
# p(my|old,,)=0.0833
# p(he|old,,)=0.0833
# p(old|old,,)=0.0833
# p(would|old,,)=0.0833
# p(childlike|old,,)=0.0833
# p(torn|old,,)=0.0833
# p(growing|old,,)=0.0833
# p(something|still,felt)=1.0000
# p(of|ship,full)=1.0000
# p(goal|reach,their)=1.0000
# p(swearwords|used,crude)=1.0000
# p(and|into,rain)=1.0000
# p(in|no,delight)=1.0000
# p(audacious|high,and)=1.0000
# p(memory|become,a)=0.0476
# p(part|become,a)=0.0476
# p(merchant|become,a)=0.0476
# p(monk|become,a)=0.0476
# p(bit|become,a)=0.0476
# p(samana|become,a)=0.1429
# p(buddha|become,a)=0.0476
# p(highway-robber|become,a)=0.0476
# p(child|become,a)=0.0476
# p(kamaswami|become,a)=0.0476
# p(man|become,a)=0.0476
# p(god|become,a)=0.0476
# p(ferryman|become,a)=0.0476
# p(common|become,a)=0.0476
# p(shackle|become,a)=0.0476
# p(fool|become,a)=0.0952
# p(childlike|become,a)=0.0476
# p(blossom|become,a)=0.0476
# p(a|man,without)=1.0000
# p(to|was,time)=1.0000
# p(,|you,mean)=0.3333
# p(by|you,mean)=0.3333
# p(.|you,mean)=0.3333
# p(than|different,pace)=1.0000
# p(and|much,doing)=1.0000
# p(,|of,something)=1.0000
# p(teachings|so,venerable)=1.0000
# p(if|awakened,as)=1.0000
# p(''|steps,.)=1.0000
# p(samana|becoming,a)=1.0000
# p(the|mother,of)=1.0000
# p(hair|combed,the)=1.0000
# p(!|:,om)=0.5000
# p(is|:,om)=0.5000
# p(,|every,touch)=1.0000
# p(it|and,that)=0.0769
# p(they|and,that)=0.1538
# p(this|and,that)=0.0769
# p(siddhartha|and,that)=0.0769
# p(there|and,that)=0.0769
# p(,|and,that)=0.0769
# p(my|and,that)=0.0769
# p(i|and,that)=0.0769
# p(he|and,that)=0.2308
# p(every|and,that)=0.0769
# p(in|two,bananas)=1.0000
# p(that|siddhartha,realised)=1.0000
# p(children|ones,of)=1.0000
# p(person|loved,a)=1.0000
# p(his|depths,of)=1.0000
# p(``|spoke,:)=1.0000
# p(he|about,,)=0.3333
# p(this|about,,)=0.3333
# p(i|about,,)=0.3333
# p(a|leaving,with)=1.0000
# p(for|has,lived)=1.0000
# p(obstacle|being,an)=1.0000
# p(both|nothing,and)=0.2500
# p(looked|nothing,and)=0.2500
# p(waited|nothing,and)=0.5000
# p(,|old,age)=1.0000
# p(,|will,return)=1.0000
# p(value|himself,all)=1.0000
# p(for|be,liable)=1.0000
# p(me|please,forgive)=1.0000
# p(would|only,i)=1.0000
# p(stranger|pilgrim,and)=1.0000
# p(myself|have,lost)=1.0000
# p(out|are,working)=1.0000
# p(to|listening,attentively)=0.5000
# p(.|listening,attentively)=0.5000
# ...
# p(himself|vasudeva,lay)=1.0000
# p(would|sick,and)=1.0000
# p(with|,,together)=1.0000
# p(which|a,disgust)=1.0000
# p(ones|with,sky-blue)=1.0000
# p(hearts|with,calm)=1.0000
# p(did|worker,that)=1.0000
# p(,|by,loneliness)=1.0000
# p(,|he,stopped)=0.6667
# p(as|he,stopped)=0.3333
# p(him|had,conducted)=1.0000
# p(the|people,see)=1.0000
# p(!|'s,fornicator)=1.0000
# p(you|why,have)=1.0000
# p(disgust|disappointment,and)=1.0000
# p(priest|until,the)=0.2500
# p(morning|until,the)=0.2500
# p(light|until,the)=0.2500
# p(sound|until,the)=0.2500
# p(to|finished,learning)=0.5000
# p(this|finished,learning)=0.5000
# p(,|:,waiting)=1.0000
# p(life|chosen,the)=1.0000
# p(--|a,circle)=0.5000
# p(.|a,circle)=0.5000
# p(finished|had,now)=0.1667
# p(,|had,now)=0.1667
# p(gone|had,now)=0.1667
# p(woken|had,now)=0.1667
# p(found|had,now)=0.1667
# p(grown|had,now)=0.1667
# p(the|,,with)=0.1346
# p(very|,,with)=0.0192
# p(plans|,,with)=0.0192
# p(women|,,with)=0.0192
# p(crystal|,,with)=0.0192
# p(their|,,with)=0.0192
# p(good|,,with)=0.0192
# p(all|,,with)=0.0192
# p(red|,,with)=0.0192
# p(contracted|,,with)=0.0192
# p(those|,,with)=0.0192
# p(praise|,,with)=0.0192
# p(his|,,with)=0.0769
# p(sky-blue|,,with)=0.0192
# p(love|,,with)=0.0192
# p(green|,,with)=0.0192
# p(dusty|,,with)=0.0385
# p(doubt|,,with)=0.0192
# p(fear|,,with)=0.0192
# p(brawny|,,with)=0.0192
# p(oil|,,with)=0.0192
# p(wide|,,with)=0.0192
# p(fiery|,,with)=0.0192
# p(honours|,,with)=0.0192
# p(whom|,,with)=0.0192
# p(an|,,with)=0.0577
# p(thinking|,,with)=0.0192
# p(this|,,with)=0.0385
# p(fading|,,with)=0.0192
# p(deep|,,with)=0.0192
# p(yearning|,,with)=0.0192
# p(a|,,with)=0.1346
# p(white|,,with)=0.0192
# p(unconsciousness|a,half)=1.0000
# p(bird|the,flying)=1.0000
# p(,|naked,samana)=1.0000
# p(,|not,joking)=1.0000
# p(.|smiled,too)=1.0000
# p(,|mother's,house)=1.0000
# p(art|govinda,the)=1.0000
# p(his|people,brought)=1.0000
# p(name|``,my)=1.0000
# p(sir|going,,)=1.0000
# p(for|of,joy)=0.2500
# p(.|of,joy)=0.2500
# p(and|of,joy)=0.2500
# p(?|of,joy)=0.1250
# p(he|of,joy)=0.1250
# p(he|;,never)=0.5000
# p(before|;,never)=0.5000
# p(brahman|quoth,the)=0.3333
# p(woman|quoth,the)=0.6667
# p(empty|to,become)=0.0500
# p(great|to,become)=0.0500
# p(his|to,become)=0.0500
# p(one|to,become)=0.1500
# p(a|to,become)=0.5000
# p(also|to,become)=0.0500
# p(dead|to,become)=0.0500
# p(like|to,become)=0.1000
# p(voice|perceived,the)=0.3333
# p(whole|perceived,the)=0.3333
# p(teachings|perceived,the)=0.3333
# p(``|him,:)=0.2857
# p(the|him,:)=0.1429
# p(to|him,:)=0.1429
# p(enjoyed|him,:)=0.1429
# p(he|him,:)=0.1429
# p(love|him,:)=0.1429
# p(a|desire,of)=1.0000
# p(,|the,cycle)=0.5000
# p(of|the,cycle)=0.2500
# p(?|the,cycle)=0.1250
# p(which|the,cycle)=0.1250
# p(,|his,shadow)=0.5000
# p(.|his,shadow)=0.5000
# p(apart|set,him)=1.0000
# p(one|satisfied,with)=0.2500
# p(this|satisfied,with)=0.2500
# p(siddhartha|satisfied,with)=0.2500
# p(you|satisfied,with)=0.2500
# p(--|wise,brahmans.)=1.0000
# p(with|,,come)=1.0000
# p(water|the,green)=1.0000
# p(,|of,waiting)=1.0000
# p(by|obtain,salvation)=1.0000
# p(it|have,followed)=1.0000
# p(parted|behind,and)=1.0000
# p(thing|that,other)=1.0000
# p(hut|this,miserable)=0.5000
# p(and|this,miserable)=0.5000
# p(,|'s,arms)=1.0000
# p(enriched|respect,,)=1.0000
# p(the|outside,of)=1.0000
# p(:|he,exclaimed)=0.3333
# p(,|he,exclaimed)=0.3333
# p(lamentingly|he,exclaimed)=0.3333
# p(himself|ways,for)=1.0000
# p(tender|careful,and)=1.0000
# p(to|helps,you)=1.0000
# p(in|with,anxiety)=1.0000
# p(his|had,on)=1.0000
# p(,|than,before)=1.0000
# p(thousand|self,a)=1.0000
# p(.|unsatisfiable,desire)=1.0000
# p(to|layers,,)=1.0000
# p(,|a,wedding)=1.0000
# p(.|much,about)=1.0000
# p(he|,,kindly)=1.0000
# p(house|kept,her)=1.0000
# p(of|a,dreariness)=1.0000
# p(all|deepest,of)=1.0000
# p(long|him,a)=0.1667
# p(bowl|him,a)=0.1667
# p(bit|him,a)=0.1667
# p(task|him,a)=0.1667
# p(look|him,a)=0.1667
# p(piece|him,a)=0.1667
# p(had|herself,,)=1.0000
# p(to|yes,'')=1.0000
# p(.|on,gods)=1.0000
# p(this|agree,with)=1.0000
# p(his|suffered,for)=1.0000
# p(into|anyhow,,)=1.0000
# p(to|event,was)=1.0000
# p(,|this,sight)=1.0000
# p(,|him,here)=0.5000
# p(following|him,here)=0.5000
# p(you're|good,that)=1.0000
# p(that|in,thinking)=0.3333
# p(this|in,thinking)=0.3333
# p(.|in,thinking)=0.3333
# p(.|cling,him)=1.0000
# p(,|``,oh)=0.4000
# p(siddhartha|``,oh)=0.4000
# p(yes|``,oh)=0.2000
# p(among|a,life)=1.0000
# p(,|the,moonlight)=1.0000
# p(that|'ll,see)=0.5000
# p(you|'ll,see)=0.2500
# p(.|'ll,see)=0.2500
# p(is|the,circle)=1.0000
# p(on|have,sat)=0.5000
# p(down|have,sat)=0.5000
# p(my|continue,on)=1.0000
# p(as|this,being)=1.0000
# p(few|with,only)=1.0000
# p(him|grow,in)=1.0000
# p(to|be,superior)=1.0000
# p(,|source,murmured)=1.0000
# p(to|few,dared)=1.0000
# p(exercise|learned,every)=1.0000
# p(rank|of,equal)=1.0000
# p(his|beats,of)=1.0000
# p(,|of,opinions)=0.5000
# p(and|of,opinions)=0.5000
# p(which|was,something)=0.2500
# p(real|was,something)=0.2500
# p(about|was,something)=0.2500
# p(,|was,something)=0.2500
# p(then|but,had)=0.3333
# p(turned|but,had)=0.3333
# p(already|but,had)=0.3333
# p(thousand|entangled,a)=1.0000
# p(on|were,fixed)=1.0000
# p(it|river,about)=1.0000
# p(thin|long,and)=1.0000
# p(a|playing,as)=1.0000
# p(and|the,pumpkin)=1.0000
# p(very|write,,)=0.5000
# p(''|write,,)=0.5000
# p(himself|as,siddhartha)=1.0000
# p(burn|continued,to)=1.0000
# p(emptiness|the,terrible)=1.0000
# p(renounced|parents,,)=1.0000
# p(,|sad,ones)=1.0000
# p(his|--,ended)=1.0000
# p(bored|up,or)=0.5000
# p(like|up,or)=0.5000
# p(,|and,power)=1.0000
# p(ten|of,its)=0.1667
# p(layers|of,its)=0.1667
# p(surface|of,its)=0.1667
# p(drawing|of,its)=0.1667
# p(veins|of,its)=0.1667
# p(own|of,its)=0.1667
# p(.|their,way)=0.2500
# p(to|their,way)=0.2500
# p(as|their,way)=0.2500
# p(with|their,way)=0.2500
# p(by|been,abused)=0.5000
# p(.|been,abused)=0.5000
# p(.|this,incarnation)=1.0000
# p(,|teachings,require)=1.0000
# p(jumped|young,fish)=1.0000
# p(was|her,body)=1.0000
# p(and|of,rage)=1.0000
# p(,|searching,man)=1.0000
# p(!|being,siddhartha)=1.0000
# p(the|positions,and)=0.5000
# p(cramps|positions,and)=0.5000
# p(talk|everyone,would)=1.0000
# p(the|hurrying,,)=0.5000
# p(suffering|hurrying,,)=0.5000
# p(,|thorny,bushes)=1.0000
# p(i|on,when)=1.0000
# p(used|times,always)=1.0000
# p(yet|really,known)=1.0000
# p(.|their,language)=1.0000
# p(sedan-chair|an,ornamental)=1.0000
# p(,|my,consent)=1.0000
# p(,|knew,many)=0.5000
# p(venerable|knew,many)=0.5000
# p(,|deep,fall)=1.0000
# p(it|always,watched)=1.0000
# p(a|entered,,)=1.0000
# p(to|mute,and)=1.0000
# p(a|she,owned)=1.0000
# p(.|often,again)=1.0000
# p(this|matter,,)=1.0000
# p(the|hovered,over)=1.0000
# p(of|woven,out)=1.0000
# p(,|belonged,to)=0.5000
# p(a|belonged,to)=0.5000
# p(voices|has,many)=1.0000
# p(lived|cage,,)=0.5000
# p(took|cage,,)=0.5000
# p(was|separating,factor)=1.0000
# p(them|,,watched)=1.0000
# p(food|remained,without)=1.0000
# p(''|day,.)=1.0000
# p(the|samanas,from)=1.0000
# p(most|ah,,)=0.5000
# p(you|ah,,)=0.5000
# p(smile|a,hidden)=1.0000
# p(all|scene,of)=1.0000
# p(and|this,unity)=1.0000
# p(,|it,heavy)=1.0000
# p(.|the,pursuer)=1.0000
# p(in|last,;)=1.0000
# p(to|,,said)=0.3333
# p(nothing|,,said)=0.6667
# p(merchant|a,rich)=0.1667
# p(house|a,rich)=0.1667
# p(man|a,rich)=0.6667
# p(as|old,vasudeva)=1.0000
# p(garden|given,her)=1.0000
# p(one|far,another)=1.0000
# p(life|current,of)=1.0000
# p(,|be,found)=1.0000
# p(kindness|viciousness,with)=1.0000
# p(up|sound,stirred)=1.0000
# p(the|you,in)=0.5000
# p(here|you,in)=0.2500
# p(any|you,in)=0.2500
# p(happiness|get,this)=1.0000
# p(in|lank,jackals)=1.0000
# p('s|now,it)=0.5000
# p(is|now,it)=0.5000
# p(saw|lustre,,)=1.0000
# p(a|;,like)=1.0000
# p(over|ferry,me)=1.0000
# p(he|profit,,)=1.0000
# p(,|this,here)=1.0000
# p(all|saint,,)=1.0000
# p(gamblers|and,some)=1.0000
# p(:|he,dreamt)=0.5000
# p(.|he,dreamt)=0.5000
# p(sleep|found,no)=0.3333
# p(delight|found,no)=0.3333
# p(teachings|found,no)=0.3333
# p(drown|to,finally)=1.0000
# p(returning|saw,gotama)=1.0000
# p(,|thinking,again)=1.0000
# p(new|thus,siddhartha's)=1.0000
# p(over|and,bent)=1.0000
# p(in|young,siddhartha)=0.3333
# p(was|young,siddhartha)=0.3333
# p(had|young,siddhartha)=0.3333
# p(not|i,will)=0.1818
# p(ask|i,will)=0.0909
# p(become|i,will)=0.0909
# p(begin|i,will)=0.0909
# p(again|i,will)=0.0909
# p(praise|i,will)=0.0909
# p(,|i,will)=0.0909
# p(also|i,will)=0.0909
# p(die|i,will)=0.0909
# p(stand|i,will)=0.0909
# p(which|the,words)=0.1429
# p(came|the,words)=0.1429
# p(through|the,words)=0.1429
# p(,|the,words)=0.1429
# p(:|the,words)=0.1429
# p(are|the,words)=0.1429
# p(of|the,words)=0.1429
# p(in|bathing,it)=1.0000
# p(,|searched,brahman)=1.0000
# p(,|thinking,people)=1.0000
# p(,|be,unchanged)=1.0000
# p(after|and,when)=0.1000
# p(she|and,when)=0.1000
# p(siddhartha|and,when)=0.1000
# p(there|and,when)=0.2000
# p(he|and,when)=0.3000
# p(they|and,when)=0.1000
# p(i|and,when)=0.1000
# p(once|ate,only)=1.0000
# p(much|of,too)=1.0000
# p(any|no,joy)=1.0000
# p(and|sadness,,)=1.0000
# p(their|were,on)=1.0000
# p(good|also,very)=0.5000
# p(much|also,very)=0.5000
# p(reminded|which,wondrously)=1.0000
# p(,|from,sin)=1.0000
# p(reward|the,immaterial)=1.0000
# p(for|'s,looking)=1.0000
# p(bows|returned,the)=0.3333
# p(wish|returned,the)=0.3333
# p(paper|returned,the)=0.3333
# p(foot|travelling,on)=1.0000
# p(to|a,warning)=0.5000
# p(reminder|a,warning)=0.5000
# p(what|'s,doing)=1.0000
# p(,|does,nothing)=1.0000
# p(this|here,from)=1.0000
# p(son|her,little)=1.0000
# p(--|is,dead)=1.0000
# p(garments|white,upper)=1.0000
# p(her|exhausted,by)=1.0000
# p(left|no,oar)=1.0000
# p(,|good,man)=1.0000
# p(you|'ll,leave)=1.0000
# p(without|food,,)=0.1667
# p(even|food,,)=0.1667
# p(to|food,,)=0.1667
# p(of|food,,)=0.3333
# p(and|food,,)=0.1667
# p(taught|how,she)=0.5000
# p(controlled|how,she)=0.5000
# p(see|happy,to)=0.5000
# p(find|happy,to)=0.5000
# p(,|being,awake)=1.0000
# p(the|flow,of)=0.3333
# p(events|flow,of)=0.6667
# p(,|talk,wisely)=1.0000
# p(penetrated|possessed,and)=1.0000
# p(.|'s,memory)=1.0000
# p(for|pilgrim,myself)=1.0000
# p(,|of,hundreds)=1.0000
# p(bath|take,his)=1.0000
# p(''|evening,?)=1.0000
# p(out|been,put)=1.0000
# p(,|there,simultaneously)=1.0000
# p(this|not,oppose)=1.0000
# p(the|slowly,,)=0.1111
# p(``|slowly,,)=0.1111
# p(like|slowly,,)=0.1111
# p(he|slowly,,)=0.2222
# p(among|slowly,,)=0.1111
# p(drop|slowly,,)=0.1111
# p(getting|slowly,,)=0.1111
# p(with|slowly,,)=0.1111
# p(,|suffered,miserably)=1.0000
# p(to|had,seemed)=1.0000
# p(else|--,how)=1.0000
# p(!|a,mouth)=1.0000
# p(all|travelling,at)=1.0000
# p(are|``,they)=1.0000
# p(the|singsong,,)=1.0000
# p(would|but,few)=1.0000
# p(this|also,like)=1.0000
# p(children|all,small)=1.0000
# p(lust|i,needed)=0.5000
# p(sin|i,needed)=0.5000
# p(you|did,n't)=1.0000
# p(,|with,kamaswami)=1.0000
# p(and|this,final)=1.0000
# p(and|proper,merchant)=1.0000
# p(life|her,previous)=1.0000
# p(interested|'m,only)=1.0000
# p(heart|no,tender)=1.0000
# p(at|known,yet)=1.0000
# p(transformation|pondered,his)=1.0000
# p(now|realized,:)=0.5000
# p(this|realized,:)=0.5000
# p(wise|mocking,,)=1.0000
# p(further|go,any)=1.0000
# p(so|pulled,him)=1.0000
# p(grew|where,siddhartha)=1.0000
# p(.|concealed,putrefaction)=1.0000
# p(of|burning,course)=1.0000
# p(in|was,floating)=1.0000
# p(not|words,are)=1.0000
# p(another|to,judge)=1.0000
# p(shook|tiredly,,)=1.0000
# p(animal|plant,or)=1.0000
# p('ve|that,we)=1.0000
# p(to|poor,man)=1.0000
# p(saw|pearls,he)=1.0000
# p(died|she,has)=1.0000
# p(well|water,so)=1.0000
# p(away|twenty,paces)=1.0000
# p(.|buddha,teaching)=1.0000
# p(brahmans|the,wise)=0.1250
# p(men|the,wise)=0.5000
# p(and|the,wise)=0.1250
# p(man|the,wise)=0.2500
# p(,|his,small)=1.0000
# p(the|aware,of)=0.4286
# p(himself|aware,of)=0.1429
# p(too|aware,of)=0.1429
# p(this|aware,of)=0.1429
# p(how|aware,of)=0.1429
# p(learning|'ll,continue)=1.0000
# p(hold|thoughts,caught)=1.0000
# p(he|task,,)=1.0000
# p(his|looking,into)=1.0000
# p(pain|glowing,with)=0.3333
# p(thirst|glowing,with)=0.3333
# p(bliss|glowing,with)=0.3333
# p(of|the,hearts)=1.0000
# p(presenting|cloak,,)=1.0000
# p(.|and,denial)=1.0000
# p(do|you,to)=0.1250
# p(be|you,to)=0.2500
# p(become|you,to)=0.1250
# p(live|you,to)=0.2500
# p(earn|you,to)=0.1250
# p(have|you,to)=0.1250
# p(had|traveller,siddhartha)=1.0000
# p(sparkling|wiggling,and)=1.0000
# p(friends|like,good)=1.0000
# p(soon|and,would)=0.2000
# p(become|and,would)=0.2000
# p(you|and,would)=0.4000
# p(reside|and,would)=0.2000
# p(were|importance,they)=1.0000
# p(the|rocks,,)=0.3333
# p(love|rocks,,)=0.3333
# p(herbs|rocks,,)=0.3333
# p(you|which,keep)=1.0000
# p(a|came,across)=1.0000
# p(to|ask,you)=1.0000
# p(weak|grown,slightly)=1.0000
# p(fled|have,completely)=1.0000
# p((|along,at)=1.0000
# p(for|,,desires)=1.0000
# p(that|flexible,like)=1.0000
# p(before|city,long)=1.0000
# p(,|the,enchantment)=1.0000
# p(,|their,meaninglessness)=1.0000
# p(like|to,emit)=1.0000
# p(,|strongly,living)=1.0000
# p(buzzed|bees,had)=1.0000
# p(a|wisdom,which)=1.0000
# p(,|heard,there)=1.0000
# p(occupied|whom,had)=1.0000
# p(rolled|carrying,the)=1.0000
# p(out|carry,it)=1.0000
# p(for|in,town)=1.0000
# p(.|buzzing,bee)=1.0000
# p(poured|rain,and)=1.0000
# p(,|and,pale)=1.0000
# p(''|once,?)=1.0000
# p(arrow|a,divine)=1.0000
# p(this|something,about)=1.0000
# p(back|was,reflected)=1.0000
# p(for|sitting,here)=1.0000
# p(,|a,source)=0.2500
# p(seemed|a,source)=0.2500
# p(of|a,source)=0.5000
# p(.|forget,that)=1.0000
# p(the|days,of)=0.5000
# p(their|days,of)=0.5000
# p(,|to,trade)=1.0000
# p(,|very,benevolently)=1.0000
# p(any|for,siddhartha)=1.0000
# p(,|world,'')=1.0000
# p(behind|thoughts,lived)=1.0000
# p(at|present,and)=1.0000
# p(the|'re,wearing)=0.5000
# p(a|'re,wearing)=0.5000
# p(such|pilgrimage,in)=1.0000
# p(me|,,let)=0.2500
# p(himself|,,let)=0.0833
# p('s|,,let)=0.1667
# p(his|,,let)=0.0833
# p(him|,,let)=0.3333
# p(us|,,let)=0.0833
# p(in|is,contained)=1.0000
# p(,|right,afterwards)=1.0000
# p(wait|stand,and)=1.0000
# p(always|others,;)=1.0000
# p(,|since,died)=1.0000
# p(,|the,possible)=1.0000
# p(,|his,rice-bowls)=1.0000
# p(which|this,world)=0.1000
# p(has|this,world)=0.1000
# p(?|this,world)=0.1000
# p(,|this,world)=0.2000
# p(here|this,world)=0.1000
# p(of|this,world)=0.3000
# p(i|this,world)=0.1000
# p(those|grief,since)=1.0000
# p(lucky|'ve,been)=0.1250
# p(the|'ve,been)=0.1250
# p(ferried|'ve,been)=0.1250
# p(waiting|'ve,been)=0.2500
# p(my|'ve,been)=0.1250
# p(a|'ve,been)=0.1250
# p(vasudeva|'ve,been)=0.1250
# p(drunk|eaten,and)=1.0000
# p(voices|``,all)=0.5000
# p(i|``,all)=0.5000
# p(,|his,transformation)=1.0000
# p(things|many,pretty)=1.0000
# p(of|the,joys)=1.0000
# p(drawn|like,being)=1.0000
# p(mute|began,the)=1.0000
# p(.|great,attention)=1.0000
# p(!|followed,it)=1.0000
# p(,|of,water)=1.0000
# p(to|first,how)=1.0000
# p(.|one,suffering)=1.0000
# p(strict|became,more)=0.5000
# p(similar|became,more)=0.5000
# p(,|was,stone)=1.0000
# p(world|this,terrible)=1.0000
# p(harm|to,ever)=1.0000
# p(,|of,mockery)=1.0000
# p(distant|,,infinitely)=0.3333
# p(far|,,infinitely)=0.3333
# p(meaningless|,,infinitely)=0.3333
# p(there|when,was)=1.0000
# p(all|over,,)=0.1429
# p(came|over,,)=0.1429
# p(and|over,,)=0.1429
# p(by|over,,)=0.1429
# p(drifted|over,,)=0.1429
# p(that|over,,)=0.1429
# p(i|over,,)=0.1429
# p(would|such,news)=1.0000
# p(he|rice-wine,,)=1.0000
# p(of|all,prayers)=1.0000
# p(his|shall,become)=1.0000
# p(moving|,,smoothly)=1.0000
# p(stomach|love,my)=1.0000
# p(in|and,beats)=1.0000
# p(with|had,agreed)=1.0000
# p(you|'m,asking)=1.0000
# p(some|them,with)=1.0000
# p(interrupted|'',kamala)=1.0000
# p(old|now,seeing)=1.0000
# p(was|the,face)=0.1111
# p(and|the,face)=0.1111
# p(of|the,face)=0.7778
# p(out|monks,went)=1.0000
# p(the|he,played)=0.5000
# p(with|he,played)=0.5000
# p(in|an,end)=0.1667
# p(to|an,end)=0.6667
# p(!|an,end)=0.1667
# p(stronger|',is)=1.0000
# p(,|his,shop)=1.0000
# p(a|offer,him)=1.0000
# p(gullibly|foolishly,and)=1.0000
# p(the|welcome,was)=1.0000
# p(with|done,away)=1.0000
# p(sake|for,the)=0.0750
# p(rest|for,the)=0.0250
# p(permission|for,the)=0.0250
# p(magic|for,the)=0.0250
# p(true|for,the)=0.0250
# p(people|for,the)=0.0250
# p(time|for,the)=0.0250
# p(good|for,the)=0.0250
# p(news|for,the)=0.0250
# p(run-away|for,the)=0.0500
# p(right|for,the)=0.0250
# p(night|for,the)=0.0250
# p(one|for,the)=0.0250
# p(love|for,the)=0.0250
# p(boy|for,the)=0.0500
# p(innumerable|for,the)=0.0250
# p(same|for,the)=0.0250
# p(goal|for,the)=0.0500
# p(pleasure|for,the)=0.0250
# p(river|for,the)=0.0250
# p(first|for,the)=0.0750
# p(teachings|for,the)=0.0500
# p(immaterial|for,the)=0.0250
# p(most|for,the)=0.0250
# p(world|for,the)=0.0500
# p(name|for,the)=0.0250
# p(words|for,the)=0.0250
# p(purpose|for,the)=0.0250
# p(pain|for,the)=0.0250
# p(secret|for,the)=0.0250
# p(path|for,the)=0.0250
# p(it|``,this)=0.1250
# p(one|``,this)=0.1250
# p(brahman|``,this)=0.1250
# p(may|``,this)=0.1250
# p(here|``,this)=0.1250
# p(too|``,this)=0.1250
# p(is|``,this)=0.1250
# p(i|``,this)=0.1250
# p(?|lovely,river)=1.0000
# p(which|pleasure-garden,,)=1.0000
# p(body|and,rotten)=1.0000

# %% [markdown]
# **[Assignment 1]** What about unigram language model? Using the above example code for computing bigram and trigram language models seen if you could implement the unigram language model.

# %% [markdown]
# **[Solution 1]**

# %%
unigram_frequency = nltk.FreqDist(words)
unigram_probability = nltk.ConditionalProbDist(unigram_frequency, nltk.MLEProbDist)
denom = len(words)
all_unigrams = {}
all_unigrams2 = {}
for word in unigram_frequency:
	freq = unigram_frequency[word]
	prob2 = (1.0)*freq/denom
	all_unigrams[word]= prob2
	all_unigrams["p("+word+")"]=prob2
	print ("p("+word+")={0:.4f}".format(prob2))

query = all_unigrams["he"]
print (str(query))
# Out:
# p(the)=0.0233
# p(to)=0.0233
# p(and)=0.0233
# p(everything)=0.0233
# p(loved)=0.0233
# p(in)=0.0465
# p(smile)=0.0233
# p(life)=0.0465
# p(been)=0.0233
# p(,)=0.1163
# p(ground)=0.0233
# p(his)=0.0465
# p(him)=0.0698
# p(touching)=0.0233
# p(was)=0.0233
# p(.)=0.0233
# p(deeply)=0.0233
# p(who)=0.0233
# p(motionlessly)=0.0233
# p(holy)=0.0233
# p(reminded)=0.0233
# p(what)=0.0233
# p(sitting)=0.0233
# p(valuable)=0.0233
# p(of)=0.0233
# p(ever)=0.0465
# p(bowed)=0.0233
# p(before)=0.0233
# p(had)=0.0465
# p(he)=0.0465
# p(whose)=0.0233
# 0.046511627906976744
