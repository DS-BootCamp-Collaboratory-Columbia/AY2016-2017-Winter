# %% [markdown]
# # Basic Concepts in Probability #

# %% [markdown]
# In this lab session we'll focus on implementing and computing basic concepts in probability. More specifically we'll focus on the following three rules from the probability theory:
#
#
# * **Sum rule:**
# $\Large p(X) = \sum_Y{p(X,Y)}$
#
#
#
# * **Product rule (also known as the chain rule):**
# $\Large p(X,Y) = p(Y|X)p(X)$
#
# The elements in the above equations are reffered to as:
# * $\Large p(X,Y)=p(Y,X)$ - Joint probability
# * $\Large p(Y|X)$ - Conditional probability
# If two random variables $X$ and $Y$ are independent of each other then their conditionaly probability $p(X|Y)$ is the same as the marginal $p(X)$.
# * $\Large p(X)$ - Marginal or Prior probability
# Under the sum rule this probability is known as the marginal probability since it is obtained by marganizling or summing out the other variable (Y) in the joint probability $p(X,Y)$.
#
#
#
# * **Bayes' Rule:**
# $\Large p(Y|X) = \frac{p(X,Y)}{p(X)} = \frac{p(X|Y)p(Y)}{p(X)}$
#
#
# Using the sum rule we could further expand the denominator in the Bayes' rule:
#
# $\Large p(Y|X) = \frac{p(X|Y)p(Y)}{p(X)} = \frac{p(X|Y)p(Y)}{\sum_Y{p(X,Y)}}$
#
# The denominator in the Bayes' rule plays an important factor in that it makes sure that the probability values across all Y variables sum to one and therefore it is oftern referred to as the normalizing constant.
# Bayes' rule plays an important role in machine learning. Under this theorem each probability component in the rule has a precise definition and it is referred to as:
#
# * $\Large p(Y|X)$ - Posterior probability
#
# * $\Large p(X|Y)$ - Likelihood
#
# * $\Large p(Y)$ - Prior probability
#
# * $\Large p(X)=\sum_Y{p(X,Y)}$ - Marginalized likelihood
#
# One fundemental use of this rule is in Bayesian model estimation where we have two random variable, the model $M$ and the data sample $D$. We are interested in the most probable model that explaines the data:
#
# $\Large argmax_M{p(M|D)} = argmax_M{\frac{p(D|M)p(M)}{p(D)}}$
#
# The model is selected based on how well it explains the data sample $p(D|M)$ and in general how good of a model it is. The latter information is contained in the prior probability $p(M)$. The marginalizing constant doesn't play an important role in the process of finding the most suitable model as it is computed by marginalizing over all possible models.

# %% [markdown]
# ## Using the Above Rules ##

# %% [markdown]
# Let's start with a simple example. Let's assume that we have two boxes, a red one and a blue one. Let's also assume that both boxes are filled with balls with two colors: black and gold. More specifically, in the red box we have 7 gold and 5 black balls and in the blue box we have 3 gold and 6 black balls.
#
# We could also use this example to depict a situation where we have two cell phone stores from two different mobile operators (e.g. AT&T and Verizon) and both of these stores carry the same smartphone model (balls) that comes in two colors (gold and black).
# ![Two Bins](prob_dist.jpg)
#
# Give that the box is red the probability of choosing a golden ball is:
# $p(C=g|B=r) = \frac{7}{12}=0.583$
#
#
# The probability of choosing a black ball is:
# $p(C=k|B=r) = \frac{5}{12}=0.417$ or:
#
# $p(C=k|B=r)=1-p(C=g|B=r)$

# %% [markdown]
# We could compute the same conditional probabilities for the blue box:
# $p(C=g|B=b) = \frac{3}{9}=0.33$
#
# $p(C=k|B=b) = \frac{6}{9}=0.67$ or:
#
# $p(C=k|B=b)=1-p(C=g|B=b)$

# %% [markdown]
# Let's assume that the probability of choosing the red box is:
# $p(B=r)=\frac{2}{5}=0.4$
#
# Given that a person has picked a golden ball we are assigned with the task of computing the probability that the golden ball was picked from the red box, i.e. $p(B=r|C=g)$. How do we go about computing this probability?

# %% [markdown]
# The alternative description of the problem would be:
# We have the red box depicting the Verizon store and the blue box depicting the AT&T store in our neighborhood. We noticed that our neighbor Mark recently obtained a golden color iPhone and our goal is to compute the probability of Mark purchasing his new phone from the Verizon store. Since the Verizon store is further away from our apartment building compared to the AT&T store, we'll assing the probability of Mark visiting the Verizon store to be $p(Verizon)=0.4$ .

# %% [markdown]
# Let's start by writing down the probability of picking a golden ball $p(C=g)$:
#
# $p(C=g)=p(C=g|B=r)p(B=r)+p(C=g|B=b)P(B=b)$
#
# $p(C=g)=0.583*0.4+0.33*0.6 = 0.233+0.198 = 0.433$

# %% [markdown]
# We then derive the required probability:
#
#
# $\Large p(B=r|C=g)=\frac{p(C=g|B=r)p(B=r)}{p(C=g)}=\frac{0.583*0.4}{0.433}=0.538$

# %% [markdown]
# Let's now implement this computation in python:

# %%
red_box = ['gold', 'gold','gold','gold', 'gold', 'gold','gold','black','black','black','black','black']
blue_box = ['gold', 'gold','gold','black','black','black','black','black','black']

c_gr=0
c_kr=0
for balls in red_box:
    if (balls=='gold'):
        c_gr +=1
    else:
        c_kr+=1

c_gb=0
c_kb=0
for balls in blue_box:
    if (balls=='gold'):
        c_gb +=1
    else:
        c_kb+=1
print("Golden Balls in Red box="+str(c_gr))
print("Black Balls in Red box="+str(c_kr))
print("Golden Balls in Blue box="+str(c_gb))
print("Black Balls in Blue box="+str(c_kb))

p_gr = (1.0)*c_gr/(c_gr+c_kr)
p_kr = 1-p_gr

p_gb = (1.0)*c_gb/(c_gb+c_kb)
p_kb = 1-p_gb

p_r = 0.4
p_b = 1-p_r
p_g = p_gr*p_r+p_gb*p_b
# Out:
# Golden Balls in Red box=7
# Black Balls in Red box=5
# Golden Balls in Blue box=3
# Black Balls in Blue box=6

# %% [markdown]
# **[Assignment 1]** How do we implement $p(B=r\ |\ C=g)$ using the code above?

# %% [markdown]
# **[Solution 1]**

# %%
p_rg = p_r*p_gr/p_g
p_rg
# Out:
# 0.5384615384615385

# %% [markdown]
# ## Working with Datasets ##

# %% [markdown]
# Let's now take a look at the tree census data and the NYPD motor vehicle collision data.

# %% [markdown]
# As in the previous lab session we'll start by loading the two datasets.

# %%
import pandas as pd
tree_data_fn2 = './street_tree_census_data/2015_Street_Tree_Census_-_Tree_Data.tsv'
tree_data2 = pd.read_csv(tree_data_fn2, delimiter='\t')
tree_data2.dtypes
# Out:
# tree_id         int64
# block_id        int64
# created_at     object
# tree_dbh        int64
# stump_diam      int64
# curb_loc       object
# status         object
# health         object
# spc_latin      object
# spc_common     object
# steward        object
# guards         object
# sidewalk       object
# user_type      object
# problems       object
# root_stone     object
# root_grate     object
# root_other     object
# trunk_wire     object
# trnk_light     object
# trnk_other     object
# brch_light     object
# brch_shoe      object
# brch_other     object
# address        object
# zipcode       float64
# zip_city       object
# cb_num        float64
# borocode        int64
# boroname       object
# cncldist        int64
# st_assem        int64
# st_senate     float64
# nta            object
# nta_name       object
# boro_ct         int64
# state          object
# latitude      float64
# longitude     float64
# x_sp          float64
# y_sp          float64
# dtype: object

# %%
coll_data_fn = './NYPD_Motor_Vehicle_Collisions.tsv'
coll_data = pd.read_csv(coll_data_fn, delimiter='\t')
coll_data
# Out:
#               DATE   TIME        BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 0       08/25/2015  19:00            NaN       NaN  40.732941 -73.920382
# 1       07/27/2012  22:35            NaN       NaN        NaN        NaN
# 2       05/17/2014   0:45            NaN       NaN        NaN        NaN
# 3       11/10/2016  15:11            NaN       NaN        NaN        NaN
# 4       05/11/2016  14:01       BROOKLYN   11217.0  40.685885 -73.973376
# 5       05/11/2016  14:05      MANHATTAN   10016.0  40.750218 -73.979056
# 6       05/11/2016  14:05         QUEENS   11435.0        NaN        NaN
# 7       05/11/2016  14:07            NaN       NaN        NaN        NaN
# 8       05/11/2016  14:15          BRONX   10454.0  40.809060 -73.907538
# 9       05/11/2016  14:15          BRONX   10468.0  40.869834 -73.898740
# 10      05/11/2016  14:15            NaN       NaN        NaN        NaN
# 11      05/11/2016  14:19      MANHATTAN   10018.0  40.755330 -73.991179
# 12      05/11/2016  14:20      MANHATTAN   10016.0  40.748366 -73.980403
# 13      04/16/2016   4:13            NaN       NaN  40.767373 -73.950057
# 14      04/16/2016   4:22            NaN       NaN        NaN        NaN
# 15      11/10/2016  16:11          BRONX   10458.0  40.859874 -73.893217
# 16      11/10/2016  16:11          BRONX   10467.0  40.878745 -73.872545
# 17      11/10/2016  16:11       BROOKLYN   11208.0  40.662514 -73.872007
# 18      11/10/2016  17:11       BROOKLYN   11215.0  40.666845 -73.994860
# 19      11/10/2016   6:11          BRONX   10462.0        NaN        NaN
# 20      05/11/2016  14:23       BROOKLYN   11208.0  40.680015 -73.877428
# 21      05/11/2016  14:30       BROOKLYN   11234.0  40.616758 -73.937873
# 22      05/11/2016  14:30      MANHATTAN   10024.0  40.784975 -73.982638
# 23      05/11/2016  14:30            NaN       NaN  40.618213 -73.897273
# 24      05/11/2016  14:36            NaN       NaN  40.846182 -73.929245
# 25      05/11/2016  14:36            NaN       NaN        NaN        NaN
# 26      05/11/2016  14:39         QUEENS   11423.0  40.720903 -73.776366
# 27      05/11/2016  15:00  STATEN ISLAND   10310.0  40.624863 -74.126231
# 28      05/11/2016  15:00            NaN       NaN        NaN        NaN
# 29      05/11/2016  15:30      MANHATTAN   10025.0  40.808231 -73.966532
# ...            ...    ...            ...       ...        ...        ...
# 940295  07/11/2012   9:00            NaN       NaN  40.746107 -73.766791
# 940296  07/11/2012   9:30            NaN       NaN        NaN        NaN
# 940297  07/10/2012  12:00            NaN       NaN        NaN        NaN
# 940298  07/10/2012  18:00            NaN       NaN        NaN        NaN
# 940299  07/10/2012  20:52            NaN       NaN        NaN        NaN
# 940300  07/09/2012  13:45            NaN       NaN        NaN        NaN
# 940301  07/09/2012   4:31            NaN       NaN        NaN        NaN
# 940302  07/08/2012  22:50            NaN       NaN        NaN        NaN
# 940303  07/08/2012   2:35            NaN       NaN  40.835486 -73.949394
# 940304  07/07/2012  13:05            NaN       NaN        NaN        NaN
# 940305  07/07/2012  14:40            NaN       NaN        NaN        NaN
# 940306  07/07/2012  19:30            NaN       NaN        NaN        NaN
# 940307  07/07/2012  23:10            NaN       NaN  40.727873 -73.929122
# 940308  07/06/2012   0:53            NaN       NaN        NaN        NaN
# 940309  07/05/2012  15:43            NaN       NaN        NaN        NaN
# 940310  07/05/2012  16:30            NaN       NaN  40.767894 -73.837995
# 940311  07/04/2012   9:15            NaN       NaN        NaN        NaN
# 940312  07/03/2012   0:05            NaN       NaN        NaN        NaN
# 940313  07/03/2012  12:35       BROOKLYN   11210.0  40.629166 -73.947326
# 940314  07/03/2012  16:30            NaN       NaN        NaN        NaN
# 940315  07/03/2012  17:00            NaN       NaN        NaN        NaN
# 940316  07/03/2012  21:05            NaN       NaN        NaN        NaN
# 940317  07/02/2012  21:37            NaN       NaN        NaN        NaN
# 940318  07/01/2012  21:55         QUEENS   11368.0  40.753565 -73.870695
# 940319  07/01/2012   4:44      MANHATTAN   10001.0  40.746659 -73.990068
# 940320  07/01/2012   7:00            NaN       NaN        NaN        NaN
# 940321  07/01/2012   9:15       BROOKLYN   11233.0  40.675380 -73.908196
# 940322  07/01/2012   9:15         QUEENS   11421.0  40.696308 -73.851549
# 940323  07/01/2012   9:15         QUEENS   11429.0  40.711860 -73.735538
# 940324  07/01/2012   9:15  STATEN ISLAND   10310.0  40.634748 -74.112253
#
#                          LOCATION        ON STREET NAME  \
# 0       (40.7329414, -73.9203819)                   NaN
# 1                             NaN                   NaN
# 2                             NaN   PENNSYLVANIA AVENUE
# 3                             NaN         MONROE STREET
# 4       (40.6858851, -73.9733756)         FULTON STREET
# 5         (40.750218, -73.979056)        EAST 39 STREET
# 6                             NaN                   NaN
# 7                             NaN                   NaN
# 8        (40.8090601, -73.907538)       EAST 144 STREET
# 9       (40.8698344, -73.8987397)                   NaN
# 10                            NaN       WESTCHESTER AVE
# 11      (40.7553303, -73.9911785)              8 AVENUE
# 12      (40.7483655, -73.9804027)        EAST 36 STREET
# 13       (40.767373, -73.9500574)        EAST 68 STREET
# 14                            NaN         BORDEN AVENUE
# 15      (40.8598744, -73.8932165)        WEBSTER AVENUE
# 16      (40.8787451, -73.8725452)    EAST GUN HILL ROAD
# 17      (40.6625139, -73.8720068)        WORTMAN AVENUE
# 18      (40.6668449, -73.9948598)              3 AVENUE
# 19                            NaN                   NaN
# 20       (40.680015, -73.8774282)       ATLANTIC AVENUE
# 21      (40.6167578, -73.9378735)              AVENUE P
# 22       (40.7849752, -73.982638)      WEST 79TH STREET
# 23       (40.6182127, -73.897273)         BERGAN AVENUE
# 24      (40.8461823, -73.9292446)                   NaN
# 25                            NaN                   NaN
# 26      (40.7209028, -73.7763657)                   NaN
# 27      (40.6248628, -74.1262315)         EGBERT AVENUE
# 28                            NaN                   NaN
# 29      (40.8082305, -73.9665319)       WEST 115 STREET
# ...                           ...                   ...
# 940295   (40.746107, -73.7667908)                   NaN
# 940296                        NaN                   NaN
# 940297                        NaN     ASTORIA BOULEVARD
# 940298                        NaN         KERMIT AVENUE
# 940299                        NaN                   NaN
# 940300                        NaN           PARK AVENUE
# 940301                        NaN                   NaN
# 940302                        NaN                   NaN
# 940303  (40.8354859, -73.9493936)                   NaN
# 940304                        NaN                   NaN
# 940305                        NaN       EAST 135 STREET
# 940306                        NaN    CASTLE HILL AVENUE
# 940307   (40.727873, -73.9291223)                   NaN
# 940308                        NaN                   NaN
# 940309                        NaN                   NaN
# 940310  (40.7678942, -73.8379954)                   NaN
# 940311                        NaN           BAY PARKWAY
# 940312                        NaN                   NaN
# 940313   (40.6291662, -73.947326)              AVENUE I
# 940314                        NaN                   NaN
# 940315                        NaN                   NaN
# 940316                        NaN        MURDOCK AVENUE
# 940317                        NaN  PELHAM PARKWAY SOUTH
# 940318  (40.7535645, -73.8706949)             97 STREET
# 940319  (40.7466595, -73.9900681)              6 AVENUE
# 940320                        NaN       BEACH 54 STREET
# 940321  (40.6753803, -73.9081956)        PACIFIC STREET
# 940322  (40.6963077, -73.8515486)             94 STREET
# 940323  (40.7118601, -73.7355383)            219 STREET
# 940324  (40.6347476, -74.1122528)      CASTLETON AVENUE
#
#                CROSS STREET NAME            OFF STREET NAME  \
# 0                            NaN                        NaN
# 1                            NaN                        NaN
# 2               RIVERDALE AVENUE                        NaN
# 3                            NaN                        NaN
# 4            SOUTH OXFORD STREET                        NaN
# 5                    PARK AVENUE                        NaN
# 6                            NaN  138-19    HILLSIDE AVENUE
# 7          WHITESTONE EXPRESSWAY                        NaN
# 8             SOUTHERN BOULEVARD                        NaN
# 9                            NaN      2756 RESERVOIR AVENUE
# 10                           NaN                        NaN
# 11                WEST 39 STREET                        NaN
# 12                   PARK AVENUE                        NaN
# 13                           NaN                        NaN
# 14                   58TH STREET                        NaN
# 15               EAST 188 STREET                        NaN
# 16                DECATUR AVENUE                        NaN
# 17                MONTAUK AVENUE                        NaN
# 18               PROSPECT AVENUE                        NaN
# 19                           NaN     880       BRADY AVENUE
# 20                  LOGAN STREET                        NaN
# 21                EAST 37 STREET                        NaN
# 22               RIVERSIDE DRIVE                        NaN
# 23                           NaN                        NaN
# 24                           NaN                        NaN
# 25                           NaN                        NaN
# 26                           NaN           85-89 188 STREET
# 27              GREENLEAF AVENUE                        NaN
# 28                     BELT PKWY                        NaN
# 29               RIVERSIDE DRIVE                        NaN
# ...                          ...                        ...
# 940295                       NaN                        NaN
# 940296                       NaN                        NaN
# 940297                 31 STREET                        NaN
# 940298          PARKINSON AVENUE                        NaN
# 940299                       NaN                        NaN
# 940300               HALL STREET                        NaN
# 940301                       NaN                        NaN
# 940302                       NaN                        NaN
# 940303                       NaN                        NaN
# 940304                       NaN                        NaN
# 940305                  3 AVENUE                        NaN
# 940306        WESTCHESTER AVENUE                        NaN
# 940307                       NaN                        NaN
# 940308                       NaN                        NaN
# 940309                       NaN                        NaN
# 940310                       NaN                        NaN
# 940311             SHORE PARKWAY                        NaN
# 940312                       NaN                        NaN
# 940313           NOSTRAND AVENUE                        NaN
# 940314                       NaN                        NaN
# 940315                       NaN                        NaN
# 940316           EAST 242 STREET                        NaN
# 940317            HOLLAND AVENUE                        NaN
# 940318                 35 AVENUE                        NaN
# 940319            WEST 29 STREET                        NaN
# 940320  ROCKAWAY BEACH BOULEVARD                        NaN
# 940321           EASTERN PARKWAY                        NaN
# 940322                   85 ROAD                        NaN
# 940323                104 AVENUE                        NaN
# 940324             BEMENT AVENUE                        NaN
#
#                ...          CONTRIBUTING FACTOR VEHICLE 2  \
# 0              ...                            Unspecified
# 1              ...                            Unspecified
# 2              ...                                    NaN
# 3              ...                            Unspecified
# 4              ...                            Unspecified
# 5              ...                            Unspecified
# 6              ...                            Unspecified
# 7              ...                            Unspecified
# 8              ...                            Unspecified
# 9              ...                            Unspecified
# 10             ...                            Unspecified
# 11             ...                            Unspecified
# 12             ...                            Unspecified
# 13             ...                        Fatigued/Drowsy
# 14             ...                                    NaN
# 15             ...                            Unspecified
# 16             ...                            Unspecified
# 17             ...                            Unspecified
# 18             ...                            Unspecified
# 19             ...                                    NaN
# 20             ...                            Unspecified
# 21             ...                            Unspecified
# 22             ...                                    NaN
# 23             ...                            Unspecified
# 24             ...                            Unspecified
# 25             ...                            Unspecified
# 26             ...                            Unspecified
# 27             ...                            Unspecified
# 28             ...                            Unspecified
# 29             ...                            Unspecified
# ...            ...                                    ...
# 940295         ...                            Unspecified
# 940296         ...                            Unspecified
# 940297         ...                            Unspecified
# 940298         ...                            Unspecified
# 940299         ...                            Unspecified
# 940300         ...                                    NaN
# 940301         ...                                    NaN
# 940302         ...                                    NaN
# 940303         ...                                    NaN
# 940304         ...                            Unspecified
# 940305         ...                            Unspecified
# 940306         ...                                    NaN
# 940307         ...                            Unspecified
# 940308         ...                            Unspecified
# 940309         ...                            Unspecified
# 940310         ...                                    NaN
# 940311         ...                                    NaN
# 940312         ...                            Unspecified
# 940313         ...                                    NaN
# 940314         ...                                    NaN
# 940315         ...                            Unspecified
# 940316         ...                            Unspecified
# 940317         ...                            Unspecified
# 940318         ...                                    NaN
# 940319         ...                                    NaN
# 940320         ...                            Unspecified
# 940321         ...                            Unspecified
# 940322         ...                            Unspecified
# 940323         ...                            Unspecified
# 940324         ...                            Unspecified
#
#         CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 0                                 NaN                            NaN
# 1                                 NaN                            NaN
# 2                                 NaN                            NaN
# 3                                 NaN                            NaN
# 4                                 NaN                            NaN
# 5                                 NaN                            NaN
# 6                                 NaN                            NaN
# 7                                 NaN                            NaN
# 8                                 NaN                            NaN
# 9                                 NaN                            NaN
# 10                                NaN                            NaN
# 11                                NaN                            NaN
# 12                                NaN                            NaN
# 13                    Fatigued/Drowsy                            NaN
# 14                                NaN                            NaN
# 15                                NaN                            NaN
# 16                                NaN                            NaN
# 17                                NaN                            NaN
# 18                                NaN                            NaN
# 19                                NaN                            NaN
# 20                                NaN                            NaN
# 21                                NaN                            NaN
# 22                                NaN                            NaN
# 23                                NaN                            NaN
# 24                                NaN                            NaN
# 25                                NaN                            NaN
# 26                                NaN                            NaN
# 27                                NaN                            NaN
# 28                                NaN                            NaN
# 29                                NaN                            NaN
# ...                               ...                            ...
# 940295                            NaN                            NaN
# 940296                            NaN                            NaN
# 940297                            NaN                            NaN
# 940298                            NaN                            NaN
# 940299                            NaN                            NaN
# 940300                            NaN                            NaN
# 940301                            NaN                            NaN
# 940302                            NaN                            NaN
# 940303                            NaN                            NaN
# 940304                            NaN                            NaN
# 940305                            NaN                            NaN
# 940306                            NaN                            NaN
# 940307                            NaN                            NaN
# 940308                            NaN                            NaN
# 940309                            NaN                            NaN
# 940310                            NaN                            NaN
# 940311                            NaN                            NaN
# 940312                            NaN                            NaN
# 940313                            NaN                            NaN
# 940314                            NaN                            NaN
# 940315                            NaN                            NaN
# 940316                            NaN                            NaN
# 940317                            NaN                            NaN
# 940318                            NaN                            NaN
# 940319                            NaN                            NaN
# 940320                            NaN                            NaN
# 940321                            NaN                            NaN
# 940322                            NaN                            NaN
# 940323                            NaN                            NaN
# 940324                            NaN                            NaN
#
#         CONTRIBUTING FACTOR VEHICLE 5  UNIQUE KEY  \
# 0                                 NaN     3284922
# 1                                 NaN     2833714
# 2                                 NaN      336679
# 3                                 NaN     3559084
# 4                                 NaN     3440855
# 5                                 NaN     3439718
# 6                                 NaN     3440233
# 7                                 NaN     3440245
# 8                                 NaN     3439814
# 9                                 NaN     3440604
# 10                                NaN     3440548
# 11                                NaN     3439704
# 12                                NaN     3439719
# 13                                NaN     3408932
# 14                                NaN     3425902
# 15                                NaN     3557464
# 16                                NaN     3557999
# 17                                NaN     3559576
# 18                                NaN     3558765
# 19                                NaN     3558014
# 20                                NaN     3441592
# 21                                NaN     3442412
# 22                                NaN     3440430
# 23                                NaN     3440649
# 24                                NaN     3443131
# 25                                NaN     3443130
# 26                                NaN     3440995
# 27                                NaN     3442901
# 28                                NaN     3440299
# 29                                NaN     3442088
# ...                               ...         ...
# 940295                            NaN     3078747
# 940296                            NaN     2912127
# 940297                            NaN      272667
# 940298                            NaN      293261
# 940299                            NaN     2918666
# 940300                            NaN      191585
# 940301                            NaN     2879038
# 940302                            NaN     3016748
# 940303                            NaN     2872826
# 940304                            NaN     3121385
# 940305                            NaN       72655
# 940306                            NaN       80874
# 940307                            NaN     3044674
# 940308                            NaN     2867735
# 940309                            NaN     2864071
# 940310                            NaN     3055606
# 940311                            NaN      121421
# 940312                            NaN     2896734
# 940313                            NaN      125685
# 940314                            NaN     2896732
# 940315                            NaN     3096749
# 940316                            NaN       94897
# 940317                            NaN      102728
# 940318                            NaN      279645
# 940319                            NaN       26084
# 940320                            NaN      202242
# 940321                            NaN      160103
# 940322                            NaN      203690
# 940323                            NaN      219394
# 940324                            NaN      284646
#
#                    VEHICLE TYPE CODE 1             VEHICLE TYPE CODE 2  \
# 0                    PASSENGER VEHICLE                            TAXI
# 1                    PASSENGER VEHICLE               PASSENGER VEHICLE
# 2                                  NaN                             NaN
# 3                    PASSENGER VEHICLE                             NaN
# 4                    PASSENGER VEHICLE               PASSENGER VEHICLE
# 5                    PASSENGER VEHICLE               PASSENGER VEHICLE
# 6                    PASSENGER VEHICLE               PASSENGER VEHICLE
# 7                    PASSENGER VEHICLE               PASSENGER VEHICLE
# 8                    PASSENGER VEHICLE               PASSENGER VEHICLE
# 9                    PASSENGER VEHICLE                             NaN
# 10                   PASSENGER VEHICLE                             NaN
# 11                   PASSENGER VEHICLE               PASSENGER VEHICLE
# 12                   PASSENGER VEHICLE               PASSENGER VEHICLE
# 13                   PASSENGER VEHICLE               PASSENGER VEHICLE
# 14                                 NaN                             NaN
# 15                   PASSENGER VEHICLE                             NaN
# 16       SPORT UTILITY / STATION WAGON                             NaN
# 17                                TAXI               PASSENGER VEHICLE
# 18       SPORT UTILITY / STATION WAGON                   PICK-UP TRUCK
# 19                   PASSENGER VEHICLE                             NaN
# 20                   PASSENGER VEHICLE               PASSENGER VEHICLE
# 21                   PASSENGER VEHICLE                         BICYCLE
# 22                   PASSENGER VEHICLE                             NaN
# 23                   PASSENGER VEHICLE               PASSENGER VEHICLE
# 24                   PASSENGER VEHICLE                             NaN
# 25                   PASSENGER VEHICLE                             NaN
# 26                   PASSENGER VEHICLE               PASSENGER VEHICLE
# 27                   PASSENGER VEHICLE                           OTHER
# 28                   PASSENGER VEHICLE               PASSENGER VEHICLE
# 29                   PASSENGER VEHICLE               PASSENGER VEHICLE
# ...                                ...                             ...
# 940295               PASSENGER VEHICLE               PASSENGER VEHICLE
# 940296               PASSENGER VEHICLE               PASSENGER VEHICLE
# 940297               PASSENGER VEHICLE                   PICK-UP TRUCK
# 940298                           OTHER               PASSENGER VEHICLE
# 940299               PASSENGER VEHICLE  LARGE COM VEH(6 OR MORE TIRES)
# 940300               PASSENGER VEHICLE                             NaN
# 940301   SPORT UTILITY / STATION WAGON                             NaN
# 940302                      MOTORCYCLE                             NaN
# 940303                           OTHER                             NaN
# 940304               PASSENGER VEHICLE               PASSENGER VEHICLE
# 940305                   PICK-UP TRUCK   SPORT UTILITY / STATION WAGON
# 940306               PASSENGER VEHICLE                             NaN
# 940307   SPORT UTILITY / STATION WAGON                         UNKNOWN
# 940308   SPORT UTILITY / STATION WAGON                            TAXI
# 940309                           OTHER               PASSENGER VEHICLE
# 940310               PASSENGER VEHICLE                             NaN
# 940311   SPORT UTILITY / STATION WAGON                             NaN
# 940312               PASSENGER VEHICLE                         UNKNOWN
# 940313                             VAN                             NaN
# 940314  LARGE COM VEH(6 OR MORE TIRES)                             NaN
# 940315               PASSENGER VEHICLE               PASSENGER VEHICLE
# 940316               PASSENGER VEHICLE               PASSENGER VEHICLE
# 940317               PASSENGER VEHICLE                         UNKNOWN
# 940318               PASSENGER VEHICLE                             NaN
# 940319   SPORT UTILITY / STATION WAGON                             NaN
# 940320               PASSENGER VEHICLE                             VAN
# 940321   SPORT UTILITY / STATION WAGON   SPORT UTILITY / STATION WAGON
# 940322               PASSENGER VEHICLE               PASSENGER VEHICLE
# 940323               PASSENGER VEHICLE                         UNKNOWN
# 940324               PASSENGER VEHICLE               PASSENGER VEHICLE
#
#         VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                       NaN                 NaN                 NaN
# 1                       NaN                 NaN                 NaN
# 2                       NaN                 NaN                 NaN
# 3                       NaN                 NaN                 NaN
# 4                       NaN                 NaN                 NaN
# 5                       NaN                 NaN                 NaN
# 6                       NaN                 NaN                 NaN
# 7                       NaN                 NaN                 NaN
# 8                       NaN                 NaN                 NaN
# 9                       NaN                 NaN                 NaN
# 10                      NaN                 NaN                 NaN
# 11                      NaN                 NaN                 NaN
# 12                      NaN                 NaN                 NaN
# 13        PASSENGER VEHICLE                 NaN                 NaN
# 14                      NaN                 NaN                 NaN
# 15                      NaN                 NaN                 NaN
# 16                      NaN                 NaN                 NaN
# 17                      NaN                 NaN                 NaN
# 18                      NaN                 NaN                 NaN
# 19                      NaN                 NaN                 NaN
# 20                      NaN                 NaN                 NaN
# 21                      NaN                 NaN                 NaN
# 22                      NaN                 NaN                 NaN
# 23                      NaN                 NaN                 NaN
# 24                      NaN                 NaN                 NaN
# 25                      NaN                 NaN                 NaN
# 26                      NaN                 NaN                 NaN
# 27                      NaN                 NaN                 NaN
# 28                      NaN                 NaN                 NaN
# 29                      NaN                 NaN                 NaN
# ...                     ...                 ...                 ...
# 940295                  NaN                 NaN                 NaN
# 940296                  NaN                 NaN                 NaN
# 940297                  NaN                 NaN                 NaN
# 940298                  NaN                 NaN                 NaN
# 940299                  NaN                 NaN                 NaN
# 940300                  NaN                 NaN                 NaN
# 940301                  NaN                 NaN                 NaN
# 940302                  NaN                 NaN                 NaN
# 940303                  NaN                 NaN                 NaN
# 940304                  NaN                 NaN                 NaN
# 940305                  NaN                 NaN                 NaN
# 940306                  NaN                 NaN                 NaN
# 940307                  NaN                 NaN                 NaN
# 940308                  NaN                 NaN                 NaN
# 940309                  NaN                 NaN                 NaN
# 940310                  NaN                 NaN                 NaN
# 940311                  NaN                 NaN                 NaN
# 940312                  NaN                 NaN                 NaN
# 940313                  NaN                 NaN                 NaN
# 940314                  NaN                 NaN                 NaN
# 940315                  NaN                 NaN                 NaN
# 940316                  NaN                 NaN                 NaN
# 940317                  NaN                 NaN                 NaN
# 940318                  NaN                 NaN                 NaN
# 940319                  NaN                 NaN                 NaN
# 940320                  NaN                 NaN                 NaN
# 940321                  NaN                 NaN                 NaN
# 940322                  NaN                 NaN                 NaN
# 940323                  NaN                 NaN                 NaN
# 940324                  NaN                 NaN                 NaN
#
# [940325 rows x 29 columns]

# %% [markdown]
# Since the NYPD collision data doesn't come with a description of the variables we'll look into the headers of each colum.

# %%
coll_data.dtypes
# Out:
# DATE                              object
# TIME                              object
# BOROUGH                           object
# ZIP CODE                         float64
# LATITUDE                         float64
# LONGITUDE                        float64
# LOCATION                          object
# ON STREET NAME                    object
# CROSS STREET NAME                 object
# OFF STREET NAME                   object
# NUMBER OF PERSONS INJURED          int64
# NUMBER OF PERSONS KILLED           int64
# NUMBER OF PEDESTRIANS INJURED      int64
# NUMBER OF PEDESTRIANS KILLED       int64
# NUMBER OF CYCLIST INJURED          int64
# NUMBER OF CYCLIST KILLED           int64
# NUMBER OF MOTORIST INJURED         int64
# NUMBER OF MOTORIST KILLED          int64
# CONTRIBUTING FACTOR VEHICLE 1     object
# CONTRIBUTING FACTOR VEHICLE 2     object
# CONTRIBUTING FACTOR VEHICLE 3     object
# CONTRIBUTING FACTOR VEHICLE 4     object
# CONTRIBUTING FACTOR VEHICLE 5     object
# UNIQUE KEY                         int64
# VEHICLE TYPE CODE 1               object
# VEHICLE TYPE CODE 2               object
# VEHICLE TYPE CODE 3               object
# VEHICLE TYPE CODE 4               object
# VEHICLE TYPE CODE 5               object
# dtype: object

# %% [markdown]
# Spend some time to look into the two data collections and decide on what aspect of the data you would like to model. Either start working on computing the probabilities based on your own task or follow the examples below.

# %% [markdown]
# ### Example 1 ###

# %% [markdown]
# In this example we'll compute the probability of having seen a particular tree species in one of the five NYC boroughs. More specifically let's assume that we are taking a walk with our friend in Riverside park. We notice a northern red oak tree. As we admire its color, out friend remembers that she may have seen this tree in one of the other boroughs in this past month. She thinks that most likely she's seen this tree species in Brooklyn where her boyfriend lives but she is not sure about it. Given the tree census data and given that our friend has spend 10 days in Brooklyn, 15 days in Manhattan and the remaining 6 days in the other 3 boroughs in the past months what is the probability that she has seen this tree in each of the five boroughs?

# %% [markdown]
# **[Assingment 2]** Spend some time to formulate the solution of the problem and derive the required probability expressions.

# %% [markdown]
# **[Assingment 2 Hint]**
# We are tasked to compute the following conditional probabilities:
#
# $p(Borough\ |\ northern\ red\ oak)$,
#
# given that the person has visited all five boroughs within the past month with the following probability:
#
# $p(Borough=Brooklyn)=\frac{10}{31}$
#
# $p(Borough=Manhattan)=\frac{15}{31}$
#
# $p(Borough=Staten\ Island)=\frac{2}{31}$
#
# $p(Borough=Bronx)=\frac{2}{31}$
#
# $p(Borough=Queens)=\frac{2}{31}$

# %% [markdown]
# **[Solution 2]** We are tasked to compute the following conditional probabilities:
#
# $p(Borough\ |\ northern\ red\ oak)$,
#
# given that the person has visited all five boroughs within the past month with the following probability:
#
# $p(Borough=Brooklyn)=\frac{10}{31}$
#
# $p(Borough=Manhattan)=\frac{15}{31}$
#
# $p(Borough=Staten\ Island)=\frac{2}{31}$
#
# $p(Borough=Bronx)=\frac{2}{31}$
#
# $p(Borough=Queens)=\frac{2}{31}$
#
# We use Bayes' Rule to derive the required probabilty:
#
# $\Large p(northern\ red\ oak\ |\ Borough)\ =\ \frac{p(northern\ red\ oak\ |\ Borough)\ p(Borough)}{\sum_{Borough}{p(northern\ red\ oak\ |\ Borough)}}$

# %% [markdown]
# **[Assignment 3]** Implement the above solution and compute the probability

# %% [markdown]
# **[Solution 3]**
#
# First compute the probability that our friend has been in one of the 5 boroughs in the past month:

# %%
p_brooklyn = 10.0/31
p_manhattan = 15.0/31
p_queens = 2.0/31
p_bronx = 2.0/31
p_si = 2.0/31

print (p_brooklyn)
# Out:
# 0.322580645161

# %%
boro_spcs=tree_data2[['boroname','spc_common']]
boro_counts = pd.value_counts(boro_spcs['boroname'])
boro_counts
# Out:
# Queens           184137
# Brooklyn         115783
# Staten Island     62971
# Bronx             46075
# Manhattan         37697
# Little Neck           1
# Name: boroname, dtype: int64

# %%
boro_nro = boro_spcs[boro_spcs['spc_common']=='northern red oak']
nro_counts = pd.value_counts(boro_nro['boroname'])
nro_counts
# Out:
# Queens           2049
# Brooklyn         1780
# Bronx             859
# Manhattan         629
# Staten Island     369
# Name: boroname, dtype: int64

# %%
p_nro_brooklyn = (1.0)*nro_counts['Brooklyn']/boro_counts['Brooklyn']
print ("p(nro|brooklyn)="+str(p_nro_brooklyn))
p_nro_queens = (1.0)*nro_counts['Queens']/boro_counts['Queens']
print ("p(nro|queens)="+str(p_nro_queens))
p_nro_bronx = (1.0)*nro_counts['Bronx']/boro_counts['Bronx']
print ("p(nro|bronx)="+str(p_nro_bronx))
p_nro_si = (1.0)*nro_counts['Staten Island']/boro_counts['Staten Island']
print ("p(nro|si)="+str(p_nro_si))
p_nro_manhattan = (1.0)*nro_counts['Manhattan']/boro_counts['Manhattan']
print ("p(nro|manhattan)="+str(p_nro_manhattan))
# Out:
# p(nro|brooklyn)=0.015373586796
# p(nro|queens)=0.011127584353
# p(nro|bronx)=0.0186435160065
# p(nro|si)=0.00585984024392
# p(nro|manhattan)=0.0166856779054

# %%
p_nro = p_nro_brooklyn*p_brooklyn+p_nro_queens*p_queens+p_nro_bronx*p_bronx+p_nro_si*p_si+p_nro_manhattan*p_manhattan
p_nro
# Out:
# 0.01533170702411999

# %%
p_brooklyn_nro = (1.0)*(p_nro_brooklyn*p_brooklyn)/p_nro
print ("p(brooklyn|nro)="+str(p_brooklyn_nro))
p_queens_nro = (1.0)*(p_nro_queens*p_queens)/p_nro
print ("p(queens|nro)="+str(p_queens_nro))
p_bronx_nro = (1.0)*(p_nro_bronx*p_bronx)/p_nro
print ("p(bronx|nro)="+str(p_bronx_nro))
p_si_nro = (1.0)*(p_nro_si*p_si)/p_nro
print ("p(si|nro)="+str(p_si_nro))
p_manhattan_nro = (1.0)*(p_nro_manhattan*p_manhattan)/p_nro
print ("p(manhattan|nro)="+str(p_manhattan_nro))
# Out:
# p(brooklyn|nro)=0.323461799739
# p(queens|nro)=0.0468250969578
# p(bronx|nro)=0.0784522873023
# p(si|nro)=0.024658324653
# p(manhattan|nro)=0.526602491348

# %% [markdown]
# Spend some time to analyze the results and to draw conclusions.

# %% [markdown]
# ### Example 2 ###

# %% [markdown]
# In this example we are going to answer a simpler question. Given the NYPD collision data and assuming that a person has been involved in a traffic incident, for each of the five boroughs compute the empirical probability of a pedestrian being injured between 2pm and 3pm. Assume that the probability of being injured as a pedestrian and the probability of being injured between 2-3pm are independent of each other given that the person has been involved in an accident.

# %% [markdown]
# **[Assignment 4]**
# Spend some time to formulate the solution of the problem and to derive the required probability expressions.

# %% [markdown]
# **[Assignment 4 Hint]**
# We are tasked to compute the following conditional probability:
# $p(pedestrian,2-3pm\ |\ involved,\ Borough)$

# %% [markdown]
# **[Solution 4]**
#
# We are tasked to compute the following conditional probability:
# $p(pedestrian,2-3pm\ |\ involved,\ Borough)$
#
# Unlike the previous example in this example we'll assume that we are equally likely to be in any of the five boroughs.
# We then have:
# $p(pedestrian,\ 2-3pm\ |\ Borough,\ involved)\ = \ p(pedestrian\ |\ Borough,\ involved)*p( 2-3pm\ |\ Borough,\ involved)$

# %% [markdown]
# **[Assignment 5]** Implement the above solution and compute the probability

# %% [markdown]
# **[Solution 5]**
# Start by computing the probability of being injured as a pedestrian in each of the 5 boroughs:

# %%
boro_stats = coll_data.groupby('BOROUGH').sum()
boro_stats
# Out:
#                    ZIP CODE      LATITUDE     LONGITUDE  \
# BOROUGH
# BRONX          9.468849e+08  3.528566e+06 -6.381864e+06
# BROOKLYN       2.396929e+09  8.342707e+06 -1.517511e+07
# MANHATTAN      1.811705e+09  7.115376e+06 -1.291236e+07
# QUEENS         2.053302e+09  7.035624e+06 -1.275678e+07
# STATEN ISLAND  3.341255e+08  1.268370e+06 -2.316509e+06
#
#                NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  \
# BOROUGH
# BRONX                              26277                       111
# BROOKLYN                           63427                       260
# MANHATTAN                          30697                       147
# QUEENS                             46843                       232
# STATEN ISLAND                       7862                        46
#
#                NUMBER OF PEDESTRIANS INJURED  NUMBER OF PEDESTRIANS KILLED  \
# BOROUGH
# BRONX                                   6736                            68
# BROOKLYN                               14858                           153
# MANHATTAN                              11182                           118
# QUEENS                                  9931                           133
# STATEN ISLAND                           1234                            19
#
#                NUMBER OF CYCLIST INJURED  NUMBER OF CYCLIST KILLED  \
# BOROUGH
# BRONX                               1589                         7
# BROOKLYN                            6963                        22
# MANHATTAN                           5238                        11
# QUEENS                              3421                        17
# STATEN ISLAND                        176                         2
#
#                NUMBER OF MOTORIST INJURED  NUMBER OF MOTORIST KILLED  \
# BOROUGH
# BRONX                               19051                         38
# BROOKLYN                            43521                         86
# MANHATTAN                           15133                         20
# QUEENS                              35360                         85
# STATEN ISLAND                        6659                         25
#
#                  UNIQUE KEY
# BOROUGH
# BRONX          162285438694
# BROOKLYN       382324801866
# MANHATTAN      303438774961
# QUEENS         331491475613
# STATEN ISLAND   53154704626

# %%
boro_victim_stats = boro_stats[[
'NUMBER OF PERSONS INJURED',
'NUMBER OF PERSONS KILLED',
'NUMBER OF PEDESTRIANS INJURED',
'NUMBER OF PEDESTRIANS KILLED',
'NUMBER OF CYCLIST INJURED',
'NUMBER OF CYCLIST KILLED',
'NUMBER OF MOTORIST INJURED',
'NUMBER OF MOTORIST KILLED']]
boro_victim_stats.transpose()
# Out:
# BOROUGH                        BRONX  BROOKLYN  MANHATTAN  QUEENS  \
# NUMBER OF PERSONS INJURED      26277     63427      30697   46843
# NUMBER OF PERSONS KILLED         111       260        147     232
# NUMBER OF PEDESTRIANS INJURED   6736     14858      11182    9931
# NUMBER OF PEDESTRIANS KILLED      68       153        118     133
# NUMBER OF CYCLIST INJURED       1589      6963       5238    3421
# NUMBER OF CYCLIST KILLED           7        22         11      17
# NUMBER OF MOTORIST INJURED     19051     43521      15133   35360
# NUMBER OF MOTORIST KILLED         38        86         20      85
#
# BOROUGH                        STATEN ISLAND
# NUMBER OF PERSONS INJURED               7862
# NUMBER OF PERSONS KILLED                  46
# NUMBER OF PEDESTRIANS INJURED           1234
# NUMBER OF PEDESTRIANS KILLED              19
# NUMBER OF CYCLIST INJURED                176
# NUMBER OF CYCLIST KILLED                   2
# NUMBER OF MOTORIST INJURED              6659
# NUMBER OF MOTORIST KILLED                 25

# %%
injured_counts = boro_victim_stats.transpose().sum(axis=0)
injured_counts
# Out:
# BOROUGH
# BRONX             53877
# BROOKLYN         129290
# MANHATTAN         62546
# QUEENS            96022
# STATEN ISLAND     16023
# dtype: int64

# %%
ped_inj_counts = boro_stats['NUMBER OF PEDESTRIANS INJURED']
ped_inj_counts
# Out:
# BOROUGH
# BRONX             6736
# BROOKLYN         14858
# MANHATTAN        11182
# QUEENS            9931
# STATEN ISLAND     1234
# Name: NUMBER OF PEDESTRIANS INJURED, dtype: int64

# %%
p_inj_brooklyn = (1.0)*ped_inj_counts['BROOKLYN']/injured_counts['BROOKLYN']
print ("p(pedestrian|brooklyn, involved)="+str(p_inj_brooklyn))
p_inj_queens = (1.0)*ped_inj_counts['QUEENS']/injured_counts['QUEENS']
print ("p(pedestrian|queens, involved)="+str(p_inj_queens))
p_inj_bronx = (1.0)*ped_inj_counts['BRONX']/injured_counts['BRONX']
print ("p(pedestrian|bronx, involved)="+str(p_inj_bronx))
p_inj_si = (1.0)*ped_inj_counts['STATEN ISLAND']/injured_counts['STATEN ISLAND']
print ("p(pedestrian|state island, involved)="+str(p_inj_si))
p_inj_manhattan = (1.0)*ped_inj_counts['MANHATTAN']/injured_counts['MANHATTAN']
print ("p(pedestrian|manhattan, involved)="+str(p_inj_manhattan))
# Out:
# p(pedestrian|brooklyn, involved)=0.114919947405
# p(pedestrian|queens, involved)=0.103424215284
# p(pedestrian|bronx, involved)=0.125025521094
# p(pedestrian|state island, involved)=0.0770142919553
# p(pedestrian|manhattan, involved)=0.178780417613

# %% [markdown]
# Next we'll compute the probability of being injured between 2pm and 3pm.

# %%
collision_boro = coll_data['BOROUGH']
collision_boro
coll_counts = pd.value_counts(collision_boro)
coll_counts
# Out:
# BROOKLYN         213651
# QUEENS           180768
# MANHATTAN        180735
# BRONX             90506
# STATEN ISLAND     32417
# Name: BOROUGH, dtype: int64

# %%
time_boro = coll_data[['TIME','BOROUGH']]

# %%
twopm_injuries = time_boro.loc[coll_data['TIME'].str.contains('14:')]
twopm_injuries_borough =  pd.value_counts(twopm_injuries['BOROUGH'])
twopm_injuries_borough
# Out:
# BROOKLYN         14774
# QUEENS           12734
# MANHATTAN        12572
# BRONX             6030
# STATEN ISLAND     2437
# Name: BOROUGH, dtype: int64

# %%
p_2pm_brooklyn = (1.0)*twopm_injuries_borough['BROOKLYN']/coll_counts['BROOKLYN']
print ("p(2-3pm|brooklyn, involved)="+str(p_2pm_brooklyn))
p_2pm_queens = (1.0)*twopm_injuries_borough['QUEENS']/coll_counts['QUEENS']
print ("p(2-3pm|queens, involved)="+str(p_2pm_queens))
p_2pm_bronx = (1.0)*twopm_injuries_borough['BRONX']/coll_counts['BRONX']
print ("p(2-3pm|bronx, involved)="+str(p_2pm_bronx))
p_2pm_si = (1.0)*twopm_injuries_borough['STATEN ISLAND']/coll_counts['STATEN ISLAND']
print ("p(2-3pm|state island, involved)="+str(p_2pm_si))
p_2pm_manhattan = (1.0)*twopm_injuries_borough['MANHATTAN']/coll_counts['MANHATTAN']
print ("p(2-3pm|manhattan, involved)="+str(p_2pm_manhattan))
# Out:
# p(2-3pm|brooklyn, involved)=0.0691501560957
# p(2-3pm|queens, involved)=0.0704438838733
# p(2-3pm|bronx, involved)=0.0666254170994
# p(2-3pm|state island, involved)=0.0751766048678
# p(2-3pm|manhattan, involved)=0.0695604061195

# %%
p_inj_brooklyn_2pm = p_inj_brooklyn*p_2pm_brooklyn
print ("p(pedestrian,2−3pm|brooklyn,involved)="+str(p_inj_brooklyn_2pm))
p_inj_queens_2pm = p_inj_queens*p_2pm_queens
print ("p(pedestrian,2-3pm|queens,involved)="+str(p_inj_queens_2pm))
p_inj_bronx_2pm = p_inj_bronx*p_2pm_bronx
print ("p(pedestrian,2-3pm|bronx,involved)="+str(p_inj_bronx_2pm))
p_inj_si_2pm = p_inj_si*p_2pm_si
print ("p(pedestrian,2-3pm|brooklyn,involved)="+str(p_inj_si_2pm))
p_inj_manhattan_2pm = p_inj_manhattan*p_2pm_manhattan
print ("p(pedestrian,2-3pm|manhattan,involved)="+str(p_inj_manhattan_2pm))
# Out:
# p(pedestrian,2−3pm|brooklyn,involved)=0.00794673230157
# p(pedestrian,2-3pm|queens,involved)=0.00728560341115
# p(pedestrian,2-3pm|bronx,involved)=0.00832987749098
# p(pedestrian,2-3pm|brooklyn,involved)=0.0057896729955
# p(pedestrian,2-3pm|manhattan,involved)=0.0124360384553

# %% [markdown]
# Spend some time to analyze the results and to draw conclusions.
